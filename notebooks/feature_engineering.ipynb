# %%
import pandas as pd
import numpy as np
import re
from textblob import TextBlob
from sklearn.preprocessing import MinMaxScaler
from tqdm.notebook import tqdm

# %%
# Load dữ liệu đã làm sạch
df = pd.read_csv("cleaned_data_clean_only.csv")

# %%
# --- Đặc trưng cảm xúc (sentiment polarity) ---
def get_sentiment(text):
    try:
        return TextBlob(text).sentiment.polarity  # -1 đến 1
    except:
        return 0

print("🧠 Đang tính sentiment polarity...")
sentiments = []
for i, text in enumerate(tqdm(df['clean_text'].tolist(), desc="🧠 Sentiment", unit="text")):
    sentiments.append(get_sentiment(text))
    if (i + 1) % 50 == 0 or (i + 1) == len(df):
        percent = (i + 1) * 100 / len(df)
        print(f"➡️ Đã tính {i + 1}/{len(df)} sentiment ({percent:.2f}%)")
df['sentiment'] = sentiments
# Out:
# 🧠 Đang tính sentiment polarity...
# 🧠 Sentiment:   0%|          | 0/89712 [00:00<?, ?text/s]
# ➡️ Đã tính 50/89712 sentiment (0.06%)
# ➡️ Đã tính 100/89712 sentiment (0.11%)
# ➡️ Đã tính 150/89712 sentiment (0.17%)
# ➡️ Đã tính 200/89712 sentiment (0.22%)
# ➡️ Đã tính 250/89712 sentiment (0.28%)
# ➡️ Đã tính 300/89712 sentiment (0.33%)
# ➡️ Đã tính 350/89712 sentiment (0.39%)
# ➡️ Đã tính 400/89712 sentiment (0.45%)
# ➡️ Đã tính 450/89712 sentiment (0.50%)
# ➡️ Đã tính 500/89712 sentiment (0.56%)
# ➡️ Đã tính 550/89712 sentiment (0.61%)
# ➡️ Đã tính 600/89712 sentiment (0.67%)
# ➡️ Đã tính 650/89712 sentiment (0.72%)
# ➡️ Đã tính 700/89712 sentiment (0.78%)
# ➡️ Đã tính 750/89712 sentiment (0.84%)
# ➡️ Đã tính 800/89712 sentiment (0.89%)
# ➡️ Đã tính 850/89712 sentiment (0.95%)
# ➡️ Đã tính 900/89712 sentiment (1.00%)
# ➡️ Đã tính 950/89712 sentiment (1.06%)
# ➡️ Đã tính 1000/89712 sentiment (1.11%)
# ➡️ Đã tính 1050/89712 sentiment (1.17%)
# ➡️ Đã tính 1100/89712 sentiment (1.23%)
# ➡️ Đã tính 1150/89712 sentiment (1.28%)
# ➡️ Đã tính 1200/89712 sentiment (1.34%)
# ➡️ Đã tính 1250/89712 sentiment (1.39%)
# ➡️ Đã tính 1300/89712 sentiment (1.45%)
# ➡️ Đã tính 1350/89712 sentiment (1.50%)
# ➡️ Đã tính 1400/89712 sentiment (1.56%)
# ➡️ Đã tính 1450/89712 sentiment (1.62%)
# ➡️ Đã tính 1500/89712 sentiment (1.67%)
# ➡️ Đã tính 1550/89712 sentiment (1.73%)
# ➡️ Đã tính 1600/89712 sentiment (1.78%)
# ➡️ Đã tính 1650/89712 sentiment (1.84%)
# ➡️ Đã tính 1700/89712 sentiment (1.89%)
# ➡️ Đã tính 1750/89712 sentiment (1.95%)
# ➡️ Đã tính 1800/89712 sentiment (2.01%)
# ➡️ Đã tính 1850/89712 sentiment (2.06%)
# ➡️ Đã tính 1900/89712 sentiment (2.12%)
# ➡️ Đã tính 1950/89712 sentiment (2.17%)
# ➡️ Đã tính 2000/89712 sentiment (2.23%)
# ➡️ Đã tính 2050/89712 sentiment (2.29%)
# ➡️ Đã tính 2100/89712 sentiment (2.34%)
# ➡️ Đã tính 2150/89712 sentiment (2.40%)
# ➡️ Đã tính 2200/89712 sentiment (2.45%)
# ➡️ Đã tính 2250/89712 sentiment (2.51%)
# ➡️ Đã tính 2300/89712 sentiment (2.56%)
# ➡️ Đã tính 2350/89712 sentiment (2.62%)
# ➡️ Đã tính 2400/89712 sentiment (2.68%)
# ➡️ Đã tính 2450/89712 sentiment (2.73%)
# ➡️ Đã tính 2500/89712 sentiment (2.79%)
# ➡️ Đã tính 2550/89712 sentiment (2.84%)
# ➡️ Đã tính 2600/89712 sentiment (2.90%)
# ➡️ Đã tính 2650/89712 sentiment (2.95%)
# ➡️ Đã tính 2700/89712 sentiment (3.01%)
# ➡️ Đã tính 2750/89712 sentiment (3.07%)
# ➡️ Đã tính 2800/89712 sentiment (3.12%)
# ➡️ Đã tính 2850/89712 sentiment (3.18%)
# ➡️ Đã tính 2900/89712 sentiment (3.23%)
# ➡️ Đã tính 2950/89712 sentiment (3.29%)
# ➡️ Đã tính 3000/89712 sentiment (3.34%)
# ➡️ Đã tính 3050/89712 sentiment (3.40%)
# ➡️ Đã tính 3100/89712 sentiment (3.46%)
# ➡️ Đã tính 3150/89712 sentiment (3.51%)
# ➡️ Đã tính 3200/89712 sentiment (3.57%)
# ➡️ Đã tính 3250/89712 sentiment (3.62%)
# ➡️ Đã tính 3300/89712 sentiment (3.68%)
# ➡️ Đã tính 3350/89712 sentiment (3.73%)
# ➡️ Đã tính 3400/89712 sentiment (3.79%)
# ➡️ Đã tính 3450/89712 sentiment (3.85%)
# ➡️ Đã tính 3500/89712 sentiment (3.90%)
# ➡️ Đã tính 3550/89712 sentiment (3.96%)
# ➡️ Đã tính 3600/89712 sentiment (4.01%)
# ➡️ Đã tính 3650/89712 sentiment (4.07%)
# ➡️ Đã tính 3700/89712 sentiment (4.12%)
# ➡️ Đã tính 3750/89712 sentiment (4.18%)
# ➡️ Đã tính 3800/89712 sentiment (4.24%)
# ➡️ Đã tính 3850/89712 sentiment (4.29%)
# ➡️ Đã tính 3900/89712 sentiment (4.35%)
# ➡️ Đã tính 3950/89712 sentiment (4.40%)
# ➡️ Đã tính 4000/89712 sentiment (4.46%)
# ➡️ Đã tính 4050/89712 sentiment (4.51%)
# ➡️ Đã tính 4100/89712 sentiment (4.57%)
# ➡️ Đã tính 4150/89712 sentiment (4.63%)
# ➡️ Đã tính 4200/89712 sentiment (4.68%)
# ➡️ Đã tính 4250/89712 sentiment (4.74%)
# ➡️ Đã tính 4300/89712 sentiment (4.79%)
# ➡️ Đã tính 4350/89712 sentiment (4.85%)
# ➡️ Đã tính 4400/89712 sentiment (4.90%)
# ➡️ Đã tính 4450/89712 sentiment (4.96%)
# ➡️ Đã tính 4500/89712 sentiment (5.02%)
# ➡️ Đã tính 4550/89712 sentiment (5.07%)
# ➡️ Đã tính 4600/89712 sentiment (5.13%)
# ➡️ Đã tính 4650/89712 sentiment (5.18%)
# ➡️ Đã tính 4700/89712 sentiment (5.24%)
# ➡️ Đã tính 4750/89712 sentiment (5.29%)
# ➡️ Đã tính 4800/89712 sentiment (5.35%)
# ➡️ Đã tính 4850/89712 sentiment (5.41%)
# ➡️ Đã tính 4900/89712 sentiment (5.46%)
# ➡️ Đã tính 4950/89712 sentiment (5.52%)
# ➡️ Đã tính 5000/89712 sentiment (5.57%)
# ➡️ Đã tính 5050/89712 sentiment (5.63%)
# ➡️ Đã tính 5100/89712 sentiment (5.68%)
# ➡️ Đã tính 5150/89712 sentiment (5.74%)
# ➡️ Đã tính 5200/89712 sentiment (5.80%)
# ➡️ Đã tính 5250/89712 sentiment (5.85%)
# ➡️ Đã tính 5300/89712 sentiment (5.91%)
# ➡️ Đã tính 5350/89712 sentiment (5.96%)
# ➡️ Đã tính 5400/89712 sentiment (6.02%)
# ➡️ Đã tính 5450/89712 sentiment (6.07%)
# ➡️ Đã tính 5500/89712 sentiment (6.13%)
# ➡️ Đã tính 5550/89712 sentiment (6.19%)
# ➡️ Đã tính 5600/89712 sentiment (6.24%)
# ➡️ Đã tính 5650/89712 sentiment (6.30%)
# ➡️ Đã tính 5700/89712 sentiment (6.35%)
# ➡️ Đã tính 5750/89712 sentiment (6.41%)
# ➡️ Đã tính 5800/89712 sentiment (6.47%)
# ➡️ Đã tính 5850/89712 sentiment (6.52%)
# ➡️ Đã tính 5900/89712 sentiment (6.58%)
# ➡️ Đã tính 5950/89712 sentiment (6.63%)
# ➡️ Đã tính 6000/89712 sentiment (6.69%)
# ➡️ Đã tính 6050/89712 sentiment (6.74%)
# ➡️ Đã tính 6100/89712 sentiment (6.80%)
# ➡️ Đã tính 6150/89712 sentiment (6.86%)
# ➡️ Đã tính 6200/89712 sentiment (6.91%)
# ➡️ Đã tính 6250/89712 sentiment (6.97%)
# ➡️ Đã tính 6300/89712 sentiment (7.02%)
# ➡️ Đã tính 6350/89712 sentiment (7.08%)
# ➡️ Đã tính 6400/89712 sentiment (7.13%)
# ➡️ Đã tính 6450/89712 sentiment (7.19%)
# ➡️ Đã tính 6500/89712 sentiment (7.25%)
# ➡️ Đã tính 6550/89712 sentiment (7.30%)
# ➡️ Đã tính 6600/89712 sentiment (7.36%)
# ➡️ Đã tính 6650/89712 sentiment (7.41%)
# ➡️ Đã tính 6700/89712 sentiment (7.47%)
# ➡️ Đã tính 6750/89712 sentiment (7.52%)
# ➡️ Đã tính 6800/89712 sentiment (7.58%)
# ➡️ Đã tính 6850/89712 sentiment (7.64%)
# ➡️ Đã tính 6900/89712 sentiment (7.69%)
# ➡️ Đã tính 6950/89712 sentiment (7.75%)
# ➡️ Đã tính 7000/89712 sentiment (7.80%)
# ➡️ Đã tính 7050/89712 sentiment (7.86%)
# ➡️ Đã tính 7100/89712 sentiment (7.91%)
# ➡️ Đã tính 7150/89712 sentiment (7.97%)
# ➡️ Đã tính 7200/89712 sentiment (8.03%)
# ➡️ Đã tính 7250/89712 sentiment (8.08%)
# ➡️ Đã tính 7300/89712 sentiment (8.14%)
# ➡️ Đã tính 7350/89712 sentiment (8.19%)
# ➡️ Đã tính 7400/89712 sentiment (8.25%)
# ➡️ Đã tính 7450/89712 sentiment (8.30%)
# ➡️ Đã tính 7500/89712 sentiment (8.36%)
# ➡️ Đã tính 7550/89712 sentiment (8.42%)
# ➡️ Đã tính 7600/89712 sentiment (8.47%)
# ➡️ Đã tính 7650/89712 sentiment (8.53%)
# ➡️ Đã tính 7700/89712 sentiment (8.58%)
# ➡️ Đã tính 7750/89712 sentiment (8.64%)
# ➡️ Đã tính 7800/89712 sentiment (8.69%)
# ➡️ Đã tính 7850/89712 sentiment (8.75%)
# ➡️ Đã tính 7900/89712 sentiment (8.81%)
# ➡️ Đã tính 7950/89712 sentiment (8.86%)
# ➡️ Đã tính 8000/89712 sentiment (8.92%)
# ➡️ Đã tính 8050/89712 sentiment (8.97%)
# ➡️ Đã tính 8100/89712 sentiment (9.03%)
# ➡️ Đã tính 8150/89712 sentiment (9.08%)
# ➡️ Đã tính 8200/89712 sentiment (9.14%)
# ➡️ Đã tính 8250/89712 sentiment (9.20%)
# ➡️ Đã tính 8300/89712 sentiment (9.25%)
# ➡️ Đã tính 8350/89712 sentiment (9.31%)
# ➡️ Đã tính 8400/89712 sentiment (9.36%)
# ➡️ Đã tính 8450/89712 sentiment (9.42%)
# ➡️ Đã tính 8500/89712 sentiment (9.47%)
# ➡️ Đã tính 8550/89712 sentiment (9.53%)
# ➡️ Đã tính 8600/89712 sentiment (9.59%)
# ➡️ Đã tính 8650/89712 sentiment (9.64%)
# ➡️ Đã tính 8700/89712 sentiment (9.70%)
# ➡️ Đã tính 8750/89712 sentiment (9.75%)
# ➡️ Đã tính 8800/89712 sentiment (9.81%)
# ➡️ Đã tính 8850/89712 sentiment (9.86%)
# ➡️ Đã tính 8900/89712 sentiment (9.92%)
# ➡️ Đã tính 8950/89712 sentiment (9.98%)
# ➡️ Đã tính 9000/89712 sentiment (10.03%)
# ➡️ Đã tính 9050/89712 sentiment (10.09%)
# ➡️ Đã tính 9100/89712 sentiment (10.14%)
# ➡️ Đã tính 9150/89712 sentiment (10.20%)
# ➡️ Đã tính 9200/89712 sentiment (10.26%)
# ➡️ Đã tính 9250/89712 sentiment (10.31%)
# ➡️ Đã tính 9300/89712 sentiment (10.37%)
# ➡️ Đã tính 9350/89712 sentiment (10.42%)
# ➡️ Đã tính 9400/89712 sentiment (10.48%)
# ➡️ Đã tính 9450/89712 sentiment (10.53%)
# ➡️ Đã tính 9500/89712 sentiment (10.59%)
# ➡️ Đã tính 9550/89712 sentiment (10.65%)
# ➡️ Đã tính 9600/89712 sentiment (10.70%)
# ➡️ Đã tính 9650/89712 sentiment (10.76%)
# ➡️ Đã tính 9700/89712 sentiment (10.81%)
# ➡️ Đã tính 9750/89712 sentiment (10.87%)
# ➡️ Đã tính 9800/89712 sentiment (10.92%)
# ➡️ Đã tính 9850/89712 sentiment (10.98%)
# ➡️ Đã tính 9900/89712 sentiment (11.04%)
# ➡️ Đã tính 9950/89712 sentiment (11.09%)
# ➡️ Đã tính 10000/89712 sentiment (11.15%)
# ➡️ Đã tính 10050/89712 sentiment (11.20%)
# ➡️ Đã tính 10100/89712 sentiment (11.26%)
# ➡️ Đã tính 10150/89712 sentiment (11.31%)
# ➡️ Đã tính 10200/89712 sentiment (11.37%)
# ➡️ Đã tính 10250/89712 sentiment (11.43%)
# ➡️ Đã tính 10300/89712 sentiment (11.48%)
# ➡️ Đã tính 10350/89712 sentiment (11.54%)
# ➡️ Đã tính 10400/89712 sentiment (11.59%)
# ➡️ Đã tính 10450/89712 sentiment (11.65%)
# ➡️ Đã tính 10500/89712 sentiment (11.70%)
# ➡️ Đã tính 10550/89712 sentiment (11.76%)
# ➡️ Đã tính 10600/89712 sentiment (11.82%)
# ➡️ Đã tính 10650/89712 sentiment (11.87%)
# ➡️ Đã tính 10700/89712 sentiment (11.93%)
# ➡️ Đã tính 10750/89712 sentiment (11.98%)
# ➡️ Đã tính 10800/89712 sentiment (12.04%)
# ➡️ Đã tính 10850/89712 sentiment (12.09%)
# ➡️ Đã tính 10900/89712 sentiment (12.15%)
# ➡️ Đã tính 10950/89712 sentiment (12.21%)
# ➡️ Đã tính 11000/89712 sentiment (12.26%)
# ➡️ Đã tính 11050/89712 sentiment (12.32%)
# ➡️ Đã tính 11100/89712 sentiment (12.37%)
# ➡️ Đã tính 11150/89712 sentiment (12.43%)
# ➡️ Đã tính 11200/89712 sentiment (12.48%)
# ➡️ Đã tính 11250/89712 sentiment (12.54%)
# ➡️ Đã tính 11300/89712 sentiment (12.60%)
# ➡️ Đã tính 11350/89712 sentiment (12.65%)
# ➡️ Đã tính 11400/89712 sentiment (12.71%)
# ➡️ Đã tính 11450/89712 sentiment (12.76%)
# ➡️ Đã tính 11500/89712 sentiment (12.82%)
# ➡️ Đã tính 11550/89712 sentiment (12.87%)
# ➡️ Đã tính 11600/89712 sentiment (12.93%)
# ➡️ Đã tính 11650/89712 sentiment (12.99%)
# ➡️ Đã tính 11700/89712 sentiment (13.04%)
# ➡️ Đã tính 11750/89712 sentiment (13.10%)
# ➡️ Đã tính 11800/89712 sentiment (13.15%)
# ➡️ Đã tính 11850/89712 sentiment (13.21%)
# ➡️ Đã tính 11900/89712 sentiment (13.26%)
# ➡️ Đã tính 11950/89712 sentiment (13.32%)
# ➡️ Đã tính 12000/89712 sentiment (13.38%)
# ➡️ Đã tính 12050/89712 sentiment (13.43%)
# ➡️ Đã tính 12100/89712 sentiment (13.49%)
# ➡️ Đã tính 12150/89712 sentiment (13.54%)
# ➡️ Đã tính 12200/89712 sentiment (13.60%)
# ➡️ Đã tính 12250/89712 sentiment (13.65%)
# ➡️ Đã tính 12300/89712 sentiment (13.71%)
# ➡️ Đã tính 12350/89712 sentiment (13.77%)
# ➡️ Đã tính 12400/89712 sentiment (13.82%)
# ➡️ Đã tính 12450/89712 sentiment (13.88%)
# ➡️ Đã tính 12500/89712 sentiment (13.93%)
# ➡️ Đã tính 12550/89712 sentiment (13.99%)
# ➡️ Đã tính 12600/89712 sentiment (14.04%)
# ➡️ Đã tính 12650/89712 sentiment (14.10%)
# ➡️ Đã tính 12700/89712 sentiment (14.16%)
# ➡️ Đã tính 12750/89712 sentiment (14.21%)
# ➡️ Đã tính 12800/89712 sentiment (14.27%)
# ➡️ Đã tính 12850/89712 sentiment (14.32%)
# ➡️ Đã tính 12900/89712 sentiment (14.38%)
# ➡️ Đã tính 12950/89712 sentiment (14.44%)
# ➡️ Đã tính 13000/89712 sentiment (14.49%)
# ➡️ Đã tính 13050/89712 sentiment (14.55%)
# ➡️ Đã tính 13100/89712 sentiment (14.60%)
# ➡️ Đã tính 13150/89712 sentiment (14.66%)
# ➡️ Đã tính 13200/89712 sentiment (14.71%)
# ➡️ Đã tính 13250/89712 sentiment (14.77%)
# ➡️ Đã tính 13300/89712 sentiment (14.83%)
# ➡️ Đã tính 13350/89712 sentiment (14.88%)
# ➡️ Đã tính 13400/89712 sentiment (14.94%)
# ➡️ Đã tính 13450/89712 sentiment (14.99%)
# ➡️ Đã tính 13500/89712 sentiment (15.05%)
# ➡️ Đã tính 13550/89712 sentiment (15.10%)
# ➡️ Đã tính 13600/89712 sentiment (15.16%)
# ➡️ Đã tính 13650/89712 sentiment (15.22%)
# ➡️ Đã tính 13700/89712 sentiment (15.27%)
# ➡️ Đã tính 13750/89712 sentiment (15.33%)
# ➡️ Đã tính 13800/89712 sentiment (15.38%)
# ➡️ Đã tính 13850/89712 sentiment (15.44%)
# ➡️ Đã tính 13900/89712 sentiment (15.49%)
# ➡️ Đã tính 13950/89712 sentiment (15.55%)
# ➡️ Đã tính 14000/89712 sentiment (15.61%)
# ➡️ Đã tính 14050/89712 sentiment (15.66%)
# ➡️ Đã tính 14100/89712 sentiment (15.72%)
# ➡️ Đã tính 14150/89712 sentiment (15.77%)
# ➡️ Đã tính 14200/89712 sentiment (15.83%)
# ➡️ Đã tính 14250/89712 sentiment (15.88%)
# ➡️ Đã tính 14300/89712 sentiment (15.94%)
# ➡️ Đã tính 14350/89712 sentiment (16.00%)
# ➡️ Đã tính 14400/89712 sentiment (16.05%)
# ➡️ Đã tính 14450/89712 sentiment (16.11%)
# ➡️ Đã tính 14500/89712 sentiment (16.16%)
# ➡️ Đã tính 14550/89712 sentiment (16.22%)
# ➡️ Đã tính 14600/89712 sentiment (16.27%)
# ➡️ Đã tính 14650/89712 sentiment (16.33%)
# ➡️ Đã tính 14700/89712 sentiment (16.39%)
# ➡️ Đã tính 14750/89712 sentiment (16.44%)
# ➡️ Đã tính 14800/89712 sentiment (16.50%)
# ➡️ Đã tính 14850/89712 sentiment (16.55%)
# ➡️ Đã tính 14900/89712 sentiment (16.61%)
# ➡️ Đã tính 14950/89712 sentiment (16.66%)
# ➡️ Đã tính 15000/89712 sentiment (16.72%)
# ➡️ Đã tính 15050/89712 sentiment (16.78%)
# ➡️ Đã tính 15100/89712 sentiment (16.83%)
# ➡️ Đã tính 15150/89712 sentiment (16.89%)
# ➡️ Đã tính 15200/89712 sentiment (16.94%)
# ➡️ Đã tính 15250/89712 sentiment (17.00%)
# ➡️ Đã tính 15300/89712 sentiment (17.05%)
# ➡️ Đã tính 15350/89712 sentiment (17.11%)
# ➡️ Đã tính 15400/89712 sentiment (17.17%)
# ➡️ Đã tính 15450/89712 sentiment (17.22%)
# ➡️ Đã tính 15500/89712 sentiment (17.28%)
# ➡️ Đã tính 15550/89712 sentiment (17.33%)
# ➡️ Đã tính 15600/89712 sentiment (17.39%)
# ➡️ Đã tính 15650/89712 sentiment (17.44%)
# ➡️ Đã tính 15700/89712 sentiment (17.50%)
# ➡️ Đã tính 15750/89712 sentiment (17.56%)
# ➡️ Đã tính 15800/89712 sentiment (17.61%)
# ➡️ Đã tính 15850/89712 sentiment (17.67%)
# ➡️ Đã tính 15900/89712 sentiment (17.72%)
# ➡️ Đã tính 15950/89712 sentiment (17.78%)
# ➡️ Đã tính 16000/89712 sentiment (17.83%)
# ➡️ Đã tính 16050/89712 sentiment (17.89%)
# ➡️ Đã tính 16100/89712 sentiment (17.95%)
# ➡️ Đã tính 16150/89712 sentiment (18.00%)
# ➡️ Đã tính 16200/89712 sentiment (18.06%)
# ➡️ Đã tính 16250/89712 sentiment (18.11%)
# ➡️ Đã tính 16300/89712 sentiment (18.17%)
# ➡️ Đã tính 16350/89712 sentiment (18.22%)
# ➡️ Đã tính 16400/89712 sentiment (18.28%)
# ➡️ Đã tính 16450/89712 sentiment (18.34%)
# ➡️ Đã tính 16500/89712 sentiment (18.39%)
# ➡️ Đã tính 16550/89712 sentiment (18.45%)
# ➡️ Đã tính 16600/89712 sentiment (18.50%)
# ➡️ Đã tính 16650/89712 sentiment (18.56%)
# ➡️ Đã tính 16700/89712 sentiment (18.62%)
# ➡️ Đã tính 16750/89712 sentiment (18.67%)
# ➡️ Đã tính 16800/89712 sentiment (18.73%)
# ➡️ Đã tính 16850/89712 sentiment (18.78%)
# ➡️ Đã tính 16900/89712 sentiment (18.84%)
# ➡️ Đã tính 16950/89712 sentiment (18.89%)
# ➡️ Đã tính 17000/89712 sentiment (18.95%)
# ➡️ Đã tính 17050/89712 sentiment (19.01%)
# ➡️ Đã tính 17100/89712 sentiment (19.06%)
# ➡️ Đã tính 17150/89712 sentiment (19.12%)
# ➡️ Đã tính 17200/89712 sentiment (19.17%)
# ➡️ Đã tính 17250/89712 sentiment (19.23%)
# ➡️ Đã tính 17300/89712 sentiment (19.28%)
# ➡️ Đã tính 17350/89712 sentiment (19.34%)
# ➡️ Đã tính 17400/89712 sentiment (19.40%)
# ➡️ Đã tính 17450/89712 sentiment (19.45%)
# ➡️ Đã tính 17500/89712 sentiment (19.51%)
# ➡️ Đã tính 17550/89712 sentiment (19.56%)
# ➡️ Đã tính 17600/89712 sentiment (19.62%)
# ➡️ Đã tính 17650/89712 sentiment (19.67%)
# ➡️ Đã tính 17700/89712 sentiment (19.73%)
# ➡️ Đã tính 17750/89712 sentiment (19.79%)
# ➡️ Đã tính 17800/89712 sentiment (19.84%)
# ➡️ Đã tính 17850/89712 sentiment (19.90%)
# ➡️ Đã tính 17900/89712 sentiment (19.95%)
# ➡️ Đã tính 17950/89712 sentiment (20.01%)
# ➡️ Đã tính 18000/89712 sentiment (20.06%)
# ➡️ Đã tính 18050/89712 sentiment (20.12%)
# ➡️ Đã tính 18100/89712 sentiment (20.18%)
# ➡️ Đã tính 18150/89712 sentiment (20.23%)
# ➡️ Đã tính 18200/89712 sentiment (20.29%)
# ➡️ Đã tính 18250/89712 sentiment (20.34%)
# ➡️ Đã tính 18300/89712 sentiment (20.40%)
# ➡️ Đã tính 18350/89712 sentiment (20.45%)
# ➡️ Đã tính 18400/89712 sentiment (20.51%)
# ➡️ Đã tính 18450/89712 sentiment (20.57%)
# ➡️ Đã tính 18500/89712 sentiment (20.62%)
# ➡️ Đã tính 18550/89712 sentiment (20.68%)
# ➡️ Đã tính 18600/89712 sentiment (20.73%)
# ➡️ Đã tính 18650/89712 sentiment (20.79%)
# ➡️ Đã tính 18700/89712 sentiment (20.84%)
# ➡️ Đã tính 18750/89712 sentiment (20.90%)
# ➡️ Đã tính 18800/89712 sentiment (20.96%)
# ➡️ Đã tính 18850/89712 sentiment (21.01%)
# ➡️ Đã tính 18900/89712 sentiment (21.07%)
# ➡️ Đã tính 18950/89712 sentiment (21.12%)
# ➡️ Đã tính 19000/89712 sentiment (21.18%)
# ➡️ Đã tính 19050/89712 sentiment (21.23%)
# ➡️ Đã tính 19100/89712 sentiment (21.29%)
# ➡️ Đã tính 19150/89712 sentiment (21.35%)
# ➡️ Đã tính 19200/89712 sentiment (21.40%)
# ➡️ Đã tính 19250/89712 sentiment (21.46%)
# ➡️ Đã tính 19300/89712 sentiment (21.51%)
# ➡️ Đã tính 19350/89712 sentiment (21.57%)
# ➡️ Đã tính 19400/89712 sentiment (21.62%)
# ➡️ Đã tính 19450/89712 sentiment (21.68%)
# ➡️ Đã tính 19500/89712 sentiment (21.74%)
# ➡️ Đã tính 19550/89712 sentiment (21.79%)
# ➡️ Đã tính 19600/89712 sentiment (21.85%)
# ➡️ Đã tính 19650/89712 sentiment (21.90%)
# ➡️ Đã tính 19700/89712 sentiment (21.96%)
# ➡️ Đã tính 19750/89712 sentiment (22.01%)
# ➡️ Đã tính 19800/89712 sentiment (22.07%)
# ➡️ Đã tính 19850/89712 sentiment (22.13%)
# ➡️ Đã tính 19900/89712 sentiment (22.18%)
# ➡️ Đã tính 19950/89712 sentiment (22.24%)
# ➡️ Đã tính 20000/89712 sentiment (22.29%)
# ➡️ Đã tính 20050/89712 sentiment (22.35%)
# ➡️ Đã tính 20100/89712 sentiment (22.41%)
# ➡️ Đã tính 20150/89712 sentiment (22.46%)
# ➡️ Đã tính 20200/89712 sentiment (22.52%)
# ➡️ Đã tính 20250/89712 sentiment (22.57%)
# ➡️ Đã tính 20300/89712 sentiment (22.63%)
# ➡️ Đã tính 20350/89712 sentiment (22.68%)
# ➡️ Đã tính 20400/89712 sentiment (22.74%)
# ➡️ Đã tính 20450/89712 sentiment (22.80%)
# ➡️ Đã tính 20500/89712 sentiment (22.85%)
# ➡️ Đã tính 20550/89712 sentiment (22.91%)
# ➡️ Đã tính 20600/89712 sentiment (22.96%)
# ➡️ Đã tính 20650/89712 sentiment (23.02%)
# ➡️ Đã tính 20700/89712 sentiment (23.07%)
# ➡️ Đã tính 20750/89712 sentiment (23.13%)
# ➡️ Đã tính 20800/89712 sentiment (23.19%)
# ➡️ Đã tính 20850/89712 sentiment (23.24%)
# ➡️ Đã tính 20900/89712 sentiment (23.30%)
# ➡️ Đã tính 20950/89712 sentiment (23.35%)
# ➡️ Đã tính 21000/89712 sentiment (23.41%)
# ➡️ Đã tính 21050/89712 sentiment (23.46%)
# ➡️ Đã tính 21100/89712 sentiment (23.52%)
# ➡️ Đã tính 21150/89712 sentiment (23.58%)
# ➡️ Đã tính 21200/89712 sentiment (23.63%)
# ➡️ Đã tính 21250/89712 sentiment (23.69%)
# ➡️ Đã tính 21300/89712 sentiment (23.74%)
# ➡️ Đã tính 21350/89712 sentiment (23.80%)
# ➡️ Đã tính 21400/89712 sentiment (23.85%)
# ➡️ Đã tính 21450/89712 sentiment (23.91%)
# ➡️ Đã tính 21500/89712 sentiment (23.97%)
# ➡️ Đã tính 21550/89712 sentiment (24.02%)
# ➡️ Đã tính 21600/89712 sentiment (24.08%)
# ➡️ Đã tính 21650/89712 sentiment (24.13%)
# ➡️ Đã tính 21700/89712 sentiment (24.19%)
# ➡️ Đã tính 21750/89712 sentiment (24.24%)
# ➡️ Đã tính 21800/89712 sentiment (24.30%)
# ➡️ Đã tính 21850/89712 sentiment (24.36%)
# ➡️ Đã tính 21900/89712 sentiment (24.41%)
# ➡️ Đã tính 21950/89712 sentiment (24.47%)
# ➡️ Đã tính 22000/89712 sentiment (24.52%)
# ➡️ Đã tính 22050/89712 sentiment (24.58%)
# ➡️ Đã tính 22100/89712 sentiment (24.63%)
# ➡️ Đã tính 22150/89712 sentiment (24.69%)
# ➡️ Đã tính 22200/89712 sentiment (24.75%)
# ➡️ Đã tính 22250/89712 sentiment (24.80%)
# ➡️ Đã tính 22300/89712 sentiment (24.86%)
# ➡️ Đã tính 22350/89712 sentiment (24.91%)
# ➡️ Đã tính 22400/89712 sentiment (24.97%)
# ➡️ Đã tính 22450/89712 sentiment (25.02%)
# ➡️ Đã tính 22500/89712 sentiment (25.08%)
# ➡️ Đã tính 22550/89712 sentiment (25.14%)
# ➡️ Đã tính 22600/89712 sentiment (25.19%)
# ➡️ Đã tính 22650/89712 sentiment (25.25%)
# ➡️ Đã tính 22700/89712 sentiment (25.30%)
# ➡️ Đã tính 22750/89712 sentiment (25.36%)
# ➡️ Đã tính 22800/89712 sentiment (25.41%)
# ➡️ Đã tính 22850/89712 sentiment (25.47%)
# ➡️ Đã tính 22900/89712 sentiment (25.53%)
# ➡️ Đã tính 22950/89712 sentiment (25.58%)
# ➡️ Đã tính 23000/89712 sentiment (25.64%)
# ➡️ Đã tính 23050/89712 sentiment (25.69%)
# ➡️ Đã tính 23100/89712 sentiment (25.75%)
# ➡️ Đã tính 23150/89712 sentiment (25.80%)
# ➡️ Đã tính 23200/89712 sentiment (25.86%)
# ➡️ Đã tính 23250/89712 sentiment (25.92%)
# ➡️ Đã tính 23300/89712 sentiment (25.97%)
# ➡️ Đã tính 23350/89712 sentiment (26.03%)
# ➡️ Đã tính 23400/89712 sentiment (26.08%)
# ➡️ Đã tính 23450/89712 sentiment (26.14%)
# ➡️ Đã tính 23500/89712 sentiment (26.19%)
# ➡️ Đã tính 23550/89712 sentiment (26.25%)
# ➡️ Đã tính 23600/89712 sentiment (26.31%)
# ➡️ Đã tính 23650/89712 sentiment (26.36%)
# ➡️ Đã tính 23700/89712 sentiment (26.42%)
# ➡️ Đã tính 23750/89712 sentiment (26.47%)
# ➡️ Đã tính 23800/89712 sentiment (26.53%)
# ➡️ Đã tính 23850/89712 sentiment (26.59%)
# ➡️ Đã tính 23900/89712 sentiment (26.64%)
# ➡️ Đã tính 23950/89712 sentiment (26.70%)
# ➡️ Đã tính 24000/89712 sentiment (26.75%)
# ➡️ Đã tính 24050/89712 sentiment (26.81%)
# ➡️ Đã tính 24100/89712 sentiment (26.86%)
# ➡️ Đã tính 24150/89712 sentiment (26.92%)
# ➡️ Đã tính 24200/89712 sentiment (26.98%)
# ➡️ Đã tính 24250/89712 sentiment (27.03%)
# ➡️ Đã tính 24300/89712 sentiment (27.09%)
# ➡️ Đã tính 24350/89712 sentiment (27.14%)
# ➡️ Đã tính 24400/89712 sentiment (27.20%)
# ➡️ Đã tính 24450/89712 sentiment (27.25%)
# ➡️ Đã tính 24500/89712 sentiment (27.31%)
# ➡️ Đã tính 24550/89712 sentiment (27.37%)
# ➡️ Đã tính 24600/89712 sentiment (27.42%)
# ➡️ Đã tính 24650/89712 sentiment (27.48%)
# ➡️ Đã tính 24700/89712 sentiment (27.53%)
# ➡️ Đã tính 24750/89712 sentiment (27.59%)
# ➡️ Đã tính 24800/89712 sentiment (27.64%)
# ➡️ Đã tính 24850/89712 sentiment (27.70%)
# ➡️ Đã tính 24900/89712 sentiment (27.76%)
# ➡️ Đã tính 24950/89712 sentiment (27.81%)
# ➡️ Đã tính 25000/89712 sentiment (27.87%)
# ➡️ Đã tính 25050/89712 sentiment (27.92%)
# ➡️ Đã tính 25100/89712 sentiment (27.98%)
# ➡️ Đã tính 25150/89712 sentiment (28.03%)
# ➡️ Đã tính 25200/89712 sentiment (28.09%)
# ➡️ Đã tính 25250/89712 sentiment (28.15%)
# ➡️ Đã tính 25300/89712 sentiment (28.20%)
# ➡️ Đã tính 25350/89712 sentiment (28.26%)
# ➡️ Đã tính 25400/89712 sentiment (28.31%)
# ➡️ Đã tính 25450/89712 sentiment (28.37%)
# ➡️ Đã tính 25500/89712 sentiment (28.42%)
# ➡️ Đã tính 25550/89712 sentiment (28.48%)
# ➡️ Đã tính 25600/89712 sentiment (28.54%)
# ➡️ Đã tính 25650/89712 sentiment (28.59%)
# ➡️ Đã tính 25700/89712 sentiment (28.65%)
# ➡️ Đã tính 25750/89712 sentiment (28.70%)
# ➡️ Đã tính 25800/89712 sentiment (28.76%)
# ➡️ Đã tính 25850/89712 sentiment (28.81%)
# ➡️ Đã tính 25900/89712 sentiment (28.87%)
# ➡️ Đã tính 25950/89712 sentiment (28.93%)
# ➡️ Đã tính 26000/89712 sentiment (28.98%)
# ➡️ Đã tính 26050/89712 sentiment (29.04%)
# ➡️ Đã tính 26100/89712 sentiment (29.09%)
# ➡️ Đã tính 26150/89712 sentiment (29.15%)
# ➡️ Đã tính 26200/89712 sentiment (29.20%)
# ➡️ Đã tính 26250/89712 sentiment (29.26%)
# ➡️ Đã tính 26300/89712 sentiment (29.32%)
# ➡️ Đã tính 26350/89712 sentiment (29.37%)
# ➡️ Đã tính 26400/89712 sentiment (29.43%)
# ➡️ Đã tính 26450/89712 sentiment (29.48%)
# ➡️ Đã tính 26500/89712 sentiment (29.54%)
# ➡️ Đã tính 26550/89712 sentiment (29.59%)
# ➡️ Đã tính 26600/89712 sentiment (29.65%)
# ➡️ Đã tính 26650/89712 sentiment (29.71%)
# ➡️ Đã tính 26700/89712 sentiment (29.76%)
# ➡️ Đã tính 26750/89712 sentiment (29.82%)
# ➡️ Đã tính 26800/89712 sentiment (29.87%)
# ➡️ Đã tính 26850/89712 sentiment (29.93%)
# ➡️ Đã tính 26900/89712 sentiment (29.98%)
# ➡️ Đã tính 26950/89712 sentiment (30.04%)
# ➡️ Đã tính 27000/89712 sentiment (30.10%)
# ➡️ Đã tính 27050/89712 sentiment (30.15%)
# ➡️ Đã tính 27100/89712 sentiment (30.21%)
# ➡️ Đã tính 27150/89712 sentiment (30.26%)
# ➡️ Đã tính 27200/89712 sentiment (30.32%)
# ➡️ Đã tính 27250/89712 sentiment (30.37%)
# ➡️ Đã tính 27300/89712 sentiment (30.43%)
# ➡️ Đã tính 27350/89712 sentiment (30.49%)
# ➡️ Đã tính 27400/89712 sentiment (30.54%)
# ➡️ Đã tính 27450/89712 sentiment (30.60%)
# ➡️ Đã tính 27500/89712 sentiment (30.65%)
# ➡️ Đã tính 27550/89712 sentiment (30.71%)
# ➡️ Đã tính 27600/89712 sentiment (30.77%)
# ➡️ Đã tính 27650/89712 sentiment (30.82%)
# ➡️ Đã tính 27700/89712 sentiment (30.88%)
# ➡️ Đã tính 27750/89712 sentiment (30.93%)
# ➡️ Đã tính 27800/89712 sentiment (30.99%)
# ➡️ Đã tính 27850/89712 sentiment (31.04%)
# ➡️ Đã tính 27900/89712 sentiment (31.10%)
# ➡️ Đã tính 27950/89712 sentiment (31.16%)
# ➡️ Đã tính 28000/89712 sentiment (31.21%)
# ➡️ Đã tính 28050/89712 sentiment (31.27%)
# ➡️ Đã tính 28100/89712 sentiment (31.32%)
# ➡️ Đã tính 28150/89712 sentiment (31.38%)
# ➡️ Đã tính 28200/89712 sentiment (31.43%)
# ➡️ Đã tính 28250/89712 sentiment (31.49%)
# ➡️ Đã tính 28300/89712 sentiment (31.55%)
# ➡️ Đã tính 28350/89712 sentiment (31.60%)
# ➡️ Đã tính 28400/89712 sentiment (31.66%)
# ➡️ Đã tính 28450/89712 sentiment (31.71%)
# ➡️ Đã tính 28500/89712 sentiment (31.77%)
# ➡️ Đã tính 28550/89712 sentiment (31.82%)
# ➡️ Đã tính 28600/89712 sentiment (31.88%)
# ➡️ Đã tính 28650/89712 sentiment (31.94%)
# ➡️ Đã tính 28700/89712 sentiment (31.99%)
# ➡️ Đã tính 28750/89712 sentiment (32.05%)
# ➡️ Đã tính 28800/89712 sentiment (32.10%)
# ➡️ Đã tính 28850/89712 sentiment (32.16%)
# ➡️ Đã tính 28900/89712 sentiment (32.21%)
# ➡️ Đã tính 28950/89712 sentiment (32.27%)
# ➡️ Đã tính 29000/89712 sentiment (32.33%)
# ➡️ Đã tính 29050/89712 sentiment (32.38%)
# ➡️ Đã tính 29100/89712 sentiment (32.44%)
# ➡️ Đã tính 29150/89712 sentiment (32.49%)
# ➡️ Đã tính 29200/89712 sentiment (32.55%)
# ➡️ Đã tính 29250/89712 sentiment (32.60%)
# ➡️ Đã tính 29300/89712 sentiment (32.66%)
# ➡️ Đã tính 29350/89712 sentiment (32.72%)
# ➡️ Đã tính 29400/89712 sentiment (32.77%)
# ➡️ Đã tính 29450/89712 sentiment (32.83%)
# ➡️ Đã tính 29500/89712 sentiment (32.88%)
# ➡️ Đã tính 29550/89712 sentiment (32.94%)
# ➡️ Đã tính 29600/89712 sentiment (32.99%)
# ➡️ Đã tính 29650/89712 sentiment (33.05%)
# ➡️ Đã tính 29700/89712 sentiment (33.11%)
# ➡️ Đã tính 29750/89712 sentiment (33.16%)
# ➡️ Đã tính 29800/89712 sentiment (33.22%)
# ➡️ Đã tính 29850/89712 sentiment (33.27%)
# ➡️ Đã tính 29900/89712 sentiment (33.33%)
# ➡️ Đã tính 29950/89712 sentiment (33.38%)
# ➡️ Đã tính 30000/89712 sentiment (33.44%)
# ➡️ Đã tính 30050/89712 sentiment (33.50%)
# ➡️ Đã tính 30100/89712 sentiment (33.55%)
# ➡️ Đã tính 30150/89712 sentiment (33.61%)
# ➡️ Đã tính 30200/89712 sentiment (33.66%)
# ➡️ Đã tính 30250/89712 sentiment (33.72%)
# ➡️ Đã tính 30300/89712 sentiment (33.77%)
# ➡️ Đã tính 30350/89712 sentiment (33.83%)
# ➡️ Đã tính 30400/89712 sentiment (33.89%)
# ➡️ Đã tính 30450/89712 sentiment (33.94%)
# ➡️ Đã tính 30500/89712 sentiment (34.00%)
# ➡️ Đã tính 30550/89712 sentiment (34.05%)
# ➡️ Đã tính 30600/89712 sentiment (34.11%)
# ➡️ Đã tính 30650/89712 sentiment (34.16%)
# ➡️ Đã tính 30700/89712 sentiment (34.22%)
# ➡️ Đã tính 30750/89712 sentiment (34.28%)
# ➡️ Đã tính 30800/89712 sentiment (34.33%)
# ➡️ Đã tính 30850/89712 sentiment (34.39%)
# ➡️ Đã tính 30900/89712 sentiment (34.44%)
# ➡️ Đã tính 30950/89712 sentiment (34.50%)
# ➡️ Đã tính 31000/89712 sentiment (34.56%)
# ➡️ Đã tính 31050/89712 sentiment (34.61%)
# ➡️ Đã tính 31100/89712 sentiment (34.67%)
# ➡️ Đã tính 31150/89712 sentiment (34.72%)
# ➡️ Đã tính 31200/89712 sentiment (34.78%)
# ➡️ Đã tính 31250/89712 sentiment (34.83%)
# ➡️ Đã tính 31300/89712 sentiment (34.89%)
# ➡️ Đã tính 31350/89712 sentiment (34.95%)
# ➡️ Đã tính 31400/89712 sentiment (35.00%)
# ➡️ Đã tính 31450/89712 sentiment (35.06%)
# ➡️ Đã tính 31500/89712 sentiment (35.11%)
# ➡️ Đã tính 31550/89712 sentiment (35.17%)
# ➡️ Đã tính 31600/89712 sentiment (35.22%)
# ➡️ Đã tính 31650/89712 sentiment (35.28%)
# ➡️ Đã tính 31700/89712 sentiment (35.34%)
# ➡️ Đã tính 31750/89712 sentiment (35.39%)
# ➡️ Đã tính 31800/89712 sentiment (35.45%)
# ➡️ Đã tính 31850/89712 sentiment (35.50%)
# ➡️ Đã tính 31900/89712 sentiment (35.56%)
# ➡️ Đã tính 31950/89712 sentiment (35.61%)
# ➡️ Đã tính 32000/89712 sentiment (35.67%)
# ➡️ Đã tính 32050/89712 sentiment (35.73%)
# ➡️ Đã tính 32100/89712 sentiment (35.78%)
# ➡️ Đã tính 32150/89712 sentiment (35.84%)
# ➡️ Đã tính 32200/89712 sentiment (35.89%)
# ➡️ Đã tính 32250/89712 sentiment (35.95%)
# ➡️ Đã tính 32300/89712 sentiment (36.00%)
# ➡️ Đã tính 32350/89712 sentiment (36.06%)
# ➡️ Đã tính 32400/89712 sentiment (36.12%)
# ➡️ Đã tính 32450/89712 sentiment (36.17%)
# ➡️ Đã tính 32500/89712 sentiment (36.23%)
# ➡️ Đã tính 32550/89712 sentiment (36.28%)
# ➡️ Đã tính 32600/89712 sentiment (36.34%)
# ➡️ Đã tính 32650/89712 sentiment (36.39%)
# ➡️ Đã tính 32700/89712 sentiment (36.45%)
# ➡️ Đã tính 32750/89712 sentiment (36.51%)
# ➡️ Đã tính 32800/89712 sentiment (36.56%)
# ➡️ Đã tính 32850/89712 sentiment (36.62%)
# ➡️ Đã tính 32900/89712 sentiment (36.67%)
# ➡️ Đã tính 32950/89712 sentiment (36.73%)
# ➡️ Đã tính 33000/89712 sentiment (36.78%)
# ➡️ Đã tính 33050/89712 sentiment (36.84%)
# ➡️ Đã tính 33100/89712 sentiment (36.90%)
# ➡️ Đã tính 33150/89712 sentiment (36.95%)
# ➡️ Đã tính 33200/89712 sentiment (37.01%)
# ➡️ Đã tính 33250/89712 sentiment (37.06%)
# ➡️ Đã tính 33300/89712 sentiment (37.12%)
# ➡️ Đã tính 33350/89712 sentiment (37.17%)
# ➡️ Đã tính 33400/89712 sentiment (37.23%)
# ➡️ Đã tính 33450/89712 sentiment (37.29%)
# ➡️ Đã tính 33500/89712 sentiment (37.34%)
# ➡️ Đã tính 33550/89712 sentiment (37.40%)
# ➡️ Đã tính 33600/89712 sentiment (37.45%)
# ➡️ Đã tính 33650/89712 sentiment (37.51%)
# ➡️ Đã tính 33700/89712 sentiment (37.56%)
# ➡️ Đã tính 33750/89712 sentiment (37.62%)
# ➡️ Đã tính 33800/89712 sentiment (37.68%)
# ➡️ Đã tính 33850/89712 sentiment (37.73%)
# ➡️ Đã tính 33900/89712 sentiment (37.79%)
# ➡️ Đã tính 33950/89712 sentiment (37.84%)
# ➡️ Đã tính 34000/89712 sentiment (37.90%)
# ➡️ Đã tính 34050/89712 sentiment (37.95%)
# ➡️ Đã tính 34100/89712 sentiment (38.01%)
# ➡️ Đã tính 34150/89712 sentiment (38.07%)
# ➡️ Đã tính 34200/89712 sentiment (38.12%)
# ➡️ Đã tính 34250/89712 sentiment (38.18%)
# ➡️ Đã tính 34300/89712 sentiment (38.23%)
# ➡️ Đã tính 34350/89712 sentiment (38.29%)
# ➡️ Đã tính 34400/89712 sentiment (38.34%)
# ➡️ Đã tính 34450/89712 sentiment (38.40%)
# ➡️ Đã tính 34500/89712 sentiment (38.46%)
# ➡️ Đã tính 34550/89712 sentiment (38.51%)
# ➡️ Đã tính 34600/89712 sentiment (38.57%)
# ➡️ Đã tính 34650/89712 sentiment (38.62%)
# ➡️ Đã tính 34700/89712 sentiment (38.68%)
# ➡️ Đã tính 34750/89712 sentiment (38.74%)
# ➡️ Đã tính 34800/89712 sentiment (38.79%)
# ➡️ Đã tính 34850/89712 sentiment (38.85%)
# ➡️ Đã tính 34900/89712 sentiment (38.90%)
# ➡️ Đã tính 34950/89712 sentiment (38.96%)
# ➡️ Đã tính 35000/89712 sentiment (39.01%)
# ➡️ Đã tính 35050/89712 sentiment (39.07%)
# ➡️ Đã tính 35100/89712 sentiment (39.13%)
# ➡️ Đã tính 35150/89712 sentiment (39.18%)
# ➡️ Đã tính 35200/89712 sentiment (39.24%)
# ➡️ Đã tính 35250/89712 sentiment (39.29%)
# ➡️ Đã tính 35300/89712 sentiment (39.35%)
# ➡️ Đã tính 35350/89712 sentiment (39.40%)
# ➡️ Đã tính 35400/89712 sentiment (39.46%)
# ➡️ Đã tính 35450/89712 sentiment (39.52%)
# ➡️ Đã tính 35500/89712 sentiment (39.57%)
# ➡️ Đã tính 35550/89712 sentiment (39.63%)
# ➡️ Đã tính 35600/89712 sentiment (39.68%)
# ➡️ Đã tính 35650/89712 sentiment (39.74%)
# ➡️ Đã tính 35700/89712 sentiment (39.79%)
# ➡️ Đã tính 35750/89712 sentiment (39.85%)
# ➡️ Đã tính 35800/89712 sentiment (39.91%)
# ➡️ Đã tính 35850/89712 sentiment (39.96%)
# ➡️ Đã tính 35900/89712 sentiment (40.02%)
# ➡️ Đã tính 35950/89712 sentiment (40.07%)
# ➡️ Đã tính 36000/89712 sentiment (40.13%)
# ➡️ Đã tính 36050/89712 sentiment (40.18%)
# ➡️ Đã tính 36100/89712 sentiment (40.24%)
# ➡️ Đã tính 36150/89712 sentiment (40.30%)
# ➡️ Đã tính 36200/89712 sentiment (40.35%)
# ➡️ Đã tính 36250/89712 sentiment (40.41%)
# ➡️ Đã tính 36300/89712 sentiment (40.46%)
# ➡️ Đã tính 36350/89712 sentiment (40.52%)
# ➡️ Đã tính 36400/89712 sentiment (40.57%)
# ➡️ Đã tính 36450/89712 sentiment (40.63%)
# ➡️ Đã tính 36500/89712 sentiment (40.69%)
# ➡️ Đã tính 36550/89712 sentiment (40.74%)
# ➡️ Đã tính 36600/89712 sentiment (40.80%)
# ➡️ Đã tính 36650/89712 sentiment (40.85%)
# ➡️ Đã tính 36700/89712 sentiment (40.91%)
# ➡️ Đã tính 36750/89712 sentiment (40.96%)
# ➡️ Đã tính 36800/89712 sentiment (41.02%)
# ➡️ Đã tính 36850/89712 sentiment (41.08%)
# ➡️ Đã tính 36900/89712 sentiment (41.13%)
# ➡️ Đã tính 36950/89712 sentiment (41.19%)
# ➡️ Đã tính 37000/89712 sentiment (41.24%)
# ➡️ Đã tính 37050/89712 sentiment (41.30%)
# ➡️ Đã tính 37100/89712 sentiment (41.35%)
# ➡️ Đã tính 37150/89712 sentiment (41.41%)
# ➡️ Đã tính 37200/89712 sentiment (41.47%)
# ➡️ Đã tính 37250/89712 sentiment (41.52%)
# ➡️ Đã tính 37300/89712 sentiment (41.58%)
# ➡️ Đã tính 37350/89712 sentiment (41.63%)
# ➡️ Đã tính 37400/89712 sentiment (41.69%)
# ➡️ Đã tính 37450/89712 sentiment (41.74%)
# ➡️ Đã tính 37500/89712 sentiment (41.80%)
# ➡️ Đã tính 37550/89712 sentiment (41.86%)
# ➡️ Đã tính 37600/89712 sentiment (41.91%)
# ➡️ Đã tính 37650/89712 sentiment (41.97%)
# ➡️ Đã tính 37700/89712 sentiment (42.02%)
# ➡️ Đã tính 37750/89712 sentiment (42.08%)
# ➡️ Đã tính 37800/89712 sentiment (42.13%)
# ➡️ Đã tính 37850/89712 sentiment (42.19%)
# ➡️ Đã tính 37900/89712 sentiment (42.25%)
# ➡️ Đã tính 37950/89712 sentiment (42.30%)
# ➡️ Đã tính 38000/89712 sentiment (42.36%)
# ➡️ Đã tính 38050/89712 sentiment (42.41%)
# ➡️ Đã tính 38100/89712 sentiment (42.47%)
# ➡️ Đã tính 38150/89712 sentiment (42.52%)
# ➡️ Đã tính 38200/89712 sentiment (42.58%)
# ➡️ Đã tính 38250/89712 sentiment (42.64%)
# ➡️ Đã tính 38300/89712 sentiment (42.69%)
# ➡️ Đã tính 38350/89712 sentiment (42.75%)
# ➡️ Đã tính 38400/89712 sentiment (42.80%)
# ➡️ Đã tính 38450/89712 sentiment (42.86%)
# ➡️ Đã tính 38500/89712 sentiment (42.92%)
# ➡️ Đã tính 38550/89712 sentiment (42.97%)
# ➡️ Đã tính 38600/89712 sentiment (43.03%)
# ➡️ Đã tính 38650/89712 sentiment (43.08%)
# ➡️ Đã tính 38700/89712 sentiment (43.14%)
# ➡️ Đã tính 38750/89712 sentiment (43.19%)
# ➡️ Đã tính 38800/89712 sentiment (43.25%)
# ➡️ Đã tính 38850/89712 sentiment (43.31%)
# ➡️ Đã tính 38900/89712 sentiment (43.36%)
# ➡️ Đã tính 38950/89712 sentiment (43.42%)
# ➡️ Đã tính 39000/89712 sentiment (43.47%)
# ➡️ Đã tính 39050/89712 sentiment (43.53%)
# ➡️ Đã tính 39100/89712 sentiment (43.58%)
# ➡️ Đã tính 39150/89712 sentiment (43.64%)
# ➡️ Đã tính 39200/89712 sentiment (43.70%)
# ➡️ Đã tính 39250/89712 sentiment (43.75%)
# ➡️ Đã tính 39300/89712 sentiment (43.81%)
# ➡️ Đã tính 39350/89712 sentiment (43.86%)
# ➡️ Đã tính 39400/89712 sentiment (43.92%)
# ➡️ Đã tính 39450/89712 sentiment (43.97%)
# ➡️ Đã tính 39500/89712 sentiment (44.03%)
# ➡️ Đã tính 39550/89712 sentiment (44.09%)
# ➡️ Đã tính 39600/89712 sentiment (44.14%)
# ➡️ Đã tính 39650/89712 sentiment (44.20%)
# ➡️ Đã tính 39700/89712 sentiment (44.25%)
# ➡️ Đã tính 39750/89712 sentiment (44.31%)
# ➡️ Đã tính 39800/89712 sentiment (44.36%)
# ➡️ Đã tính 39850/89712 sentiment (44.42%)
# ➡️ Đã tính 39900/89712 sentiment (44.48%)
# ➡️ Đã tính 39950/89712 sentiment (44.53%)
# ➡️ Đã tính 40000/89712 sentiment (44.59%)
# ➡️ Đã tính 40050/89712 sentiment (44.64%)
# ➡️ Đã tính 40100/89712 sentiment (44.70%)
# ➡️ Đã tính 40150/89712 sentiment (44.75%)
# ➡️ Đã tính 40200/89712 sentiment (44.81%)
# ➡️ Đã tính 40250/89712 sentiment (44.87%)
# ➡️ Đã tính 40300/89712 sentiment (44.92%)
# ➡️ Đã tính 40350/89712 sentiment (44.98%)
# ➡️ Đã tính 40400/89712 sentiment (45.03%)
# ➡️ Đã tính 40450/89712 sentiment (45.09%)
# ➡️ Đã tính 40500/89712 sentiment (45.14%)
# ➡️ Đã tính 40550/89712 sentiment (45.20%)
# ➡️ Đã tính 40600/89712 sentiment (45.26%)
# ➡️ Đã tính 40650/89712 sentiment (45.31%)
# ➡️ Đã tính 40700/89712 sentiment (45.37%)
# ➡️ Đã tính 40750/89712 sentiment (45.42%)
# ➡️ Đã tính 40800/89712 sentiment (45.48%)
# ➡️ Đã tính 40850/89712 sentiment (45.53%)
# ➡️ Đã tính 40900/89712 sentiment (45.59%)
# ➡️ Đã tính 40950/89712 sentiment (45.65%)
# ➡️ Đã tính 41000/89712 sentiment (45.70%)
# ➡️ Đã tính 41050/89712 sentiment (45.76%)
# ➡️ Đã tính 41100/89712 sentiment (45.81%)
# ➡️ Đã tính 41150/89712 sentiment (45.87%)
# ➡️ Đã tính 41200/89712 sentiment (45.92%)
# ➡️ Đã tính 41250/89712 sentiment (45.98%)
# ➡️ Đã tính 41300/89712 sentiment (46.04%)
# ➡️ Đã tính 41350/89712 sentiment (46.09%)
# ➡️ Đã tính 41400/89712 sentiment (46.15%)
# ➡️ Đã tính 41450/89712 sentiment (46.20%)
# ➡️ Đã tính 41500/89712 sentiment (46.26%)
# ➡️ Đã tính 41550/89712 sentiment (46.31%)
# ➡️ Đã tính 41600/89712 sentiment (46.37%)
# ➡️ Đã tính 41650/89712 sentiment (46.43%)
# ➡️ Đã tính 41700/89712 sentiment (46.48%)
# ➡️ Đã tính 41750/89712 sentiment (46.54%)
# ➡️ Đã tính 41800/89712 sentiment (46.59%)
# ➡️ Đã tính 41850/89712 sentiment (46.65%)
# ➡️ Đã tính 41900/89712 sentiment (46.71%)
# ➡️ Đã tính 41950/89712 sentiment (46.76%)
# ➡️ Đã tính 42000/89712 sentiment (46.82%)
# ➡️ Đã tính 42050/89712 sentiment (46.87%)
# ➡️ Đã tính 42100/89712 sentiment (46.93%)
# ➡️ Đã tính 42150/89712 sentiment (46.98%)
# ➡️ Đã tính 42200/89712 sentiment (47.04%)
# ➡️ Đã tính 42250/89712 sentiment (47.10%)
# ➡️ Đã tính 42300/89712 sentiment (47.15%)
# ➡️ Đã tính 42350/89712 sentiment (47.21%)
# ➡️ Đã tính 42400/89712 sentiment (47.26%)
# ➡️ Đã tính 42450/89712 sentiment (47.32%)
# ➡️ Đã tính 42500/89712 sentiment (47.37%)
# ➡️ Đã tính 42550/89712 sentiment (47.43%)
# ➡️ Đã tính 42600/89712 sentiment (47.49%)
# ➡️ Đã tính 42650/89712 sentiment (47.54%)
# ➡️ Đã tính 42700/89712 sentiment (47.60%)
# ➡️ Đã tính 42750/89712 sentiment (47.65%)
# ➡️ Đã tính 42800/89712 sentiment (47.71%)
# ➡️ Đã tính 42850/89712 sentiment (47.76%)
# ➡️ Đã tính 42900/89712 sentiment (47.82%)
# ➡️ Đã tính 42950/89712 sentiment (47.88%)
# ➡️ Đã tính 43000/89712 sentiment (47.93%)
# ➡️ Đã tính 43050/89712 sentiment (47.99%)
# ➡️ Đã tính 43100/89712 sentiment (48.04%)
# ➡️ Đã tính 43150/89712 sentiment (48.10%)
# ➡️ Đã tính 43200/89712 sentiment (48.15%)
# ➡️ Đã tính 43250/89712 sentiment (48.21%)
# ➡️ Đã tính 43300/89712 sentiment (48.27%)
# ➡️ Đã tính 43350/89712 sentiment (48.32%)
# ➡️ Đã tính 43400/89712 sentiment (48.38%)
# ➡️ Đã tính 43450/89712 sentiment (48.43%)
# ➡️ Đã tính 43500/89712 sentiment (48.49%)
# ➡️ Đã tính 43550/89712 sentiment (48.54%)
# ➡️ Đã tính 43600/89712 sentiment (48.60%)
# ➡️ Đã tính 43650/89712 sentiment (48.66%)
# ➡️ Đã tính 43700/89712 sentiment (48.71%)
# ➡️ Đã tính 43750/89712 sentiment (48.77%)
# ➡️ Đã tính 43800/89712 sentiment (48.82%)
# ➡️ Đã tính 43850/89712 sentiment (48.88%)
# ➡️ Đã tính 43900/89712 sentiment (48.93%)
# ➡️ Đã tính 43950/89712 sentiment (48.99%)
# ➡️ Đã tính 44000/89712 sentiment (49.05%)
# ➡️ Đã tính 44050/89712 sentiment (49.10%)
# ➡️ Đã tính 44100/89712 sentiment (49.16%)
# ➡️ Đã tính 44150/89712 sentiment (49.21%)
# ➡️ Đã tính 44200/89712 sentiment (49.27%)
# ➡️ Đã tính 44250/89712 sentiment (49.32%)
# ➡️ Đã tính 44300/89712 sentiment (49.38%)
# ➡️ Đã tính 44350/89712 sentiment (49.44%)
# ➡️ Đã tính 44400/89712 sentiment (49.49%)
# ➡️ Đã tính 44450/89712 sentiment (49.55%)
# ➡️ Đã tính 44500/89712 sentiment (49.60%)
# ➡️ Đã tính 44550/89712 sentiment (49.66%)
# ➡️ Đã tính 44600/89712 sentiment (49.71%)
# ➡️ Đã tính 44650/89712 sentiment (49.77%)
# ➡️ Đã tính 44700/89712 sentiment (49.83%)
# ➡️ Đã tính 44750/89712 sentiment (49.88%)
# ➡️ Đã tính 44800/89712 sentiment (49.94%)
# ➡️ Đã tính 44850/89712 sentiment (49.99%)
# ➡️ Đã tính 44900/89712 sentiment (50.05%)
# ➡️ Đã tính 44950/89712 sentiment (50.10%)
# ➡️ Đã tính 45000/89712 sentiment (50.16%)
# ➡️ Đã tính 45050/89712 sentiment (50.22%)
# ➡️ Đã tính 45100/89712 sentiment (50.27%)
# ➡️ Đã tính 45150/89712 sentiment (50.33%)
# ➡️ Đã tính 45200/89712 sentiment (50.38%)
# ➡️ Đã tính 45250/89712 sentiment (50.44%)
# ➡️ Đã tính 45300/89712 sentiment (50.49%)
# ➡️ Đã tính 45350/89712 sentiment (50.55%)
# ➡️ Đã tính 45400/89712 sentiment (50.61%)
# ➡️ Đã tính 45450/89712 sentiment (50.66%)
# ➡️ Đã tính 45500/89712 sentiment (50.72%)
# ➡️ Đã tính 45550/89712 sentiment (50.77%)
# ➡️ Đã tính 45600/89712 sentiment (50.83%)
# ➡️ Đã tính 45650/89712 sentiment (50.89%)
# ➡️ Đã tính 45700/89712 sentiment (50.94%)
# ➡️ Đã tính 45750/89712 sentiment (51.00%)
# ➡️ Đã tính 45800/89712 sentiment (51.05%)
# ➡️ Đã tính 45850/89712 sentiment (51.11%)
# ➡️ Đã tính 45900/89712 sentiment (51.16%)
# ➡️ Đã tính 45950/89712 sentiment (51.22%)
# ➡️ Đã tính 46000/89712 sentiment (51.28%)
# ➡️ Đã tính 46050/89712 sentiment (51.33%)
# ➡️ Đã tính 46100/89712 sentiment (51.39%)
# ➡️ Đã tính 46150/89712 sentiment (51.44%)
# ➡️ Đã tính 46200/89712 sentiment (51.50%)
# ➡️ Đã tính 46250/89712 sentiment (51.55%)
# ➡️ Đã tính 46300/89712 sentiment (51.61%)
# ➡️ Đã tính 46350/89712 sentiment (51.67%)
# ➡️ Đã tính 46400/89712 sentiment (51.72%)
# ➡️ Đã tính 46450/89712 sentiment (51.78%)
# ➡️ Đã tính 46500/89712 sentiment (51.83%)
# ➡️ Đã tính 46550/89712 sentiment (51.89%)
# ➡️ Đã tính 46600/89712 sentiment (51.94%)
# ➡️ Đã tính 46650/89712 sentiment (52.00%)
# ➡️ Đã tính 46700/89712 sentiment (52.06%)
# ➡️ Đã tính 46750/89712 sentiment (52.11%)
# ➡️ Đã tính 46800/89712 sentiment (52.17%)
# ➡️ Đã tính 46850/89712 sentiment (52.22%)
# ➡️ Đã tính 46900/89712 sentiment (52.28%)
# ➡️ Đã tính 46950/89712 sentiment (52.33%)
# ➡️ Đã tính 47000/89712 sentiment (52.39%)
# ➡️ Đã tính 47050/89712 sentiment (52.45%)
# ➡️ Đã tính 47100/89712 sentiment (52.50%)
# ➡️ Đã tính 47150/89712 sentiment (52.56%)
# ➡️ Đã tính 47200/89712 sentiment (52.61%)
# ➡️ Đã tính 47250/89712 sentiment (52.67%)
# ➡️ Đã tính 47300/89712 sentiment (52.72%)
# ➡️ Đã tính 47350/89712 sentiment (52.78%)
# ➡️ Đã tính 47400/89712 sentiment (52.84%)
# ➡️ Đã tính 47450/89712 sentiment (52.89%)
# ➡️ Đã tính 47500/89712 sentiment (52.95%)
# ➡️ Đã tính 47550/89712 sentiment (53.00%)
# ➡️ Đã tính 47600/89712 sentiment (53.06%)
# ➡️ Đã tính 47650/89712 sentiment (53.11%)
# ➡️ Đã tính 47700/89712 sentiment (53.17%)
# ➡️ Đã tính 47750/89712 sentiment (53.23%)
# ➡️ Đã tính 47800/89712 sentiment (53.28%)
# ➡️ Đã tính 47850/89712 sentiment (53.34%)
# ➡️ Đã tính 47900/89712 sentiment (53.39%)
# ➡️ Đã tính 47950/89712 sentiment (53.45%)
# ➡️ Đã tính 48000/89712 sentiment (53.50%)
# ➡️ Đã tính 48050/89712 sentiment (53.56%)
# ➡️ Đã tính 48100/89712 sentiment (53.62%)
# ➡️ Đã tính 48150/89712 sentiment (53.67%)
# ➡️ Đã tính 48200/89712 sentiment (53.73%)
# ➡️ Đã tính 48250/89712 sentiment (53.78%)
# ➡️ Đã tính 48300/89712 sentiment (53.84%)
# ➡️ Đã tính 48350/89712 sentiment (53.89%)
# ➡️ Đã tính 48400/89712 sentiment (53.95%)
# ➡️ Đã tính 48450/89712 sentiment (54.01%)
# ➡️ Đã tính 48500/89712 sentiment (54.06%)
# ➡️ Đã tính 48550/89712 sentiment (54.12%)
# ➡️ Đã tính 48600/89712 sentiment (54.17%)
# ➡️ Đã tính 48650/89712 sentiment (54.23%)
# ➡️ Đã tính 48700/89712 sentiment (54.28%)
# ➡️ Đã tính 48750/89712 sentiment (54.34%)
# ➡️ Đã tính 48800/89712 sentiment (54.40%)
# ➡️ Đã tính 48850/89712 sentiment (54.45%)
# ➡️ Đã tính 48900/89712 sentiment (54.51%)
# ➡️ Đã tính 48950/89712 sentiment (54.56%)
# ➡️ Đã tính 49000/89712 sentiment (54.62%)
# ➡️ Đã tính 49050/89712 sentiment (54.67%)
# ➡️ Đã tính 49100/89712 sentiment (54.73%)
# ➡️ Đã tính 49150/89712 sentiment (54.79%)
# ➡️ Đã tính 49200/89712 sentiment (54.84%)
# ➡️ Đã tính 49250/89712 sentiment (54.90%)
# ➡️ Đã tính 49300/89712 sentiment (54.95%)
# ➡️ Đã tính 49350/89712 sentiment (55.01%)
# ➡️ Đã tính 49400/89712 sentiment (55.07%)
# ➡️ Đã tính 49450/89712 sentiment (55.12%)
# ➡️ Đã tính 49500/89712 sentiment (55.18%)
# ➡️ Đã tính 49550/89712 sentiment (55.23%)
# ➡️ Đã tính 49600/89712 sentiment (55.29%)
# ➡️ Đã tính 49650/89712 sentiment (55.34%)
# ➡️ Đã tính 49700/89712 sentiment (55.40%)
# ➡️ Đã tính 49750/89712 sentiment (55.46%)
# ➡️ Đã tính 49800/89712 sentiment (55.51%)
# ➡️ Đã tính 49850/89712 sentiment (55.57%)
# ➡️ Đã tính 49900/89712 sentiment (55.62%)
# ➡️ Đã tính 49950/89712 sentiment (55.68%)
# ➡️ Đã tính 50000/89712 sentiment (55.73%)
# ➡️ Đã tính 50050/89712 sentiment (55.79%)
# ➡️ Đã tính 50100/89712 sentiment (55.85%)
# ➡️ Đã tính 50150/89712 sentiment (55.90%)
# ➡️ Đã tính 50200/89712 sentiment (55.96%)
# ➡️ Đã tính 50250/89712 sentiment (56.01%)
# ➡️ Đã tính 50300/89712 sentiment (56.07%)
# ➡️ Đã tính 50350/89712 sentiment (56.12%)
# ➡️ Đã tính 50400/89712 sentiment (56.18%)
# ➡️ Đã tính 50450/89712 sentiment (56.24%)
# ➡️ Đã tính 50500/89712 sentiment (56.29%)
# ➡️ Đã tính 50550/89712 sentiment (56.35%)
# ➡️ Đã tính 50600/89712 sentiment (56.40%)
# ➡️ Đã tính 50650/89712 sentiment (56.46%)
# ➡️ Đã tính 50700/89712 sentiment (56.51%)
# ➡️ Đã tính 50750/89712 sentiment (56.57%)
# ➡️ Đã tính 50800/89712 sentiment (56.63%)
# ➡️ Đã tính 50850/89712 sentiment (56.68%)
# ➡️ Đã tính 50900/89712 sentiment (56.74%)
# ➡️ Đã tính 50950/89712 sentiment (56.79%)
# ➡️ Đã tính 51000/89712 sentiment (56.85%)
# ➡️ Đã tính 51050/89712 sentiment (56.90%)
# ➡️ Đã tính 51100/89712 sentiment (56.96%)
# ➡️ Đã tính 51150/89712 sentiment (57.02%)
# ➡️ Đã tính 51200/89712 sentiment (57.07%)
# ➡️ Đã tính 51250/89712 sentiment (57.13%)
# ➡️ Đã tính 51300/89712 sentiment (57.18%)
# ➡️ Đã tính 51350/89712 sentiment (57.24%)
# ➡️ Đã tính 51400/89712 sentiment (57.29%)
# ➡️ Đã tính 51450/89712 sentiment (57.35%)
# ➡️ Đã tính 51500/89712 sentiment (57.41%)
# ➡️ Đã tính 51550/89712 sentiment (57.46%)
# ➡️ Đã tính 51600/89712 sentiment (57.52%)
# ➡️ Đã tính 51650/89712 sentiment (57.57%)
# ➡️ Đã tính 51700/89712 sentiment (57.63%)
# ➡️ Đã tính 51750/89712 sentiment (57.68%)
# ➡️ Đã tính 51800/89712 sentiment (57.74%)
# ➡️ Đã tính 51850/89712 sentiment (57.80%)
# ➡️ Đã tính 51900/89712 sentiment (57.85%)
# ➡️ Đã tính 51950/89712 sentiment (57.91%)
# ➡️ Đã tính 52000/89712 sentiment (57.96%)
# ➡️ Đã tính 52050/89712 sentiment (58.02%)
# ➡️ Đã tính 52100/89712 sentiment (58.07%)
# ➡️ Đã tính 52150/89712 sentiment (58.13%)
# ➡️ Đã tính 52200/89712 sentiment (58.19%)
# ➡️ Đã tính 52250/89712 sentiment (58.24%)
# ➡️ Đã tính 52300/89712 sentiment (58.30%)
# ➡️ Đã tính 52350/89712 sentiment (58.35%)
# ➡️ Đã tính 52400/89712 sentiment (58.41%)
# ➡️ Đã tính 52450/89712 sentiment (58.46%)
# ➡️ Đã tính 52500/89712 sentiment (58.52%)
# ➡️ Đã tính 52550/89712 sentiment (58.58%)
# ➡️ Đã tính 52600/89712 sentiment (58.63%)
# ➡️ Đã tính 52650/89712 sentiment (58.69%)
# ➡️ Đã tính 52700/89712 sentiment (58.74%)
# ➡️ Đã tính 52750/89712 sentiment (58.80%)
# ➡️ Đã tính 52800/89712 sentiment (58.86%)
# ➡️ Đã tính 52850/89712 sentiment (58.91%)
# ➡️ Đã tính 52900/89712 sentiment (58.97%)
# ➡️ Đã tính 52950/89712 sentiment (59.02%)
# ➡️ Đã tính 53000/89712 sentiment (59.08%)
# ➡️ Đã tính 53050/89712 sentiment (59.13%)
# ➡️ Đã tính 53100/89712 sentiment (59.19%)
# ➡️ Đã tính 53150/89712 sentiment (59.25%)
# ➡️ Đã tính 53200/89712 sentiment (59.30%)
# ➡️ Đã tính 53250/89712 sentiment (59.36%)
# ➡️ Đã tính 53300/89712 sentiment (59.41%)
# ➡️ Đã tính 53350/89712 sentiment (59.47%)
# ➡️ Đã tính 53400/89712 sentiment (59.52%)
# ➡️ Đã tính 53450/89712 sentiment (59.58%)
# ➡️ Đã tính 53500/89712 sentiment (59.64%)
# ➡️ Đã tính 53550/89712 sentiment (59.69%)
# ➡️ Đã tính 53600/89712 sentiment (59.75%)
# ➡️ Đã tính 53650/89712 sentiment (59.80%)
# ➡️ Đã tính 53700/89712 sentiment (59.86%)
# ➡️ Đã tính 53750/89712 sentiment (59.91%)
# ➡️ Đã tính 53800/89712 sentiment (59.97%)
# ➡️ Đã tính 53850/89712 sentiment (60.03%)
# ➡️ Đã tính 53900/89712 sentiment (60.08%)
# ➡️ Đã tính 53950/89712 sentiment (60.14%)
# ➡️ Đã tính 54000/89712 sentiment (60.19%)
# ➡️ Đã tính 54050/89712 sentiment (60.25%)
# ➡️ Đã tính 54100/89712 sentiment (60.30%)
# ➡️ Đã tính 54150/89712 sentiment (60.36%)
# ➡️ Đã tính 54200/89712 sentiment (60.42%)
# ➡️ Đã tính 54250/89712 sentiment (60.47%)
# ➡️ Đã tính 54300/89712 sentiment (60.53%)
# ➡️ Đã tính 54350/89712 sentiment (60.58%)
# ➡️ Đã tính 54400/89712 sentiment (60.64%)
# ➡️ Đã tính 54450/89712 sentiment (60.69%)
# ➡️ Đã tính 54500/89712 sentiment (60.75%)
# ➡️ Đã tính 54550/89712 sentiment (60.81%)
# ➡️ Đã tính 54600/89712 sentiment (60.86%)
# ➡️ Đã tính 54650/89712 sentiment (60.92%)
# ➡️ Đã tính 54700/89712 sentiment (60.97%)
# ➡️ Đã tính 54750/89712 sentiment (61.03%)
# ➡️ Đã tính 54800/89712 sentiment (61.08%)
# ➡️ Đã tính 54850/89712 sentiment (61.14%)
# ➡️ Đã tính 54900/89712 sentiment (61.20%)
# ➡️ Đã tính 54950/89712 sentiment (61.25%)
# ➡️ Đã tính 55000/89712 sentiment (61.31%)
# ➡️ Đã tính 55050/89712 sentiment (61.36%)
# ➡️ Đã tính 55100/89712 sentiment (61.42%)
# ➡️ Đã tính 55150/89712 sentiment (61.47%)
# ➡️ Đã tính 55200/89712 sentiment (61.53%)
# ➡️ Đã tính 55250/89712 sentiment (61.59%)
# ➡️ Đã tính 55300/89712 sentiment (61.64%)
# ➡️ Đã tính 55350/89712 sentiment (61.70%)
# ➡️ Đã tính 55400/89712 sentiment (61.75%)
# ➡️ Đã tính 55450/89712 sentiment (61.81%)
# ➡️ Đã tính 55500/89712 sentiment (61.86%)
# ➡️ Đã tính 55550/89712 sentiment (61.92%)
# ➡️ Đã tính 55600/89712 sentiment (61.98%)
# ➡️ Đã tính 55650/89712 sentiment (62.03%)
# ➡️ Đã tính 55700/89712 sentiment (62.09%)
# ➡️ Đã tính 55750/89712 sentiment (62.14%)
# ➡️ Đã tính 55800/89712 sentiment (62.20%)
# ➡️ Đã tính 55850/89712 sentiment (62.25%)
# ➡️ Đã tính 55900/89712 sentiment (62.31%)
# ➡️ Đã tính 55950/89712 sentiment (62.37%)
# ➡️ Đã tính 56000/89712 sentiment (62.42%)
# ➡️ Đã tính 56050/89712 sentiment (62.48%)
# ➡️ Đã tính 56100/89712 sentiment (62.53%)
# ➡️ Đã tính 56150/89712 sentiment (62.59%)
# ➡️ Đã tính 56200/89712 sentiment (62.64%)
# ➡️ Đã tính 56250/89712 sentiment (62.70%)
# ➡️ Đã tính 56300/89712 sentiment (62.76%)
# ➡️ Đã tính 56350/89712 sentiment (62.81%)
# ➡️ Đã tính 56400/89712 sentiment (62.87%)
# ➡️ Đã tính 56450/89712 sentiment (62.92%)
# ➡️ Đã tính 56500/89712 sentiment (62.98%)
# ➡️ Đã tính 56550/89712 sentiment (63.04%)
# ➡️ Đã tính 56600/89712 sentiment (63.09%)
# ➡️ Đã tính 56650/89712 sentiment (63.15%)
# ➡️ Đã tính 56700/89712 sentiment (63.20%)
# ➡️ Đã tính 56750/89712 sentiment (63.26%)
# ➡️ Đã tính 56800/89712 sentiment (63.31%)
# ➡️ Đã tính 56850/89712 sentiment (63.37%)
# ➡️ Đã tính 56900/89712 sentiment (63.43%)
# ➡️ Đã tính 56950/89712 sentiment (63.48%)
# ➡️ Đã tính 57000/89712 sentiment (63.54%)
# ➡️ Đã tính 57050/89712 sentiment (63.59%)
# ➡️ Đã tính 57100/89712 sentiment (63.65%)
# ➡️ Đã tính 57150/89712 sentiment (63.70%)
# ➡️ Đã tính 57200/89712 sentiment (63.76%)
# ➡️ Đã tính 57250/89712 sentiment (63.82%)
# ➡️ Đã tính 57300/89712 sentiment (63.87%)
# ➡️ Đã tính 57350/89712 sentiment (63.93%)
# ➡️ Đã tính 57400/89712 sentiment (63.98%)
# ➡️ Đã tính 57450/89712 sentiment (64.04%)
# ➡️ Đã tính 57500/89712 sentiment (64.09%)
# ...
# ➡️ Đã tính 70800/89712 sentiment (78.92%)
# ➡️ Đã tính 70850/89712 sentiment (78.97%)
# ➡️ Đã tính 70900/89712 sentiment (79.03%)
# ➡️ Đã tính 70950/89712 sentiment (79.09%)
# ➡️ Đã tính 71000/89712 sentiment (79.14%)
# ➡️ Đã tính 71050/89712 sentiment (79.20%)
# ➡️ Đã tính 71100/89712 sentiment (79.25%)
# ➡️ Đã tính 71150/89712 sentiment (79.31%)
# ➡️ Đã tính 71200/89712 sentiment (79.37%)
# ➡️ Đã tính 71250/89712 sentiment (79.42%)
# ➡️ Đã tính 71300/89712 sentiment (79.48%)
# ➡️ Đã tính 71350/89712 sentiment (79.53%)
# ➡️ Đã tính 71400/89712 sentiment (79.59%)
# ➡️ Đã tính 71450/89712 sentiment (79.64%)
# ➡️ Đã tính 71500/89712 sentiment (79.70%)
# ➡️ Đã tính 71550/89712 sentiment (79.76%)
# ➡️ Đã tính 71600/89712 sentiment (79.81%)
# ➡️ Đã tính 71650/89712 sentiment (79.87%)
# ➡️ Đã tính 71700/89712 sentiment (79.92%)
# ➡️ Đã tính 71750/89712 sentiment (79.98%)
# ➡️ Đã tính 71800/89712 sentiment (80.03%)
# ➡️ Đã tính 71850/89712 sentiment (80.09%)
# ➡️ Đã tính 71900/89712 sentiment (80.15%)
# ➡️ Đã tính 71950/89712 sentiment (80.20%)
# ➡️ Đã tính 72000/89712 sentiment (80.26%)
# ➡️ Đã tính 72050/89712 sentiment (80.31%)
# ➡️ Đã tính 72100/89712 sentiment (80.37%)
# ➡️ Đã tính 72150/89712 sentiment (80.42%)
# ➡️ Đã tính 72200/89712 sentiment (80.48%)
# ➡️ Đã tính 72250/89712 sentiment (80.54%)
# ➡️ Đã tính 72300/89712 sentiment (80.59%)
# ➡️ Đã tính 72350/89712 sentiment (80.65%)
# ➡️ Đã tính 72400/89712 sentiment (80.70%)
# ➡️ Đã tính 72450/89712 sentiment (80.76%)
# ➡️ Đã tính 72500/89712 sentiment (80.81%)
# ➡️ Đã tính 72550/89712 sentiment (80.87%)
# ➡️ Đã tính 72600/89712 sentiment (80.93%)
# ➡️ Đã tính 72650/89712 sentiment (80.98%)
# ➡️ Đã tính 72700/89712 sentiment (81.04%)
# ➡️ Đã tính 72750/89712 sentiment (81.09%)
# ➡️ Đã tính 72800/89712 sentiment (81.15%)
# ➡️ Đã tính 72850/89712 sentiment (81.20%)
# ➡️ Đã tính 72900/89712 sentiment (81.26%)
# ➡️ Đã tính 72950/89712 sentiment (81.32%)
# ➡️ Đã tính 73000/89712 sentiment (81.37%)
# ➡️ Đã tính 73050/89712 sentiment (81.43%)
# ➡️ Đã tính 73100/89712 sentiment (81.48%)
# ➡️ Đã tính 73150/89712 sentiment (81.54%)
# ➡️ Đã tính 73200/89712 sentiment (81.59%)
# ➡️ Đã tính 73250/89712 sentiment (81.65%)
# ➡️ Đã tính 73300/89712 sentiment (81.71%)
# ➡️ Đã tính 73350/89712 sentiment (81.76%)
# ➡️ Đã tính 73400/89712 sentiment (81.82%)
# ➡️ Đã tính 73450/89712 sentiment (81.87%)
# ➡️ Đã tính 73500/89712 sentiment (81.93%)
# ➡️ Đã tính 73550/89712 sentiment (81.98%)
# ➡️ Đã tính 73600/89712 sentiment (82.04%)
# ➡️ Đã tính 73650/89712 sentiment (82.10%)
# ➡️ Đã tính 73700/89712 sentiment (82.15%)
# ➡️ Đã tính 73750/89712 sentiment (82.21%)
# ➡️ Đã tính 73800/89712 sentiment (82.26%)
# ➡️ Đã tính 73850/89712 sentiment (82.32%)
# ➡️ Đã tính 73900/89712 sentiment (82.37%)
# ➡️ Đã tính 73950/89712 sentiment (82.43%)
# ➡️ Đã tính 74000/89712 sentiment (82.49%)
# ➡️ Đã tính 74050/89712 sentiment (82.54%)
# ➡️ Đã tính 74100/89712 sentiment (82.60%)
# ➡️ Đã tính 74150/89712 sentiment (82.65%)
# ➡️ Đã tính 74200/89712 sentiment (82.71%)
# ➡️ Đã tính 74250/89712 sentiment (82.76%)
# ➡️ Đã tính 74300/89712 sentiment (82.82%)
# ➡️ Đã tính 74350/89712 sentiment (82.88%)
# ➡️ Đã tính 74400/89712 sentiment (82.93%)
# ➡️ Đã tính 74450/89712 sentiment (82.99%)
# ➡️ Đã tính 74500/89712 sentiment (83.04%)
# ➡️ Đã tính 74550/89712 sentiment (83.10%)
# ➡️ Đã tính 74600/89712 sentiment (83.15%)
# ➡️ Đã tính 74650/89712 sentiment (83.21%)
# ➡️ Đã tính 74700/89712 sentiment (83.27%)
# ➡️ Đã tính 74750/89712 sentiment (83.32%)
# ➡️ Đã tính 74800/89712 sentiment (83.38%)
# ➡️ Đã tính 74850/89712 sentiment (83.43%)
# ➡️ Đã tính 74900/89712 sentiment (83.49%)
# ➡️ Đã tính 74950/89712 sentiment (83.55%)
# ➡️ Đã tính 75000/89712 sentiment (83.60%)
# ➡️ Đã tính 75050/89712 sentiment (83.66%)
# ➡️ Đã tính 75100/89712 sentiment (83.71%)
# ➡️ Đã tính 75150/89712 sentiment (83.77%)
# ➡️ Đã tính 75200/89712 sentiment (83.82%)
# ➡️ Đã tính 75250/89712 sentiment (83.88%)
# ➡️ Đã tính 75300/89712 sentiment (83.94%)
# ➡️ Đã tính 75350/89712 sentiment (83.99%)
# ➡️ Đã tính 75400/89712 sentiment (84.05%)
# ➡️ Đã tính 75450/89712 sentiment (84.10%)
# ➡️ Đã tính 75500/89712 sentiment (84.16%)
# ➡️ Đã tính 75550/89712 sentiment (84.21%)
# ➡️ Đã tính 75600/89712 sentiment (84.27%)
# ➡️ Đã tính 75650/89712 sentiment (84.33%)
# ➡️ Đã tính 75700/89712 sentiment (84.38%)
# ➡️ Đã tính 75750/89712 sentiment (84.44%)
# ➡️ Đã tính 75800/89712 sentiment (84.49%)
# ➡️ Đã tính 75850/89712 sentiment (84.55%)
# ➡️ Đã tính 75900/89712 sentiment (84.60%)
# ➡️ Đã tính 75950/89712 sentiment (84.66%)
# ➡️ Đã tính 76000/89712 sentiment (84.72%)
# ➡️ Đã tính 76050/89712 sentiment (84.77%)
# ➡️ Đã tính 76100/89712 sentiment (84.83%)
# ➡️ Đã tính 76150/89712 sentiment (84.88%)
# ➡️ Đã tính 76200/89712 sentiment (84.94%)
# ➡️ Đã tính 76250/89712 sentiment (84.99%)
# ➡️ Đã tính 76300/89712 sentiment (85.05%)
# ➡️ Đã tính 76350/89712 sentiment (85.11%)
# ➡️ Đã tính 76400/89712 sentiment (85.16%)
# ➡️ Đã tính 76450/89712 sentiment (85.22%)
# ➡️ Đã tính 76500/89712 sentiment (85.27%)
# ➡️ Đã tính 76550/89712 sentiment (85.33%)
# ➡️ Đã tính 76600/89712 sentiment (85.38%)
# ➡️ Đã tính 76650/89712 sentiment (85.44%)
# ➡️ Đã tính 76700/89712 sentiment (85.50%)
# ➡️ Đã tính 76750/89712 sentiment (85.55%)
# ➡️ Đã tính 76800/89712 sentiment (85.61%)
# ➡️ Đã tính 76850/89712 sentiment (85.66%)
# ➡️ Đã tính 76900/89712 sentiment (85.72%)
# ➡️ Đã tính 76950/89712 sentiment (85.77%)
# ➡️ Đã tính 77000/89712 sentiment (85.83%)
# ➡️ Đã tính 77050/89712 sentiment (85.89%)
# ➡️ Đã tính 77100/89712 sentiment (85.94%)
# ➡️ Đã tính 77150/89712 sentiment (86.00%)
# ➡️ Đã tính 77200/89712 sentiment (86.05%)
# ➡️ Đã tính 77250/89712 sentiment (86.11%)
# ➡️ Đã tính 77300/89712 sentiment (86.16%)
# ➡️ Đã tính 77350/89712 sentiment (86.22%)
# ➡️ Đã tính 77400/89712 sentiment (86.28%)
# ➡️ Đã tính 77450/89712 sentiment (86.33%)
# ➡️ Đã tính 77500/89712 sentiment (86.39%)
# ➡️ Đã tính 77550/89712 sentiment (86.44%)
# ➡️ Đã tính 77600/89712 sentiment (86.50%)
# ➡️ Đã tính 77650/89712 sentiment (86.55%)
# ➡️ Đã tính 77700/89712 sentiment (86.61%)
# ➡️ Đã tính 77750/89712 sentiment (86.67%)
# ➡️ Đã tính 77800/89712 sentiment (86.72%)
# ➡️ Đã tính 77850/89712 sentiment (86.78%)
# ➡️ Đã tính 77900/89712 sentiment (86.83%)
# ➡️ Đã tính 77950/89712 sentiment (86.89%)
# ➡️ Đã tính 78000/89712 sentiment (86.94%)
# ➡️ Đã tính 78050/89712 sentiment (87.00%)
# ➡️ Đã tính 78100/89712 sentiment (87.06%)
# ➡️ Đã tính 78150/89712 sentiment (87.11%)
# ➡️ Đã tính 78200/89712 sentiment (87.17%)
# ➡️ Đã tính 78250/89712 sentiment (87.22%)
# ➡️ Đã tính 78300/89712 sentiment (87.28%)
# ➡️ Đã tính 78350/89712 sentiment (87.34%)
# ➡️ Đã tính 78400/89712 sentiment (87.39%)
# ➡️ Đã tính 78450/89712 sentiment (87.45%)
# ➡️ Đã tính 78500/89712 sentiment (87.50%)
# ➡️ Đã tính 78550/89712 sentiment (87.56%)
# ➡️ Đã tính 78600/89712 sentiment (87.61%)
# ➡️ Đã tính 78650/89712 sentiment (87.67%)
# ➡️ Đã tính 78700/89712 sentiment (87.73%)
# ➡️ Đã tính 78750/89712 sentiment (87.78%)
# ➡️ Đã tính 78800/89712 sentiment (87.84%)
# ➡️ Đã tính 78850/89712 sentiment (87.89%)
# ➡️ Đã tính 78900/89712 sentiment (87.95%)
# ➡️ Đã tính 78950/89712 sentiment (88.00%)
# ➡️ Đã tính 79000/89712 sentiment (88.06%)
# ➡️ Đã tính 79050/89712 sentiment (88.12%)
# ➡️ Đã tính 79100/89712 sentiment (88.17%)
# ➡️ Đã tính 79150/89712 sentiment (88.23%)
# ➡️ Đã tính 79200/89712 sentiment (88.28%)
# ➡️ Đã tính 79250/89712 sentiment (88.34%)
# ➡️ Đã tính 79300/89712 sentiment (88.39%)
# ➡️ Đã tính 79350/89712 sentiment (88.45%)
# ➡️ Đã tính 79400/89712 sentiment (88.51%)
# ➡️ Đã tính 79450/89712 sentiment (88.56%)
# ➡️ Đã tính 79500/89712 sentiment (88.62%)
# ➡️ Đã tính 79550/89712 sentiment (88.67%)
# ➡️ Đã tính 79600/89712 sentiment (88.73%)
# ➡️ Đã tính 79650/89712 sentiment (88.78%)
# ➡️ Đã tính 79700/89712 sentiment (88.84%)
# ➡️ Đã tính 79750/89712 sentiment (88.90%)
# ➡️ Đã tính 79800/89712 sentiment (88.95%)
# ➡️ Đã tính 79850/89712 sentiment (89.01%)
# ➡️ Đã tính 79900/89712 sentiment (89.06%)
# ➡️ Đã tính 79950/89712 sentiment (89.12%)
# ➡️ Đã tính 80000/89712 sentiment (89.17%)
# ➡️ Đã tính 80050/89712 sentiment (89.23%)
# ➡️ Đã tính 80100/89712 sentiment (89.29%)
# ➡️ Đã tính 80150/89712 sentiment (89.34%)
# ➡️ Đã tính 80200/89712 sentiment (89.40%)
# ➡️ Đã tính 80250/89712 sentiment (89.45%)
# ➡️ Đã tính 80300/89712 sentiment (89.51%)
# ➡️ Đã tính 80350/89712 sentiment (89.56%)
# ➡️ Đã tính 80400/89712 sentiment (89.62%)
# ➡️ Đã tính 80450/89712 sentiment (89.68%)
# ➡️ Đã tính 80500/89712 sentiment (89.73%)
# ➡️ Đã tính 80550/89712 sentiment (89.79%)
# ➡️ Đã tính 80600/89712 sentiment (89.84%)
# ➡️ Đã tính 80650/89712 sentiment (89.90%)
# ➡️ Đã tính 80700/89712 sentiment (89.95%)
# ➡️ Đã tính 80750/89712 sentiment (90.01%)
# ➡️ Đã tính 80800/89712 sentiment (90.07%)
# ➡️ Đã tính 80850/89712 sentiment (90.12%)
# ➡️ Đã tính 80900/89712 sentiment (90.18%)
# ➡️ Đã tính 80950/89712 sentiment (90.23%)
# ➡️ Đã tính 81000/89712 sentiment (90.29%)
# ➡️ Đã tính 81050/89712 sentiment (90.34%)
# ➡️ Đã tính 81100/89712 sentiment (90.40%)
# ➡️ Đã tính 81150/89712 sentiment (90.46%)
# ➡️ Đã tính 81200/89712 sentiment (90.51%)
# ➡️ Đã tính 81250/89712 sentiment (90.57%)
# ➡️ Đã tính 81300/89712 sentiment (90.62%)
# ➡️ Đã tính 81350/89712 sentiment (90.68%)
# ➡️ Đã tính 81400/89712 sentiment (90.73%)
# ➡️ Đã tính 81450/89712 sentiment (90.79%)
# ➡️ Đã tính 81500/89712 sentiment (90.85%)
# ➡️ Đã tính 81550/89712 sentiment (90.90%)
# ➡️ Đã tính 81600/89712 sentiment (90.96%)
# ➡️ Đã tính 81650/89712 sentiment (91.01%)
# ➡️ Đã tính 81700/89712 sentiment (91.07%)
# ➡️ Đã tính 81750/89712 sentiment (91.12%)
# ➡️ Đã tính 81800/89712 sentiment (91.18%)
# ➡️ Đã tính 81850/89712 sentiment (91.24%)
# ➡️ Đã tính 81900/89712 sentiment (91.29%)
# ➡️ Đã tính 81950/89712 sentiment (91.35%)
# ➡️ Đã tính 82000/89712 sentiment (91.40%)
# ➡️ Đã tính 82050/89712 sentiment (91.46%)
# ➡️ Đã tính 82100/89712 sentiment (91.52%)
# ➡️ Đã tính 82150/89712 sentiment (91.57%)
# ➡️ Đã tính 82200/89712 sentiment (91.63%)
# ➡️ Đã tính 82250/89712 sentiment (91.68%)
# ➡️ Đã tính 82300/89712 sentiment (91.74%)
# ➡️ Đã tính 82350/89712 sentiment (91.79%)
# ➡️ Đã tính 82400/89712 sentiment (91.85%)
# ➡️ Đã tính 82450/89712 sentiment (91.91%)
# ➡️ Đã tính 82500/89712 sentiment (91.96%)
# ➡️ Đã tính 82550/89712 sentiment (92.02%)
# ➡️ Đã tính 82600/89712 sentiment (92.07%)
# ➡️ Đã tính 82650/89712 sentiment (92.13%)
# ➡️ Đã tính 82700/89712 sentiment (92.18%)
# ➡️ Đã tính 82750/89712 sentiment (92.24%)
# ➡️ Đã tính 82800/89712 sentiment (92.30%)
# ➡️ Đã tính 82850/89712 sentiment (92.35%)
# ➡️ Đã tính 82900/89712 sentiment (92.41%)
# ➡️ Đã tính 82950/89712 sentiment (92.46%)
# ➡️ Đã tính 83000/89712 sentiment (92.52%)
# ➡️ Đã tính 83050/89712 sentiment (92.57%)
# ➡️ Đã tính 83100/89712 sentiment (92.63%)
# ➡️ Đã tính 83150/89712 sentiment (92.69%)
# ➡️ Đã tính 83200/89712 sentiment (92.74%)
# ➡️ Đã tính 83250/89712 sentiment (92.80%)
# ➡️ Đã tính 83300/89712 sentiment (92.85%)
# ➡️ Đã tính 83350/89712 sentiment (92.91%)
# ➡️ Đã tính 83400/89712 sentiment (92.96%)
# ➡️ Đã tính 83450/89712 sentiment (93.02%)
# ➡️ Đã tính 83500/89712 sentiment (93.08%)
# ➡️ Đã tính 83550/89712 sentiment (93.13%)
# ➡️ Đã tính 83600/89712 sentiment (93.19%)
# ➡️ Đã tính 83650/89712 sentiment (93.24%)
# ➡️ Đã tính 83700/89712 sentiment (93.30%)
# ➡️ Đã tính 83750/89712 sentiment (93.35%)
# ➡️ Đã tính 83800/89712 sentiment (93.41%)
# ➡️ Đã tính 83850/89712 sentiment (93.47%)
# ➡️ Đã tính 83900/89712 sentiment (93.52%)
# ➡️ Đã tính 83950/89712 sentiment (93.58%)
# ➡️ Đã tính 84000/89712 sentiment (93.63%)
# ➡️ Đã tính 84050/89712 sentiment (93.69%)
# ➡️ Đã tính 84100/89712 sentiment (93.74%)
# ➡️ Đã tính 84150/89712 sentiment (93.80%)
# ➡️ Đã tính 84200/89712 sentiment (93.86%)
# ➡️ Đã tính 84250/89712 sentiment (93.91%)
# ➡️ Đã tính 84300/89712 sentiment (93.97%)
# ➡️ Đã tính 84350/89712 sentiment (94.02%)
# ➡️ Đã tính 84400/89712 sentiment (94.08%)
# ➡️ Đã tính 84450/89712 sentiment (94.13%)
# ➡️ Đã tính 84500/89712 sentiment (94.19%)
# ➡️ Đã tính 84550/89712 sentiment (94.25%)
# ➡️ Đã tính 84600/89712 sentiment (94.30%)
# ➡️ Đã tính 84650/89712 sentiment (94.36%)
# ➡️ Đã tính 84700/89712 sentiment (94.41%)
# ➡️ Đã tính 84750/89712 sentiment (94.47%)
# ➡️ Đã tính 84800/89712 sentiment (94.52%)
# ➡️ Đã tính 84850/89712 sentiment (94.58%)
# ➡️ Đã tính 84900/89712 sentiment (94.64%)
# ➡️ Đã tính 84950/89712 sentiment (94.69%)
# ➡️ Đã tính 85000/89712 sentiment (94.75%)
# ➡️ Đã tính 85050/89712 sentiment (94.80%)
# ➡️ Đã tính 85100/89712 sentiment (94.86%)
# ➡️ Đã tính 85150/89712 sentiment (94.91%)
# ➡️ Đã tính 85200/89712 sentiment (94.97%)
# ➡️ Đã tính 85250/89712 sentiment (95.03%)
# ➡️ Đã tính 85300/89712 sentiment (95.08%)
# ➡️ Đã tính 85350/89712 sentiment (95.14%)
# ➡️ Đã tính 85400/89712 sentiment (95.19%)
# ➡️ Đã tính 85450/89712 sentiment (95.25%)
# ➡️ Đã tính 85500/89712 sentiment (95.30%)
# ➡️ Đã tính 85550/89712 sentiment (95.36%)
# ➡️ Đã tính 85600/89712 sentiment (95.42%)
# ➡️ Đã tính 85650/89712 sentiment (95.47%)
# ➡️ Đã tính 85700/89712 sentiment (95.53%)
# ➡️ Đã tính 85750/89712 sentiment (95.58%)
# ➡️ Đã tính 85800/89712 sentiment (95.64%)
# ➡️ Đã tính 85850/89712 sentiment (95.70%)
# ➡️ Đã tính 85900/89712 sentiment (95.75%)
# ➡️ Đã tính 85950/89712 sentiment (95.81%)
# ➡️ Đã tính 86000/89712 sentiment (95.86%)
# ➡️ Đã tính 86050/89712 sentiment (95.92%)
# ➡️ Đã tính 86100/89712 sentiment (95.97%)
# ➡️ Đã tính 86150/89712 sentiment (96.03%)
# ➡️ Đã tính 86200/89712 sentiment (96.09%)
# ➡️ Đã tính 86250/89712 sentiment (96.14%)
# ➡️ Đã tính 86300/89712 sentiment (96.20%)
# ➡️ Đã tính 86350/89712 sentiment (96.25%)
# ➡️ Đã tính 86400/89712 sentiment (96.31%)
# ➡️ Đã tính 86450/89712 sentiment (96.36%)
# ➡️ Đã tính 86500/89712 sentiment (96.42%)
# ➡️ Đã tính 86550/89712 sentiment (96.48%)
# ➡️ Đã tính 86600/89712 sentiment (96.53%)
# ➡️ Đã tính 86650/89712 sentiment (96.59%)
# ➡️ Đã tính 86700/89712 sentiment (96.64%)
# ➡️ Đã tính 86750/89712 sentiment (96.70%)
# ➡️ Đã tính 86800/89712 sentiment (96.75%)
# ➡️ Đã tính 86850/89712 sentiment (96.81%)
# ➡️ Đã tính 86900/89712 sentiment (96.87%)
# ➡️ Đã tính 86950/89712 sentiment (96.92%)
# ➡️ Đã tính 87000/89712 sentiment (96.98%)
# ➡️ Đã tính 87050/89712 sentiment (97.03%)
# ➡️ Đã tính 87100/89712 sentiment (97.09%)
# ➡️ Đã tính 87150/89712 sentiment (97.14%)
# ➡️ Đã tính 87200/89712 sentiment (97.20%)
# ➡️ Đã tính 87250/89712 sentiment (97.26%)
# ➡️ Đã tính 87300/89712 sentiment (97.31%)
# ➡️ Đã tính 87350/89712 sentiment (97.37%)
# ➡️ Đã tính 87400/89712 sentiment (97.42%)
# ➡️ Đã tính 87450/89712 sentiment (97.48%)
# ➡️ Đã tính 87500/89712 sentiment (97.53%)
# ➡️ Đã tính 87550/89712 sentiment (97.59%)
# ➡️ Đã tính 87600/89712 sentiment (97.65%)
# ➡️ Đã tính 87650/89712 sentiment (97.70%)
# ➡️ Đã tính 87700/89712 sentiment (97.76%)
# ➡️ Đã tính 87750/89712 sentiment (97.81%)
# ➡️ Đã tính 87800/89712 sentiment (97.87%)
# ➡️ Đã tính 87850/89712 sentiment (97.92%)
# ➡️ Đã tính 87900/89712 sentiment (97.98%)
# ➡️ Đã tính 87950/89712 sentiment (98.04%)
# ➡️ Đã tính 88000/89712 sentiment (98.09%)
# ➡️ Đã tính 88050/89712 sentiment (98.15%)
# ➡️ Đã tính 88100/89712 sentiment (98.20%)
# ➡️ Đã tính 88150/89712 sentiment (98.26%)
# ➡️ Đã tính 88200/89712 sentiment (98.31%)
# ➡️ Đã tính 88250/89712 sentiment (98.37%)
# ➡️ Đã tính 88300/89712 sentiment (98.43%)
# ➡️ Đã tính 88350/89712 sentiment (98.48%)
# ➡️ Đã tính 88400/89712 sentiment (98.54%)
# ➡️ Đã tính 88450/89712 sentiment (98.59%)
# ➡️ Đã tính 88500/89712 sentiment (98.65%)
# ➡️ Đã tính 88550/89712 sentiment (98.70%)
# ➡️ Đã tính 88600/89712 sentiment (98.76%)
# ➡️ Đã tính 88650/89712 sentiment (98.82%)
# ➡️ Đã tính 88700/89712 sentiment (98.87%)
# ➡️ Đã tính 88750/89712 sentiment (98.93%)
# ➡️ Đã tính 88800/89712 sentiment (98.98%)
# ➡️ Đã tính 88850/89712 sentiment (99.04%)
# ➡️ Đã tính 88900/89712 sentiment (99.09%)
# ➡️ Đã tính 88950/89712 sentiment (99.15%)
# ➡️ Đã tính 89000/89712 sentiment (99.21%)
# ➡️ Đã tính 89050/89712 sentiment (99.26%)
# ➡️ Đã tính 89100/89712 sentiment (99.32%)
# ➡️ Đã tính 89150/89712 sentiment (99.37%)
# ➡️ Đã tính 89200/89712 sentiment (99.43%)
# ➡️ Đã tính 89250/89712 sentiment (99.49%)
# ➡️ Đã tính 89300/89712 sentiment (99.54%)
# ➡️ Đã tính 89350/89712 sentiment (99.60%)
# ➡️ Đã tính 89400/89712 sentiment (99.65%)
# ➡️ Đã tính 89450/89712 sentiment (99.71%)
# ➡️ Đã tính 89500/89712 sentiment (99.76%)
# ➡️ Đã tính 89550/89712 sentiment (99.82%)
# ➡️ Đã tính 89600/89712 sentiment (99.88%)
# ➡️ Đã tính 89650/89712 sentiment (99.93%)
# ➡️ Đã tính 89700/89712 sentiment (99.99%)
# ➡️ Đã tính 89712/89712 sentiment (100.00%)

# %%
# --- Các đặc trưng cấu trúc văn bản ---
print("🔢 Đang tạo các đặc trưng thống kê từ văn bản...")
char_count = []
word_count = []
capital_ratio = []
punctuation_ratio = []

for i, text in enumerate(tqdm(df['clean_text'].tolist(), desc="🔤 Stats", unit="text")):
    char_count.append(len(text))
    word_count.append(len(text.split()))
    capital_ratio.append(sum(1 for c in text if c.isupper()) / len(text) if len(text) > 0 else 0)
    punctuation_ratio.append(sum(1 for c in text if c in '!?') / len(text) if len(text) > 0 else 0)
    if (i + 1) % 50 == 0 or (i + 1) == len(df):
        percent = (i + 1) * 100 / len(df)
        print(f"➡️ Đã xử lý {i + 1}/{len(df)} dòng ({percent:.2f}%)")

df['char_count'] = char_count
df['word_count'] = word_count
df['capital_ratio'] = capital_ratio
df['punctuation_ratio'] = punctuation_ratio
# Out:
# 🔢 Đang tạo các đặc trưng thống kê từ văn bản...
# 🔤 Stats:   0%|          | 0/89712 [00:00<?, ?text/s]
# ➡️ Đã xử lý 50/89712 dòng (0.06%)
# ➡️ Đã xử lý 100/89712 dòng (0.11%)
# ➡️ Đã xử lý 150/89712 dòng (0.17%)
# ➡️ Đã xử lý 200/89712 dòng (0.22%)
# ➡️ Đã xử lý 250/89712 dòng (0.28%)
# ➡️ Đã xử lý 300/89712 dòng (0.33%)
# ➡️ Đã xử lý 350/89712 dòng (0.39%)
# ➡️ Đã xử lý 400/89712 dòng (0.45%)
# ➡️ Đã xử lý 450/89712 dòng (0.50%)
# ➡️ Đã xử lý 500/89712 dòng (0.56%)
# ➡️ Đã xử lý 550/89712 dòng (0.61%)
# ➡️ Đã xử lý 600/89712 dòng (0.67%)
# ➡️ Đã xử lý 650/89712 dòng (0.72%)
# ➡️ Đã xử lý 700/89712 dòng (0.78%)
# ➡️ Đã xử lý 750/89712 dòng (0.84%)
# ➡️ Đã xử lý 800/89712 dòng (0.89%)
# ➡️ Đã xử lý 850/89712 dòng (0.95%)
# ➡️ Đã xử lý 900/89712 dòng (1.00%)
# ➡️ Đã xử lý 950/89712 dòng (1.06%)
# ➡️ Đã xử lý 1000/89712 dòng (1.11%)
# ➡️ Đã xử lý 1050/89712 dòng (1.17%)
# ➡️ Đã xử lý 1100/89712 dòng (1.23%)
# ➡️ Đã xử lý 1150/89712 dòng (1.28%)
# ➡️ Đã xử lý 1200/89712 dòng (1.34%)
# ➡️ Đã xử lý 1250/89712 dòng (1.39%)
# ➡️ Đã xử lý 1300/89712 dòng (1.45%)
# ➡️ Đã xử lý 1350/89712 dòng (1.50%)
# ➡️ Đã xử lý 1400/89712 dòng (1.56%)
# ➡️ Đã xử lý 1450/89712 dòng (1.62%)
# ➡️ Đã xử lý 1500/89712 dòng (1.67%)
# ➡️ Đã xử lý 1550/89712 dòng (1.73%)
# ➡️ Đã xử lý 1600/89712 dòng (1.78%)
# ➡️ Đã xử lý 1650/89712 dòng (1.84%)
# ➡️ Đã xử lý 1700/89712 dòng (1.89%)
# ➡️ Đã xử lý 1750/89712 dòng (1.95%)
# ➡️ Đã xử lý 1800/89712 dòng (2.01%)
# ➡️ Đã xử lý 1850/89712 dòng (2.06%)
# ➡️ Đã xử lý 1900/89712 dòng (2.12%)
# ➡️ Đã xử lý 1950/89712 dòng (2.17%)
# ➡️ Đã xử lý 2000/89712 dòng (2.23%)
# ➡️ Đã xử lý 2050/89712 dòng (2.29%)
# ➡️ Đã xử lý 2100/89712 dòng (2.34%)
# ➡️ Đã xử lý 2150/89712 dòng (2.40%)
# ➡️ Đã xử lý 2200/89712 dòng (2.45%)
# ➡️ Đã xử lý 2250/89712 dòng (2.51%)
# ➡️ Đã xử lý 2300/89712 dòng (2.56%)
# ➡️ Đã xử lý 2350/89712 dòng (2.62%)
# ➡️ Đã xử lý 2400/89712 dòng (2.68%)
# ➡️ Đã xử lý 2450/89712 dòng (2.73%)
# ➡️ Đã xử lý 2500/89712 dòng (2.79%)
# ➡️ Đã xử lý 2550/89712 dòng (2.84%)
# ➡️ Đã xử lý 2600/89712 dòng (2.90%)
# ➡️ Đã xử lý 2650/89712 dòng (2.95%)
# ➡️ Đã xử lý 2700/89712 dòng (3.01%)
# ➡️ Đã xử lý 2750/89712 dòng (3.07%)
# ➡️ Đã xử lý 2800/89712 dòng (3.12%)
# ➡️ Đã xử lý 2850/89712 dòng (3.18%)
# ➡️ Đã xử lý 2900/89712 dòng (3.23%)
# ➡️ Đã xử lý 2950/89712 dòng (3.29%)
# ➡️ Đã xử lý 3000/89712 dòng (3.34%)
# ➡️ Đã xử lý 3050/89712 dòng (3.40%)
# ➡️ Đã xử lý 3100/89712 dòng (3.46%)
# ➡️ Đã xử lý 3150/89712 dòng (3.51%)
# ➡️ Đã xử lý 3200/89712 dòng (3.57%)
# ➡️ Đã xử lý 3250/89712 dòng (3.62%)
# ➡️ Đã xử lý 3300/89712 dòng (3.68%)
# ➡️ Đã xử lý 3350/89712 dòng (3.73%)
# ➡️ Đã xử lý 3400/89712 dòng (3.79%)
# ➡️ Đã xử lý 3450/89712 dòng (3.85%)
# ➡️ Đã xử lý 3500/89712 dòng (3.90%)
# ➡️ Đã xử lý 3550/89712 dòng (3.96%)
# ➡️ Đã xử lý 3600/89712 dòng (4.01%)
# ➡️ Đã xử lý 3650/89712 dòng (4.07%)
# ➡️ Đã xử lý 3700/89712 dòng (4.12%)
# ➡️ Đã xử lý 3750/89712 dòng (4.18%)
# ➡️ Đã xử lý 3800/89712 dòng (4.24%)
# ➡️ Đã xử lý 3850/89712 dòng (4.29%)
# ➡️ Đã xử lý 3900/89712 dòng (4.35%)
# ➡️ Đã xử lý 3950/89712 dòng (4.40%)
# ➡️ Đã xử lý 4000/89712 dòng (4.46%)
# ➡️ Đã xử lý 4050/89712 dòng (4.51%)
# ➡️ Đã xử lý 4100/89712 dòng (4.57%)
# ➡️ Đã xử lý 4150/89712 dòng (4.63%)
# ➡️ Đã xử lý 4200/89712 dòng (4.68%)
# ➡️ Đã xử lý 4250/89712 dòng (4.74%)
# ➡️ Đã xử lý 4300/89712 dòng (4.79%)
# ➡️ Đã xử lý 4350/89712 dòng (4.85%)
# ➡️ Đã xử lý 4400/89712 dòng (4.90%)
# ➡️ Đã xử lý 4450/89712 dòng (4.96%)
# ➡️ Đã xử lý 4500/89712 dòng (5.02%)
# ➡️ Đã xử lý 4550/89712 dòng (5.07%)
# ➡️ Đã xử lý 4600/89712 dòng (5.13%)
# ➡️ Đã xử lý 4650/89712 dòng (5.18%)
# ➡️ Đã xử lý 4700/89712 dòng (5.24%)
# ➡️ Đã xử lý 4750/89712 dòng (5.29%)
# ➡️ Đã xử lý 4800/89712 dòng (5.35%)
# ➡️ Đã xử lý 4850/89712 dòng (5.41%)
# ➡️ Đã xử lý 4900/89712 dòng (5.46%)
# ➡️ Đã xử lý 4950/89712 dòng (5.52%)
# ➡️ Đã xử lý 5000/89712 dòng (5.57%)
# ➡️ Đã xử lý 5050/89712 dòng (5.63%)
# ➡️ Đã xử lý 5100/89712 dòng (5.68%)
# ➡️ Đã xử lý 5150/89712 dòng (5.74%)
# ➡️ Đã xử lý 5200/89712 dòng (5.80%)
# ➡️ Đã xử lý 5250/89712 dòng (5.85%)
# ➡️ Đã xử lý 5300/89712 dòng (5.91%)
# ➡️ Đã xử lý 5350/89712 dòng (5.96%)
# ➡️ Đã xử lý 5400/89712 dòng (6.02%)
# ➡️ Đã xử lý 5450/89712 dòng (6.07%)
# ➡️ Đã xử lý 5500/89712 dòng (6.13%)
# ➡️ Đã xử lý 5550/89712 dòng (6.19%)
# ➡️ Đã xử lý 5600/89712 dòng (6.24%)
# ➡️ Đã xử lý 5650/89712 dòng (6.30%)
# ➡️ Đã xử lý 5700/89712 dòng (6.35%)
# ➡️ Đã xử lý 5750/89712 dòng (6.41%)
# ➡️ Đã xử lý 5800/89712 dòng (6.47%)
# ➡️ Đã xử lý 5850/89712 dòng (6.52%)
# ➡️ Đã xử lý 5900/89712 dòng (6.58%)
# ➡️ Đã xử lý 5950/89712 dòng (6.63%)
# ➡️ Đã xử lý 6000/89712 dòng (6.69%)
# ➡️ Đã xử lý 6050/89712 dòng (6.74%)
# ➡️ Đã xử lý 6100/89712 dòng (6.80%)
# ➡️ Đã xử lý 6150/89712 dòng (6.86%)
# ➡️ Đã xử lý 6200/89712 dòng (6.91%)
# ➡️ Đã xử lý 6250/89712 dòng (6.97%)
# ➡️ Đã xử lý 6300/89712 dòng (7.02%)
# ➡️ Đã xử lý 6350/89712 dòng (7.08%)
# ➡️ Đã xử lý 6400/89712 dòng (7.13%)
# ➡️ Đã xử lý 6450/89712 dòng (7.19%)
# ➡️ Đã xử lý 6500/89712 dòng (7.25%)
# ➡️ Đã xử lý 6550/89712 dòng (7.30%)
# ➡️ Đã xử lý 6600/89712 dòng (7.36%)
# ➡️ Đã xử lý 6650/89712 dòng (7.41%)
# ➡️ Đã xử lý 6700/89712 dòng (7.47%)
# ➡️ Đã xử lý 6750/89712 dòng (7.52%)
# ➡️ Đã xử lý 6800/89712 dòng (7.58%)
# ➡️ Đã xử lý 6850/89712 dòng (7.64%)
# ➡️ Đã xử lý 6900/89712 dòng (7.69%)
# ➡️ Đã xử lý 6950/89712 dòng (7.75%)
# ➡️ Đã xử lý 7000/89712 dòng (7.80%)
# ➡️ Đã xử lý 7050/89712 dòng (7.86%)
# ➡️ Đã xử lý 7100/89712 dòng (7.91%)
# ➡️ Đã xử lý 7150/89712 dòng (7.97%)
# ➡️ Đã xử lý 7200/89712 dòng (8.03%)
# ➡️ Đã xử lý 7250/89712 dòng (8.08%)
# ➡️ Đã xử lý 7300/89712 dòng (8.14%)
# ➡️ Đã xử lý 7350/89712 dòng (8.19%)
# ➡️ Đã xử lý 7400/89712 dòng (8.25%)
# ➡️ Đã xử lý 7450/89712 dòng (8.30%)
# ➡️ Đã xử lý 7500/89712 dòng (8.36%)
# ➡️ Đã xử lý 7550/89712 dòng (8.42%)
# ➡️ Đã xử lý 7600/89712 dòng (8.47%)
# ➡️ Đã xử lý 7650/89712 dòng (8.53%)
# ➡️ Đã xử lý 7700/89712 dòng (8.58%)
# ➡️ Đã xử lý 7750/89712 dòng (8.64%)
# ➡️ Đã xử lý 7800/89712 dòng (8.69%)
# ➡️ Đã xử lý 7850/89712 dòng (8.75%)
# ➡️ Đã xử lý 7900/89712 dòng (8.81%)
# ➡️ Đã xử lý 7950/89712 dòng (8.86%)
# ➡️ Đã xử lý 8000/89712 dòng (8.92%)
# ➡️ Đã xử lý 8050/89712 dòng (8.97%)
# ➡️ Đã xử lý 8100/89712 dòng (9.03%)
# ➡️ Đã xử lý 8150/89712 dòng (9.08%)
# ➡️ Đã xử lý 8200/89712 dòng (9.14%)
# ➡️ Đã xử lý 8250/89712 dòng (9.20%)
# ➡️ Đã xử lý 8300/89712 dòng (9.25%)
# ➡️ Đã xử lý 8350/89712 dòng (9.31%)
# ➡️ Đã xử lý 8400/89712 dòng (9.36%)
# ➡️ Đã xử lý 8450/89712 dòng (9.42%)
# ➡️ Đã xử lý 8500/89712 dòng (9.47%)
# ➡️ Đã xử lý 8550/89712 dòng (9.53%)
# ➡️ Đã xử lý 8600/89712 dòng (9.59%)
# ➡️ Đã xử lý 8650/89712 dòng (9.64%)
# ➡️ Đã xử lý 8700/89712 dòng (9.70%)
# ➡️ Đã xử lý 8750/89712 dòng (9.75%)
# ➡️ Đã xử lý 8800/89712 dòng (9.81%)
# ➡️ Đã xử lý 8850/89712 dòng (9.86%)
# ➡️ Đã xử lý 8900/89712 dòng (9.92%)
# ➡️ Đã xử lý 8950/89712 dòng (9.98%)
# ➡️ Đã xử lý 9000/89712 dòng (10.03%)
# ➡️ Đã xử lý 9050/89712 dòng (10.09%)
# ➡️ Đã xử lý 9100/89712 dòng (10.14%)
# ➡️ Đã xử lý 9150/89712 dòng (10.20%)
# ➡️ Đã xử lý 9200/89712 dòng (10.26%)
# ➡️ Đã xử lý 9250/89712 dòng (10.31%)
# ➡️ Đã xử lý 9300/89712 dòng (10.37%)
# ➡️ Đã xử lý 9350/89712 dòng (10.42%)
# ➡️ Đã xử lý 9400/89712 dòng (10.48%)
# ➡️ Đã xử lý 9450/89712 dòng (10.53%)
# ➡️ Đã xử lý 9500/89712 dòng (10.59%)
# ➡️ Đã xử lý 9550/89712 dòng (10.65%)
# ➡️ Đã xử lý 9600/89712 dòng (10.70%)
# ➡️ Đã xử lý 9650/89712 dòng (10.76%)
# ➡️ Đã xử lý 9700/89712 dòng (10.81%)
# ➡️ Đã xử lý 9750/89712 dòng (10.87%)
# ➡️ Đã xử lý 9800/89712 dòng (10.92%)
# ➡️ Đã xử lý 9850/89712 dòng (10.98%)
# ➡️ Đã xử lý 9900/89712 dòng (11.04%)
# ➡️ Đã xử lý 9950/89712 dòng (11.09%)
# ➡️ Đã xử lý 10000/89712 dòng (11.15%)
# ➡️ Đã xử lý 10050/89712 dòng (11.20%)
# ➡️ Đã xử lý 10100/89712 dòng (11.26%)
# ➡️ Đã xử lý 10150/89712 dòng (11.31%)
# ➡️ Đã xử lý 10200/89712 dòng (11.37%)
# ➡️ Đã xử lý 10250/89712 dòng (11.43%)
# ➡️ Đã xử lý 10300/89712 dòng (11.48%)
# ➡️ Đã xử lý 10350/89712 dòng (11.54%)
# ➡️ Đã xử lý 10400/89712 dòng (11.59%)
# ➡️ Đã xử lý 10450/89712 dòng (11.65%)
# ➡️ Đã xử lý 10500/89712 dòng (11.70%)
# ➡️ Đã xử lý 10550/89712 dòng (11.76%)
# ➡️ Đã xử lý 10600/89712 dòng (11.82%)
# ➡️ Đã xử lý 10650/89712 dòng (11.87%)
# ➡️ Đã xử lý 10700/89712 dòng (11.93%)
# ➡️ Đã xử lý 10750/89712 dòng (11.98%)
# ➡️ Đã xử lý 10800/89712 dòng (12.04%)
# ➡️ Đã xử lý 10850/89712 dòng (12.09%)
# ➡️ Đã xử lý 10900/89712 dòng (12.15%)
# ➡️ Đã xử lý 10950/89712 dòng (12.21%)
# ➡️ Đã xử lý 11000/89712 dòng (12.26%)
# ➡️ Đã xử lý 11050/89712 dòng (12.32%)
# ➡️ Đã xử lý 11100/89712 dòng (12.37%)
# ➡️ Đã xử lý 11150/89712 dòng (12.43%)
# ➡️ Đã xử lý 11200/89712 dòng (12.48%)
# ➡️ Đã xử lý 11250/89712 dòng (12.54%)
# ➡️ Đã xử lý 11300/89712 dòng (12.60%)
# ➡️ Đã xử lý 11350/89712 dòng (12.65%)
# ➡️ Đã xử lý 11400/89712 dòng (12.71%)
# ➡️ Đã xử lý 11450/89712 dòng (12.76%)
# ➡️ Đã xử lý 11500/89712 dòng (12.82%)
# ➡️ Đã xử lý 11550/89712 dòng (12.87%)
# ➡️ Đã xử lý 11600/89712 dòng (12.93%)
# ➡️ Đã xử lý 11650/89712 dòng (12.99%)
# ➡️ Đã xử lý 11700/89712 dòng (13.04%)
# ➡️ Đã xử lý 11750/89712 dòng (13.10%)
# ➡️ Đã xử lý 11800/89712 dòng (13.15%)
# ➡️ Đã xử lý 11850/89712 dòng (13.21%)
# ➡️ Đã xử lý 11900/89712 dòng (13.26%)
# ➡️ Đã xử lý 11950/89712 dòng (13.32%)
# ➡️ Đã xử lý 12000/89712 dòng (13.38%)
# ➡️ Đã xử lý 12050/89712 dòng (13.43%)
# ➡️ Đã xử lý 12100/89712 dòng (13.49%)
# ➡️ Đã xử lý 12150/89712 dòng (13.54%)
# ➡️ Đã xử lý 12200/89712 dòng (13.60%)
# ➡️ Đã xử lý 12250/89712 dòng (13.65%)
# ➡️ Đã xử lý 12300/89712 dòng (13.71%)
# ➡️ Đã xử lý 12350/89712 dòng (13.77%)
# ➡️ Đã xử lý 12400/89712 dòng (13.82%)
# ➡️ Đã xử lý 12450/89712 dòng (13.88%)
# ➡️ Đã xử lý 12500/89712 dòng (13.93%)
# ➡️ Đã xử lý 12550/89712 dòng (13.99%)
# ➡️ Đã xử lý 12600/89712 dòng (14.04%)
# ➡️ Đã xử lý 12650/89712 dòng (14.10%)
# ➡️ Đã xử lý 12700/89712 dòng (14.16%)
# ➡️ Đã xử lý 12750/89712 dòng (14.21%)
# ➡️ Đã xử lý 12800/89712 dòng (14.27%)
# ➡️ Đã xử lý 12850/89712 dòng (14.32%)
# ➡️ Đã xử lý 12900/89712 dòng (14.38%)
# ➡️ Đã xử lý 12950/89712 dòng (14.44%)
# ➡️ Đã xử lý 13000/89712 dòng (14.49%)
# ➡️ Đã xử lý 13050/89712 dòng (14.55%)
# ➡️ Đã xử lý 13100/89712 dòng (14.60%)
# ➡️ Đã xử lý 13150/89712 dòng (14.66%)
# ➡️ Đã xử lý 13200/89712 dòng (14.71%)
# ➡️ Đã xử lý 13250/89712 dòng (14.77%)
# ➡️ Đã xử lý 13300/89712 dòng (14.83%)
# ➡️ Đã xử lý 13350/89712 dòng (14.88%)
# ➡️ Đã xử lý 13400/89712 dòng (14.94%)
# ➡️ Đã xử lý 13450/89712 dòng (14.99%)
# ➡️ Đã xử lý 13500/89712 dòng (15.05%)
# ➡️ Đã xử lý 13550/89712 dòng (15.10%)
# ➡️ Đã xử lý 13600/89712 dòng (15.16%)
# ➡️ Đã xử lý 13650/89712 dòng (15.22%)
# ➡️ Đã xử lý 13700/89712 dòng (15.27%)
# ➡️ Đã xử lý 13750/89712 dòng (15.33%)
# ➡️ Đã xử lý 13800/89712 dòng (15.38%)
# ➡️ Đã xử lý 13850/89712 dòng (15.44%)
# ➡️ Đã xử lý 13900/89712 dòng (15.49%)
# ➡️ Đã xử lý 13950/89712 dòng (15.55%)
# ➡️ Đã xử lý 14000/89712 dòng (15.61%)
# ➡️ Đã xử lý 14050/89712 dòng (15.66%)
# ➡️ Đã xử lý 14100/89712 dòng (15.72%)
# ➡️ Đã xử lý 14150/89712 dòng (15.77%)
# ➡️ Đã xử lý 14200/89712 dòng (15.83%)
# ➡️ Đã xử lý 14250/89712 dòng (15.88%)
# ➡️ Đã xử lý 14300/89712 dòng (15.94%)
# ➡️ Đã xử lý 14350/89712 dòng (16.00%)
# ➡️ Đã xử lý 14400/89712 dòng (16.05%)
# ➡️ Đã xử lý 14450/89712 dòng (16.11%)
# ➡️ Đã xử lý 14500/89712 dòng (16.16%)
# ➡️ Đã xử lý 14550/89712 dòng (16.22%)
# ➡️ Đã xử lý 14600/89712 dòng (16.27%)
# ➡️ Đã xử lý 14650/89712 dòng (16.33%)
# ➡️ Đã xử lý 14700/89712 dòng (16.39%)
# ➡️ Đã xử lý 14750/89712 dòng (16.44%)
# ➡️ Đã xử lý 14800/89712 dòng (16.50%)
# ➡️ Đã xử lý 14850/89712 dòng (16.55%)
# ➡️ Đã xử lý 14900/89712 dòng (16.61%)
# ➡️ Đã xử lý 14950/89712 dòng (16.66%)
# ➡️ Đã xử lý 15000/89712 dòng (16.72%)
# ➡️ Đã xử lý 15050/89712 dòng (16.78%)
# ➡️ Đã xử lý 15100/89712 dòng (16.83%)
# ➡️ Đã xử lý 15150/89712 dòng (16.89%)
# ➡️ Đã xử lý 15200/89712 dòng (16.94%)
# ➡️ Đã xử lý 15250/89712 dòng (17.00%)
# ➡️ Đã xử lý 15300/89712 dòng (17.05%)
# ➡️ Đã xử lý 15350/89712 dòng (17.11%)
# ➡️ Đã xử lý 15400/89712 dòng (17.17%)
# ➡️ Đã xử lý 15450/89712 dòng (17.22%)
# ➡️ Đã xử lý 15500/89712 dòng (17.28%)
# ➡️ Đã xử lý 15550/89712 dòng (17.33%)
# ➡️ Đã xử lý 15600/89712 dòng (17.39%)
# ➡️ Đã xử lý 15650/89712 dòng (17.44%)
# ➡️ Đã xử lý 15700/89712 dòng (17.50%)
# ➡️ Đã xử lý 15750/89712 dòng (17.56%)
# ➡️ Đã xử lý 15800/89712 dòng (17.61%)
# ➡️ Đã xử lý 15850/89712 dòng (17.67%)
# ➡️ Đã xử lý 15900/89712 dòng (17.72%)
# ➡️ Đã xử lý 15950/89712 dòng (17.78%)
# ➡️ Đã xử lý 16000/89712 dòng (17.83%)
# ➡️ Đã xử lý 16050/89712 dòng (17.89%)
# ➡️ Đã xử lý 16100/89712 dòng (17.95%)
# ➡️ Đã xử lý 16150/89712 dòng (18.00%)
# ➡️ Đã xử lý 16200/89712 dòng (18.06%)
# ➡️ Đã xử lý 16250/89712 dòng (18.11%)
# ➡️ Đã xử lý 16300/89712 dòng (18.17%)
# ➡️ Đã xử lý 16350/89712 dòng (18.22%)
# ➡️ Đã xử lý 16400/89712 dòng (18.28%)
# ➡️ Đã xử lý 16450/89712 dòng (18.34%)
# ➡️ Đã xử lý 16500/89712 dòng (18.39%)
# ➡️ Đã xử lý 16550/89712 dòng (18.45%)
# ➡️ Đã xử lý 16600/89712 dòng (18.50%)
# ➡️ Đã xử lý 16650/89712 dòng (18.56%)
# ➡️ Đã xử lý 16700/89712 dòng (18.62%)
# ➡️ Đã xử lý 16750/89712 dòng (18.67%)
# ➡️ Đã xử lý 16800/89712 dòng (18.73%)
# ➡️ Đã xử lý 16850/89712 dòng (18.78%)
# ➡️ Đã xử lý 16900/89712 dòng (18.84%)
# ➡️ Đã xử lý 16950/89712 dòng (18.89%)
# ➡️ Đã xử lý 17000/89712 dòng (18.95%)
# ➡️ Đã xử lý 17050/89712 dòng (19.01%)
# ➡️ Đã xử lý 17100/89712 dòng (19.06%)
# ➡️ Đã xử lý 17150/89712 dòng (19.12%)
# ➡️ Đã xử lý 17200/89712 dòng (19.17%)
# ➡️ Đã xử lý 17250/89712 dòng (19.23%)
# ➡️ Đã xử lý 17300/89712 dòng (19.28%)
# ➡️ Đã xử lý 17350/89712 dòng (19.34%)
# ➡️ Đã xử lý 17400/89712 dòng (19.40%)
# ➡️ Đã xử lý 17450/89712 dòng (19.45%)
# ➡️ Đã xử lý 17500/89712 dòng (19.51%)
# ➡️ Đã xử lý 17550/89712 dòng (19.56%)
# ➡️ Đã xử lý 17600/89712 dòng (19.62%)
# ➡️ Đã xử lý 17650/89712 dòng (19.67%)
# ➡️ Đã xử lý 17700/89712 dòng (19.73%)
# ➡️ Đã xử lý 17750/89712 dòng (19.79%)
# ➡️ Đã xử lý 17800/89712 dòng (19.84%)
# ➡️ Đã xử lý 17850/89712 dòng (19.90%)
# ➡️ Đã xử lý 17900/89712 dòng (19.95%)
# ➡️ Đã xử lý 17950/89712 dòng (20.01%)
# ➡️ Đã xử lý 18000/89712 dòng (20.06%)
# ➡️ Đã xử lý 18050/89712 dòng (20.12%)
# ➡️ Đã xử lý 18100/89712 dòng (20.18%)
# ➡️ Đã xử lý 18150/89712 dòng (20.23%)
# ➡️ Đã xử lý 18200/89712 dòng (20.29%)
# ➡️ Đã xử lý 18250/89712 dòng (20.34%)
# ➡️ Đã xử lý 18300/89712 dòng (20.40%)
# ➡️ Đã xử lý 18350/89712 dòng (20.45%)
# ➡️ Đã xử lý 18400/89712 dòng (20.51%)
# ➡️ Đã xử lý 18450/89712 dòng (20.57%)
# ➡️ Đã xử lý 18500/89712 dòng (20.62%)
# ➡️ Đã xử lý 18550/89712 dòng (20.68%)
# ➡️ Đã xử lý 18600/89712 dòng (20.73%)
# ➡️ Đã xử lý 18650/89712 dòng (20.79%)
# ➡️ Đã xử lý 18700/89712 dòng (20.84%)
# ➡️ Đã xử lý 18750/89712 dòng (20.90%)
# ➡️ Đã xử lý 18800/89712 dòng (20.96%)
# ➡️ Đã xử lý 18850/89712 dòng (21.01%)
# ➡️ Đã xử lý 18900/89712 dòng (21.07%)
# ➡️ Đã xử lý 18950/89712 dòng (21.12%)
# ➡️ Đã xử lý 19000/89712 dòng (21.18%)
# ➡️ Đã xử lý 19050/89712 dòng (21.23%)
# ➡️ Đã xử lý 19100/89712 dòng (21.29%)
# ➡️ Đã xử lý 19150/89712 dòng (21.35%)
# ➡️ Đã xử lý 19200/89712 dòng (21.40%)
# ➡️ Đã xử lý 19250/89712 dòng (21.46%)
# ➡️ Đã xử lý 19300/89712 dòng (21.51%)
# ➡️ Đã xử lý 19350/89712 dòng (21.57%)
# ➡️ Đã xử lý 19400/89712 dòng (21.62%)
# ➡️ Đã xử lý 19450/89712 dòng (21.68%)
# ➡️ Đã xử lý 19500/89712 dòng (21.74%)
# ➡️ Đã xử lý 19550/89712 dòng (21.79%)
# ➡️ Đã xử lý 19600/89712 dòng (21.85%)
# ➡️ Đã xử lý 19650/89712 dòng (21.90%)
# ➡️ Đã xử lý 19700/89712 dòng (21.96%)
# ➡️ Đã xử lý 19750/89712 dòng (22.01%)
# ➡️ Đã xử lý 19800/89712 dòng (22.07%)
# ➡️ Đã xử lý 19850/89712 dòng (22.13%)
# ➡️ Đã xử lý 19900/89712 dòng (22.18%)
# ➡️ Đã xử lý 19950/89712 dòng (22.24%)
# ➡️ Đã xử lý 20000/89712 dòng (22.29%)
# ➡️ Đã xử lý 20050/89712 dòng (22.35%)
# ➡️ Đã xử lý 20100/89712 dòng (22.41%)
# ➡️ Đã xử lý 20150/89712 dòng (22.46%)
# ➡️ Đã xử lý 20200/89712 dòng (22.52%)
# ➡️ Đã xử lý 20250/89712 dòng (22.57%)
# ➡️ Đã xử lý 20300/89712 dòng (22.63%)
# ➡️ Đã xử lý 20350/89712 dòng (22.68%)
# ➡️ Đã xử lý 20400/89712 dòng (22.74%)
# ➡️ Đã xử lý 20450/89712 dòng (22.80%)
# ➡️ Đã xử lý 20500/89712 dòng (22.85%)
# ➡️ Đã xử lý 20550/89712 dòng (22.91%)
# ➡️ Đã xử lý 20600/89712 dòng (22.96%)
# ➡️ Đã xử lý 20650/89712 dòng (23.02%)
# ➡️ Đã xử lý 20700/89712 dòng (23.07%)
# ➡️ Đã xử lý 20750/89712 dòng (23.13%)
# ➡️ Đã xử lý 20800/89712 dòng (23.19%)
# ➡️ Đã xử lý 20850/89712 dòng (23.24%)
# ➡️ Đã xử lý 20900/89712 dòng (23.30%)
# ➡️ Đã xử lý 20950/89712 dòng (23.35%)
# ➡️ Đã xử lý 21000/89712 dòng (23.41%)
# ➡️ Đã xử lý 21050/89712 dòng (23.46%)
# ➡️ Đã xử lý 21100/89712 dòng (23.52%)
# ➡️ Đã xử lý 21150/89712 dòng (23.58%)
# ➡️ Đã xử lý 21200/89712 dòng (23.63%)
# ➡️ Đã xử lý 21250/89712 dòng (23.69%)
# ➡️ Đã xử lý 21300/89712 dòng (23.74%)
# ➡️ Đã xử lý 21350/89712 dòng (23.80%)
# ➡️ Đã xử lý 21400/89712 dòng (23.85%)
# ➡️ Đã xử lý 21450/89712 dòng (23.91%)
# ➡️ Đã xử lý 21500/89712 dòng (23.97%)
# ➡️ Đã xử lý 21550/89712 dòng (24.02%)
# ➡️ Đã xử lý 21600/89712 dòng (24.08%)
# ➡️ Đã xử lý 21650/89712 dòng (24.13%)
# ➡️ Đã xử lý 21700/89712 dòng (24.19%)
# ➡️ Đã xử lý 21750/89712 dòng (24.24%)
# ➡️ Đã xử lý 21800/89712 dòng (24.30%)
# ➡️ Đã xử lý 21850/89712 dòng (24.36%)
# ➡️ Đã xử lý 21900/89712 dòng (24.41%)
# ➡️ Đã xử lý 21950/89712 dòng (24.47%)
# ➡️ Đã xử lý 22000/89712 dòng (24.52%)
# ➡️ Đã xử lý 22050/89712 dòng (24.58%)
# ➡️ Đã xử lý 22100/89712 dòng (24.63%)
# ➡️ Đã xử lý 22150/89712 dòng (24.69%)
# ➡️ Đã xử lý 22200/89712 dòng (24.75%)
# ➡️ Đã xử lý 22250/89712 dòng (24.80%)
# ➡️ Đã xử lý 22300/89712 dòng (24.86%)
# ➡️ Đã xử lý 22350/89712 dòng (24.91%)
# ➡️ Đã xử lý 22400/89712 dòng (24.97%)
# ➡️ Đã xử lý 22450/89712 dòng (25.02%)
# ➡️ Đã xử lý 22500/89712 dòng (25.08%)
# ➡️ Đã xử lý 22550/89712 dòng (25.14%)
# ➡️ Đã xử lý 22600/89712 dòng (25.19%)
# ➡️ Đã xử lý 22650/89712 dòng (25.25%)
# ➡️ Đã xử lý 22700/89712 dòng (25.30%)
# ➡️ Đã xử lý 22750/89712 dòng (25.36%)
# ➡️ Đã xử lý 22800/89712 dòng (25.41%)
# ➡️ Đã xử lý 22850/89712 dòng (25.47%)
# ➡️ Đã xử lý 22900/89712 dòng (25.53%)
# ➡️ Đã xử lý 22950/89712 dòng (25.58%)
# ➡️ Đã xử lý 23000/89712 dòng (25.64%)
# ➡️ Đã xử lý 23050/89712 dòng (25.69%)
# ➡️ Đã xử lý 23100/89712 dòng (25.75%)
# ➡️ Đã xử lý 23150/89712 dòng (25.80%)
# ➡️ Đã xử lý 23200/89712 dòng (25.86%)
# ➡️ Đã xử lý 23250/89712 dòng (25.92%)
# ➡️ Đã xử lý 23300/89712 dòng (25.97%)
# ➡️ Đã xử lý 23350/89712 dòng (26.03%)
# ➡️ Đã xử lý 23400/89712 dòng (26.08%)
# ➡️ Đã xử lý 23450/89712 dòng (26.14%)
# ➡️ Đã xử lý 23500/89712 dòng (26.19%)
# ➡️ Đã xử lý 23550/89712 dòng (26.25%)
# ➡️ Đã xử lý 23600/89712 dòng (26.31%)
# ➡️ Đã xử lý 23650/89712 dòng (26.36%)
# ➡️ Đã xử lý 23700/89712 dòng (26.42%)
# ➡️ Đã xử lý 23750/89712 dòng (26.47%)
# ➡️ Đã xử lý 23800/89712 dòng (26.53%)
# ➡️ Đã xử lý 23850/89712 dòng (26.59%)
# ➡️ Đã xử lý 23900/89712 dòng (26.64%)
# ➡️ Đã xử lý 23950/89712 dòng (26.70%)
# ➡️ Đã xử lý 24000/89712 dòng (26.75%)
# ➡️ Đã xử lý 24050/89712 dòng (26.81%)
# ➡️ Đã xử lý 24100/89712 dòng (26.86%)
# ➡️ Đã xử lý 24150/89712 dòng (26.92%)
# ➡️ Đã xử lý 24200/89712 dòng (26.98%)
# ➡️ Đã xử lý 24250/89712 dòng (27.03%)
# ➡️ Đã xử lý 24300/89712 dòng (27.09%)
# ➡️ Đã xử lý 24350/89712 dòng (27.14%)
# ➡️ Đã xử lý 24400/89712 dòng (27.20%)
# ➡️ Đã xử lý 24450/89712 dòng (27.25%)
# ➡️ Đã xử lý 24500/89712 dòng (27.31%)
# ➡️ Đã xử lý 24550/89712 dòng (27.37%)
# ➡️ Đã xử lý 24600/89712 dòng (27.42%)
# ➡️ Đã xử lý 24650/89712 dòng (27.48%)
# ➡️ Đã xử lý 24700/89712 dòng (27.53%)
# ➡️ Đã xử lý 24750/89712 dòng (27.59%)
# ➡️ Đã xử lý 24800/89712 dòng (27.64%)
# ➡️ Đã xử lý 24850/89712 dòng (27.70%)
# ➡️ Đã xử lý 24900/89712 dòng (27.76%)
# ➡️ Đã xử lý 24950/89712 dòng (27.81%)
# ➡️ Đã xử lý 25000/89712 dòng (27.87%)
# ➡️ Đã xử lý 25050/89712 dòng (27.92%)
# ➡️ Đã xử lý 25100/89712 dòng (27.98%)
# ➡️ Đã xử lý 25150/89712 dòng (28.03%)
# ➡️ Đã xử lý 25200/89712 dòng (28.09%)
# ➡️ Đã xử lý 25250/89712 dòng (28.15%)
# ➡️ Đã xử lý 25300/89712 dòng (28.20%)
# ➡️ Đã xử lý 25350/89712 dòng (28.26%)
# ➡️ Đã xử lý 25400/89712 dòng (28.31%)
# ➡️ Đã xử lý 25450/89712 dòng (28.37%)
# ➡️ Đã xử lý 25500/89712 dòng (28.42%)
# ➡️ Đã xử lý 25550/89712 dòng (28.48%)
# ➡️ Đã xử lý 25600/89712 dòng (28.54%)
# ➡️ Đã xử lý 25650/89712 dòng (28.59%)
# ➡️ Đã xử lý 25700/89712 dòng (28.65%)
# ➡️ Đã xử lý 25750/89712 dòng (28.70%)
# ➡️ Đã xử lý 25800/89712 dòng (28.76%)
# ➡️ Đã xử lý 25850/89712 dòng (28.81%)
# ➡️ Đã xử lý 25900/89712 dòng (28.87%)
# ➡️ Đã xử lý 25950/89712 dòng (28.93%)
# ➡️ Đã xử lý 26000/89712 dòng (28.98%)
# ➡️ Đã xử lý 26050/89712 dòng (29.04%)
# ➡️ Đã xử lý 26100/89712 dòng (29.09%)
# ➡️ Đã xử lý 26150/89712 dòng (29.15%)
# ➡️ Đã xử lý 26200/89712 dòng (29.20%)
# ➡️ Đã xử lý 26250/89712 dòng (29.26%)
# ➡️ Đã xử lý 26300/89712 dòng (29.32%)
# ➡️ Đã xử lý 26350/89712 dòng (29.37%)
# ➡️ Đã xử lý 26400/89712 dòng (29.43%)
# ➡️ Đã xử lý 26450/89712 dòng (29.48%)
# ➡️ Đã xử lý 26500/89712 dòng (29.54%)
# ➡️ Đã xử lý 26550/89712 dòng (29.59%)
# ➡️ Đã xử lý 26600/89712 dòng (29.65%)
# ➡️ Đã xử lý 26650/89712 dòng (29.71%)
# ➡️ Đã xử lý 26700/89712 dòng (29.76%)
# ➡️ Đã xử lý 26750/89712 dòng (29.82%)
# ➡️ Đã xử lý 26800/89712 dòng (29.87%)
# ➡️ Đã xử lý 26850/89712 dòng (29.93%)
# ➡️ Đã xử lý 26900/89712 dòng (29.98%)
# ➡️ Đã xử lý 26950/89712 dòng (30.04%)
# ➡️ Đã xử lý 27000/89712 dòng (30.10%)
# ➡️ Đã xử lý 27050/89712 dòng (30.15%)
# ➡️ Đã xử lý 27100/89712 dòng (30.21%)
# ➡️ Đã xử lý 27150/89712 dòng (30.26%)
# ➡️ Đã xử lý 27200/89712 dòng (30.32%)
# ➡️ Đã xử lý 27250/89712 dòng (30.37%)
# ➡️ Đã xử lý 27300/89712 dòng (30.43%)
# ➡️ Đã xử lý 27350/89712 dòng (30.49%)
# ➡️ Đã xử lý 27400/89712 dòng (30.54%)
# ➡️ Đã xử lý 27450/89712 dòng (30.60%)
# ➡️ Đã xử lý 27500/89712 dòng (30.65%)
# ➡️ Đã xử lý 27550/89712 dòng (30.71%)
# ➡️ Đã xử lý 27600/89712 dòng (30.77%)
# ➡️ Đã xử lý 27650/89712 dòng (30.82%)
# ➡️ Đã xử lý 27700/89712 dòng (30.88%)
# ➡️ Đã xử lý 27750/89712 dòng (30.93%)
# ➡️ Đã xử lý 27800/89712 dòng (30.99%)
# ➡️ Đã xử lý 27850/89712 dòng (31.04%)
# ➡️ Đã xử lý 27900/89712 dòng (31.10%)
# ➡️ Đã xử lý 27950/89712 dòng (31.16%)
# ➡️ Đã xử lý 28000/89712 dòng (31.21%)
# ➡️ Đã xử lý 28050/89712 dòng (31.27%)
# ➡️ Đã xử lý 28100/89712 dòng (31.32%)
# ➡️ Đã xử lý 28150/89712 dòng (31.38%)
# ➡️ Đã xử lý 28200/89712 dòng (31.43%)
# ➡️ Đã xử lý 28250/89712 dòng (31.49%)
# ➡️ Đã xử lý 28300/89712 dòng (31.55%)
# ➡️ Đã xử lý 28350/89712 dòng (31.60%)
# ➡️ Đã xử lý 28400/89712 dòng (31.66%)
# ➡️ Đã xử lý 28450/89712 dòng (31.71%)
# ➡️ Đã xử lý 28500/89712 dòng (31.77%)
# ➡️ Đã xử lý 28550/89712 dòng (31.82%)
# ➡️ Đã xử lý 28600/89712 dòng (31.88%)
# ➡️ Đã xử lý 28650/89712 dòng (31.94%)
# ➡️ Đã xử lý 28700/89712 dòng (31.99%)
# ➡️ Đã xử lý 28750/89712 dòng (32.05%)
# ➡️ Đã xử lý 28800/89712 dòng (32.10%)
# ➡️ Đã xử lý 28850/89712 dòng (32.16%)
# ➡️ Đã xử lý 28900/89712 dòng (32.21%)
# ➡️ Đã xử lý 28950/89712 dòng (32.27%)
# ➡️ Đã xử lý 29000/89712 dòng (32.33%)
# ➡️ Đã xử lý 29050/89712 dòng (32.38%)
# ➡️ Đã xử lý 29100/89712 dòng (32.44%)
# ➡️ Đã xử lý 29150/89712 dòng (32.49%)
# ➡️ Đã xử lý 29200/89712 dòng (32.55%)
# ➡️ Đã xử lý 29250/89712 dòng (32.60%)
# ➡️ Đã xử lý 29300/89712 dòng (32.66%)
# ➡️ Đã xử lý 29350/89712 dòng (32.72%)
# ➡️ Đã xử lý 29400/89712 dòng (32.77%)
# ➡️ Đã xử lý 29450/89712 dòng (32.83%)
# ➡️ Đã xử lý 29500/89712 dòng (32.88%)
# ➡️ Đã xử lý 29550/89712 dòng (32.94%)
# ➡️ Đã xử lý 29600/89712 dòng (32.99%)
# ➡️ Đã xử lý 29650/89712 dòng (33.05%)
# ➡️ Đã xử lý 29700/89712 dòng (33.11%)
# ➡️ Đã xử lý 29750/89712 dòng (33.16%)
# ➡️ Đã xử lý 29800/89712 dòng (33.22%)
# ➡️ Đã xử lý 29850/89712 dòng (33.27%)
# ➡️ Đã xử lý 29900/89712 dòng (33.33%)
# ➡️ Đã xử lý 29950/89712 dòng (33.38%)
# ➡️ Đã xử lý 30000/89712 dòng (33.44%)
# ➡️ Đã xử lý 30050/89712 dòng (33.50%)
# ➡️ Đã xử lý 30100/89712 dòng (33.55%)
# ➡️ Đã xử lý 30150/89712 dòng (33.61%)
# ➡️ Đã xử lý 30200/89712 dòng (33.66%)
# ➡️ Đã xử lý 30250/89712 dòng (33.72%)
# ➡️ Đã xử lý 30300/89712 dòng (33.77%)
# ➡️ Đã xử lý 30350/89712 dòng (33.83%)
# ➡️ Đã xử lý 30400/89712 dòng (33.89%)
# ➡️ Đã xử lý 30450/89712 dòng (33.94%)
# ➡️ Đã xử lý 30500/89712 dòng (34.00%)
# ➡️ Đã xử lý 30550/89712 dòng (34.05%)
# ➡️ Đã xử lý 30600/89712 dòng (34.11%)
# ➡️ Đã xử lý 30650/89712 dòng (34.16%)
# ➡️ Đã xử lý 30700/89712 dòng (34.22%)
# ➡️ Đã xử lý 30750/89712 dòng (34.28%)
# ➡️ Đã xử lý 30800/89712 dòng (34.33%)
# ➡️ Đã xử lý 30850/89712 dòng (34.39%)
# ➡️ Đã xử lý 30900/89712 dòng (34.44%)
# ➡️ Đã xử lý 30950/89712 dòng (34.50%)
# ➡️ Đã xử lý 31000/89712 dòng (34.56%)
# ➡️ Đã xử lý 31050/89712 dòng (34.61%)
# ➡️ Đã xử lý 31100/89712 dòng (34.67%)
# ➡️ Đã xử lý 31150/89712 dòng (34.72%)
# ➡️ Đã xử lý 31200/89712 dòng (34.78%)
# ➡️ Đã xử lý 31250/89712 dòng (34.83%)
# ➡️ Đã xử lý 31300/89712 dòng (34.89%)
# ➡️ Đã xử lý 31350/89712 dòng (34.95%)
# ➡️ Đã xử lý 31400/89712 dòng (35.00%)
# ➡️ Đã xử lý 31450/89712 dòng (35.06%)
# ➡️ Đã xử lý 31500/89712 dòng (35.11%)
# ➡️ Đã xử lý 31550/89712 dòng (35.17%)
# ➡️ Đã xử lý 31600/89712 dòng (35.22%)
# ➡️ Đã xử lý 31650/89712 dòng (35.28%)
# ➡️ Đã xử lý 31700/89712 dòng (35.34%)
# ➡️ Đã xử lý 31750/89712 dòng (35.39%)
# ➡️ Đã xử lý 31800/89712 dòng (35.45%)
# ➡️ Đã xử lý 31850/89712 dòng (35.50%)
# ➡️ Đã xử lý 31900/89712 dòng (35.56%)
# ➡️ Đã xử lý 31950/89712 dòng (35.61%)
# ➡️ Đã xử lý 32000/89712 dòng (35.67%)
# ➡️ Đã xử lý 32050/89712 dòng (35.73%)
# ➡️ Đã xử lý 32100/89712 dòng (35.78%)
# ➡️ Đã xử lý 32150/89712 dòng (35.84%)
# ➡️ Đã xử lý 32200/89712 dòng (35.89%)
# ➡️ Đã xử lý 32250/89712 dòng (35.95%)
# ➡️ Đã xử lý 32300/89712 dòng (36.00%)
# ➡️ Đã xử lý 32350/89712 dòng (36.06%)
# ➡️ Đã xử lý 32400/89712 dòng (36.12%)
# ➡️ Đã xử lý 32450/89712 dòng (36.17%)
# ➡️ Đã xử lý 32500/89712 dòng (36.23%)
# ➡️ Đã xử lý 32550/89712 dòng (36.28%)
# ➡️ Đã xử lý 32600/89712 dòng (36.34%)
# ➡️ Đã xử lý 32650/89712 dòng (36.39%)
# ➡️ Đã xử lý 32700/89712 dòng (36.45%)
# ➡️ Đã xử lý 32750/89712 dòng (36.51%)
# ➡️ Đã xử lý 32800/89712 dòng (36.56%)
# ➡️ Đã xử lý 32850/89712 dòng (36.62%)
# ➡️ Đã xử lý 32900/89712 dòng (36.67%)
# ➡️ Đã xử lý 32950/89712 dòng (36.73%)
# ➡️ Đã xử lý 33000/89712 dòng (36.78%)
# ➡️ Đã xử lý 33050/89712 dòng (36.84%)
# ➡️ Đã xử lý 33100/89712 dòng (36.90%)
# ➡️ Đã xử lý 33150/89712 dòng (36.95%)
# ➡️ Đã xử lý 33200/89712 dòng (37.01%)
# ➡️ Đã xử lý 33250/89712 dòng (37.06%)
# ➡️ Đã xử lý 33300/89712 dòng (37.12%)
# ➡️ Đã xử lý 33350/89712 dòng (37.17%)
# ➡️ Đã xử lý 33400/89712 dòng (37.23%)
# ➡️ Đã xử lý 33450/89712 dòng (37.29%)
# ➡️ Đã xử lý 33500/89712 dòng (37.34%)
# ➡️ Đã xử lý 33550/89712 dòng (37.40%)
# ➡️ Đã xử lý 33600/89712 dòng (37.45%)
# ➡️ Đã xử lý 33650/89712 dòng (37.51%)
# ➡️ Đã xử lý 33700/89712 dòng (37.56%)
# ➡️ Đã xử lý 33750/89712 dòng (37.62%)
# ➡️ Đã xử lý 33800/89712 dòng (37.68%)
# ➡️ Đã xử lý 33850/89712 dòng (37.73%)
# ➡️ Đã xử lý 33900/89712 dòng (37.79%)
# ➡️ Đã xử lý 33950/89712 dòng (37.84%)
# ➡️ Đã xử lý 34000/89712 dòng (37.90%)
# ➡️ Đã xử lý 34050/89712 dòng (37.95%)
# ➡️ Đã xử lý 34100/89712 dòng (38.01%)
# ➡️ Đã xử lý 34150/89712 dòng (38.07%)
# ➡️ Đã xử lý 34200/89712 dòng (38.12%)
# ➡️ Đã xử lý 34250/89712 dòng (38.18%)
# ➡️ Đã xử lý 34300/89712 dòng (38.23%)
# ➡️ Đã xử lý 34350/89712 dòng (38.29%)
# ➡️ Đã xử lý 34400/89712 dòng (38.34%)
# ➡️ Đã xử lý 34450/89712 dòng (38.40%)
# ➡️ Đã xử lý 34500/89712 dòng (38.46%)
# ➡️ Đã xử lý 34550/89712 dòng (38.51%)
# ➡️ Đã xử lý 34600/89712 dòng (38.57%)
# ➡️ Đã xử lý 34650/89712 dòng (38.62%)
# ➡️ Đã xử lý 34700/89712 dòng (38.68%)
# ➡️ Đã xử lý 34750/89712 dòng (38.74%)
# ➡️ Đã xử lý 34800/89712 dòng (38.79%)
# ➡️ Đã xử lý 34850/89712 dòng (38.85%)
# ➡️ Đã xử lý 34900/89712 dòng (38.90%)
# ➡️ Đã xử lý 34950/89712 dòng (38.96%)
# ➡️ Đã xử lý 35000/89712 dòng (39.01%)
# ➡️ Đã xử lý 35050/89712 dòng (39.07%)
# ➡️ Đã xử lý 35100/89712 dòng (39.13%)
# ➡️ Đã xử lý 35150/89712 dòng (39.18%)
# ➡️ Đã xử lý 35200/89712 dòng (39.24%)
# ➡️ Đã xử lý 35250/89712 dòng (39.29%)
# ➡️ Đã xử lý 35300/89712 dòng (39.35%)
# ➡️ Đã xử lý 35350/89712 dòng (39.40%)
# ➡️ Đã xử lý 35400/89712 dòng (39.46%)
# ➡️ Đã xử lý 35450/89712 dòng (39.52%)
# ➡️ Đã xử lý 35500/89712 dòng (39.57%)
# ➡️ Đã xử lý 35550/89712 dòng (39.63%)
# ➡️ Đã xử lý 35600/89712 dòng (39.68%)
# ➡️ Đã xử lý 35650/89712 dòng (39.74%)
# ➡️ Đã xử lý 35700/89712 dòng (39.79%)
# ➡️ Đã xử lý 35750/89712 dòng (39.85%)
# ➡️ Đã xử lý 35800/89712 dòng (39.91%)
# ➡️ Đã xử lý 35850/89712 dòng (39.96%)
# ➡️ Đã xử lý 35900/89712 dòng (40.02%)
# ➡️ Đã xử lý 35950/89712 dòng (40.07%)
# ➡️ Đã xử lý 36000/89712 dòng (40.13%)
# ➡️ Đã xử lý 36050/89712 dòng (40.18%)
# ➡️ Đã xử lý 36100/89712 dòng (40.24%)
# ➡️ Đã xử lý 36150/89712 dòng (40.30%)
# ➡️ Đã xử lý 36200/89712 dòng (40.35%)
# ➡️ Đã xử lý 36250/89712 dòng (40.41%)
# ➡️ Đã xử lý 36300/89712 dòng (40.46%)
# ➡️ Đã xử lý 36350/89712 dòng (40.52%)
# ➡️ Đã xử lý 36400/89712 dòng (40.57%)
# ➡️ Đã xử lý 36450/89712 dòng (40.63%)
# ➡️ Đã xử lý 36500/89712 dòng (40.69%)
# ➡️ Đã xử lý 36550/89712 dòng (40.74%)
# ➡️ Đã xử lý 36600/89712 dòng (40.80%)
# ➡️ Đã xử lý 36650/89712 dòng (40.85%)
# ➡️ Đã xử lý 36700/89712 dòng (40.91%)
# ➡️ Đã xử lý 36750/89712 dòng (40.96%)
# ➡️ Đã xử lý 36800/89712 dòng (41.02%)
# ➡️ Đã xử lý 36850/89712 dòng (41.08%)
# ➡️ Đã xử lý 36900/89712 dòng (41.13%)
# ➡️ Đã xử lý 36950/89712 dòng (41.19%)
# ➡️ Đã xử lý 37000/89712 dòng (41.24%)
# ➡️ Đã xử lý 37050/89712 dòng (41.30%)
# ➡️ Đã xử lý 37100/89712 dòng (41.35%)
# ➡️ Đã xử lý 37150/89712 dòng (41.41%)
# ➡️ Đã xử lý 37200/89712 dòng (41.47%)
# ➡️ Đã xử lý 37250/89712 dòng (41.52%)
# ➡️ Đã xử lý 37300/89712 dòng (41.58%)
# ➡️ Đã xử lý 37350/89712 dòng (41.63%)
# ➡️ Đã xử lý 37400/89712 dòng (41.69%)
# ➡️ Đã xử lý 37450/89712 dòng (41.74%)
# ➡️ Đã xử lý 37500/89712 dòng (41.80%)
# ➡️ Đã xử lý 37550/89712 dòng (41.86%)
# ➡️ Đã xử lý 37600/89712 dòng (41.91%)
# ➡️ Đã xử lý 37650/89712 dòng (41.97%)
# ➡️ Đã xử lý 37700/89712 dòng (42.02%)
# ➡️ Đã xử lý 37750/89712 dòng (42.08%)
# ➡️ Đã xử lý 37800/89712 dòng (42.13%)
# ➡️ Đã xử lý 37850/89712 dòng (42.19%)
# ➡️ Đã xử lý 37900/89712 dòng (42.25%)
# ➡️ Đã xử lý 37950/89712 dòng (42.30%)
# ➡️ Đã xử lý 38000/89712 dòng (42.36%)
# ➡️ Đã xử lý 38050/89712 dòng (42.41%)
# ➡️ Đã xử lý 38100/89712 dòng (42.47%)
# ➡️ Đã xử lý 38150/89712 dòng (42.52%)
# ➡️ Đã xử lý 38200/89712 dòng (42.58%)
# ➡️ Đã xử lý 38250/89712 dòng (42.64%)
# ➡️ Đã xử lý 38300/89712 dòng (42.69%)
# ➡️ Đã xử lý 38350/89712 dòng (42.75%)
# ➡️ Đã xử lý 38400/89712 dòng (42.80%)
# ➡️ Đã xử lý 38450/89712 dòng (42.86%)
# ➡️ Đã xử lý 38500/89712 dòng (42.92%)
# ➡️ Đã xử lý 38550/89712 dòng (42.97%)
# ➡️ Đã xử lý 38600/89712 dòng (43.03%)
# ➡️ Đã xử lý 38650/89712 dòng (43.08%)
# ➡️ Đã xử lý 38700/89712 dòng (43.14%)
# ➡️ Đã xử lý 38750/89712 dòng (43.19%)
# ➡️ Đã xử lý 38800/89712 dòng (43.25%)
# ➡️ Đã xử lý 38850/89712 dòng (43.31%)
# ➡️ Đã xử lý 38900/89712 dòng (43.36%)
# ➡️ Đã xử lý 38950/89712 dòng (43.42%)
# ➡️ Đã xử lý 39000/89712 dòng (43.47%)
# ➡️ Đã xử lý 39050/89712 dòng (43.53%)
# ➡️ Đã xử lý 39100/89712 dòng (43.58%)
# ➡️ Đã xử lý 39150/89712 dòng (43.64%)
# ➡️ Đã xử lý 39200/89712 dòng (43.70%)
# ➡️ Đã xử lý 39250/89712 dòng (43.75%)
# ➡️ Đã xử lý 39300/89712 dòng (43.81%)
# ➡️ Đã xử lý 39350/89712 dòng (43.86%)
# ➡️ Đã xử lý 39400/89712 dòng (43.92%)
# ➡️ Đã xử lý 39450/89712 dòng (43.97%)
# ➡️ Đã xử lý 39500/89712 dòng (44.03%)
# ➡️ Đã xử lý 39550/89712 dòng (44.09%)
# ➡️ Đã xử lý 39600/89712 dòng (44.14%)
# ➡️ Đã xử lý 39650/89712 dòng (44.20%)
# ➡️ Đã xử lý 39700/89712 dòng (44.25%)
# ➡️ Đã xử lý 39750/89712 dòng (44.31%)
# ➡️ Đã xử lý 39800/89712 dòng (44.36%)
# ➡️ Đã xử lý 39850/89712 dòng (44.42%)
# ➡️ Đã xử lý 39900/89712 dòng (44.48%)
# ➡️ Đã xử lý 39950/89712 dòng (44.53%)
# ➡️ Đã xử lý 40000/89712 dòng (44.59%)
# ➡️ Đã xử lý 40050/89712 dòng (44.64%)
# ➡️ Đã xử lý 40100/89712 dòng (44.70%)
# ➡️ Đã xử lý 40150/89712 dòng (44.75%)
# ➡️ Đã xử lý 40200/89712 dòng (44.81%)
# ➡️ Đã xử lý 40250/89712 dòng (44.87%)
# ➡️ Đã xử lý 40300/89712 dòng (44.92%)
# ➡️ Đã xử lý 40350/89712 dòng (44.98%)
# ➡️ Đã xử lý 40400/89712 dòng (45.03%)
# ➡️ Đã xử lý 40450/89712 dòng (45.09%)
# ➡️ Đã xử lý 40500/89712 dòng (45.14%)
# ➡️ Đã xử lý 40550/89712 dòng (45.20%)
# ➡️ Đã xử lý 40600/89712 dòng (45.26%)
# ➡️ Đã xử lý 40650/89712 dòng (45.31%)
# ➡️ Đã xử lý 40700/89712 dòng (45.37%)
# ➡️ Đã xử lý 40750/89712 dòng (45.42%)
# ➡️ Đã xử lý 40800/89712 dòng (45.48%)
# ➡️ Đã xử lý 40850/89712 dòng (45.53%)
# ➡️ Đã xử lý 40900/89712 dòng (45.59%)
# ➡️ Đã xử lý 40950/89712 dòng (45.65%)
# ➡️ Đã xử lý 41000/89712 dòng (45.70%)
# ➡️ Đã xử lý 41050/89712 dòng (45.76%)
# ➡️ Đã xử lý 41100/89712 dòng (45.81%)
# ➡️ Đã xử lý 41150/89712 dòng (45.87%)
# ➡️ Đã xử lý 41200/89712 dòng (45.92%)
# ➡️ Đã xử lý 41250/89712 dòng (45.98%)
# ➡️ Đã xử lý 41300/89712 dòng (46.04%)
# ➡️ Đã xử lý 41350/89712 dòng (46.09%)
# ➡️ Đã xử lý 41400/89712 dòng (46.15%)
# ➡️ Đã xử lý 41450/89712 dòng (46.20%)
# ➡️ Đã xử lý 41500/89712 dòng (46.26%)
# ➡️ Đã xử lý 41550/89712 dòng (46.31%)
# ➡️ Đã xử lý 41600/89712 dòng (46.37%)
# ➡️ Đã xử lý 41650/89712 dòng (46.43%)
# ➡️ Đã xử lý 41700/89712 dòng (46.48%)
# ➡️ Đã xử lý 41750/89712 dòng (46.54%)
# ➡️ Đã xử lý 41800/89712 dòng (46.59%)
# ➡️ Đã xử lý 41850/89712 dòng (46.65%)
# ➡️ Đã xử lý 41900/89712 dòng (46.71%)
# ➡️ Đã xử lý 41950/89712 dòng (46.76%)
# ➡️ Đã xử lý 42000/89712 dòng (46.82%)
# ➡️ Đã xử lý 42050/89712 dòng (46.87%)
# ➡️ Đã xử lý 42100/89712 dòng (46.93%)
# ➡️ Đã xử lý 42150/89712 dòng (46.98%)
# ➡️ Đã xử lý 42200/89712 dòng (47.04%)
# ➡️ Đã xử lý 42250/89712 dòng (47.10%)
# ➡️ Đã xử lý 42300/89712 dòng (47.15%)
# ➡️ Đã xử lý 42350/89712 dòng (47.21%)
# ➡️ Đã xử lý 42400/89712 dòng (47.26%)
# ➡️ Đã xử lý 42450/89712 dòng (47.32%)
# ➡️ Đã xử lý 42500/89712 dòng (47.37%)
# ➡️ Đã xử lý 42550/89712 dòng (47.43%)
# ➡️ Đã xử lý 42600/89712 dòng (47.49%)
# ➡️ Đã xử lý 42650/89712 dòng (47.54%)
# ➡️ Đã xử lý 42700/89712 dòng (47.60%)
# ➡️ Đã xử lý 42750/89712 dòng (47.65%)
# ➡️ Đã xử lý 42800/89712 dòng (47.71%)
# ➡️ Đã xử lý 42850/89712 dòng (47.76%)
# ➡️ Đã xử lý 42900/89712 dòng (47.82%)
# ➡️ Đã xử lý 42950/89712 dòng (47.88%)
# ➡️ Đã xử lý 43000/89712 dòng (47.93%)
# ➡️ Đã xử lý 43050/89712 dòng (47.99%)
# ➡️ Đã xử lý 43100/89712 dòng (48.04%)
# ➡️ Đã xử lý 43150/89712 dòng (48.10%)
# ➡️ Đã xử lý 43200/89712 dòng (48.15%)
# ➡️ Đã xử lý 43250/89712 dòng (48.21%)
# ➡️ Đã xử lý 43300/89712 dòng (48.27%)
# ➡️ Đã xử lý 43350/89712 dòng (48.32%)
# ➡️ Đã xử lý 43400/89712 dòng (48.38%)
# ➡️ Đã xử lý 43450/89712 dòng (48.43%)
# ➡️ Đã xử lý 43500/89712 dòng (48.49%)
# ➡️ Đã xử lý 43550/89712 dòng (48.54%)
# ➡️ Đã xử lý 43600/89712 dòng (48.60%)
# ➡️ Đã xử lý 43650/89712 dòng (48.66%)
# ➡️ Đã xử lý 43700/89712 dòng (48.71%)
# ➡️ Đã xử lý 43750/89712 dòng (48.77%)
# ➡️ Đã xử lý 43800/89712 dòng (48.82%)
# ➡️ Đã xử lý 43850/89712 dòng (48.88%)
# ➡️ Đã xử lý 43900/89712 dòng (48.93%)
# ➡️ Đã xử lý 43950/89712 dòng (48.99%)
# ➡️ Đã xử lý 44000/89712 dòng (49.05%)
# ➡️ Đã xử lý 44050/89712 dòng (49.10%)
# ➡️ Đã xử lý 44100/89712 dòng (49.16%)
# ➡️ Đã xử lý 44150/89712 dòng (49.21%)
# ➡️ Đã xử lý 44200/89712 dòng (49.27%)
# ➡️ Đã xử lý 44250/89712 dòng (49.32%)
# ➡️ Đã xử lý 44300/89712 dòng (49.38%)
# ➡️ Đã xử lý 44350/89712 dòng (49.44%)
# ➡️ Đã xử lý 44400/89712 dòng (49.49%)
# ➡️ Đã xử lý 44450/89712 dòng (49.55%)
# ➡️ Đã xử lý 44500/89712 dòng (49.60%)
# ➡️ Đã xử lý 44550/89712 dòng (49.66%)
# ➡️ Đã xử lý 44600/89712 dòng (49.71%)
# ➡️ Đã xử lý 44650/89712 dòng (49.77%)
# ➡️ Đã xử lý 44700/89712 dòng (49.83%)
# ➡️ Đã xử lý 44750/89712 dòng (49.88%)
# ➡️ Đã xử lý 44800/89712 dòng (49.94%)
# ➡️ Đã xử lý 44850/89712 dòng (49.99%)
# ➡️ Đã xử lý 44900/89712 dòng (50.05%)
# ➡️ Đã xử lý 44950/89712 dòng (50.10%)
# ➡️ Đã xử lý 45000/89712 dòng (50.16%)
# ➡️ Đã xử lý 45050/89712 dòng (50.22%)
# ➡️ Đã xử lý 45100/89712 dòng (50.27%)
# ➡️ Đã xử lý 45150/89712 dòng (50.33%)
# ➡️ Đã xử lý 45200/89712 dòng (50.38%)
# ➡️ Đã xử lý 45250/89712 dòng (50.44%)
# ➡️ Đã xử lý 45300/89712 dòng (50.49%)
# ➡️ Đã xử lý 45350/89712 dòng (50.55%)
# ➡️ Đã xử lý 45400/89712 dòng (50.61%)
# ➡️ Đã xử lý 45450/89712 dòng (50.66%)
# ➡️ Đã xử lý 45500/89712 dòng (50.72%)
# ➡️ Đã xử lý 45550/89712 dòng (50.77%)
# ➡️ Đã xử lý 45600/89712 dòng (50.83%)
# ➡️ Đã xử lý 45650/89712 dòng (50.89%)
# ➡️ Đã xử lý 45700/89712 dòng (50.94%)
# ➡️ Đã xử lý 45750/89712 dòng (51.00%)
# ➡️ Đã xử lý 45800/89712 dòng (51.05%)
# ➡️ Đã xử lý 45850/89712 dòng (51.11%)
# ➡️ Đã xử lý 45900/89712 dòng (51.16%)
# ➡️ Đã xử lý 45950/89712 dòng (51.22%)
# ➡️ Đã xử lý 46000/89712 dòng (51.28%)
# ➡️ Đã xử lý 46050/89712 dòng (51.33%)
# ➡️ Đã xử lý 46100/89712 dòng (51.39%)
# ➡️ Đã xử lý 46150/89712 dòng (51.44%)
# ➡️ Đã xử lý 46200/89712 dòng (51.50%)
# ➡️ Đã xử lý 46250/89712 dòng (51.55%)
# ➡️ Đã xử lý 46300/89712 dòng (51.61%)
# ➡️ Đã xử lý 46350/89712 dòng (51.67%)
# ➡️ Đã xử lý 46400/89712 dòng (51.72%)
# ➡️ Đã xử lý 46450/89712 dòng (51.78%)
# ➡️ Đã xử lý 46500/89712 dòng (51.83%)
# ➡️ Đã xử lý 46550/89712 dòng (51.89%)
# ➡️ Đã xử lý 46600/89712 dòng (51.94%)
# ➡️ Đã xử lý 46650/89712 dòng (52.00%)
# ➡️ Đã xử lý 46700/89712 dòng (52.06%)
# ➡️ Đã xử lý 46750/89712 dòng (52.11%)
# ➡️ Đã xử lý 46800/89712 dòng (52.17%)
# ➡️ Đã xử lý 46850/89712 dòng (52.22%)
# ➡️ Đã xử lý 46900/89712 dòng (52.28%)
# ➡️ Đã xử lý 46950/89712 dòng (52.33%)
# ➡️ Đã xử lý 47000/89712 dòng (52.39%)
# ➡️ Đã xử lý 47050/89712 dòng (52.45%)
# ➡️ Đã xử lý 47100/89712 dòng (52.50%)
# ➡️ Đã xử lý 47150/89712 dòng (52.56%)
# ➡️ Đã xử lý 47200/89712 dòng (52.61%)
# ➡️ Đã xử lý 47250/89712 dòng (52.67%)
# ➡️ Đã xử lý 47300/89712 dòng (52.72%)
# ➡️ Đã xử lý 47350/89712 dòng (52.78%)
# ➡️ Đã xử lý 47400/89712 dòng (52.84%)
# ➡️ Đã xử lý 47450/89712 dòng (52.89%)
# ➡️ Đã xử lý 47500/89712 dòng (52.95%)
# ➡️ Đã xử lý 47550/89712 dòng (53.00%)
# ➡️ Đã xử lý 47600/89712 dòng (53.06%)
# ➡️ Đã xử lý 47650/89712 dòng (53.11%)
# ➡️ Đã xử lý 47700/89712 dòng (53.17%)
# ➡️ Đã xử lý 47750/89712 dòng (53.23%)
# ➡️ Đã xử lý 47800/89712 dòng (53.28%)
# ➡️ Đã xử lý 47850/89712 dòng (53.34%)
# ➡️ Đã xử lý 47900/89712 dòng (53.39%)
# ➡️ Đã xử lý 47950/89712 dòng (53.45%)
# ➡️ Đã xử lý 48000/89712 dòng (53.50%)
# ➡️ Đã xử lý 48050/89712 dòng (53.56%)
# ➡️ Đã xử lý 48100/89712 dòng (53.62%)
# ➡️ Đã xử lý 48150/89712 dòng (53.67%)
# ➡️ Đã xử lý 48200/89712 dòng (53.73%)
# ➡️ Đã xử lý 48250/89712 dòng (53.78%)
# ➡️ Đã xử lý 48300/89712 dòng (53.84%)
# ➡️ Đã xử lý 48350/89712 dòng (53.89%)
# ➡️ Đã xử lý 48400/89712 dòng (53.95%)
# ➡️ Đã xử lý 48450/89712 dòng (54.01%)
# ➡️ Đã xử lý 48500/89712 dòng (54.06%)
# ➡️ Đã xử lý 48550/89712 dòng (54.12%)
# ➡️ Đã xử lý 48600/89712 dòng (54.17%)
# ➡️ Đã xử lý 48650/89712 dòng (54.23%)
# ➡️ Đã xử lý 48700/89712 dòng (54.28%)
# ➡️ Đã xử lý 48750/89712 dòng (54.34%)
# ➡️ Đã xử lý 48800/89712 dòng (54.40%)
# ➡️ Đã xử lý 48850/89712 dòng (54.45%)
# ➡️ Đã xử lý 48900/89712 dòng (54.51%)
# ➡️ Đã xử lý 48950/89712 dòng (54.56%)
# ➡️ Đã xử lý 49000/89712 dòng (54.62%)
# ➡️ Đã xử lý 49050/89712 dòng (54.67%)
# ➡️ Đã xử lý 49100/89712 dòng (54.73%)
# ➡️ Đã xử lý 49150/89712 dòng (54.79%)
# ➡️ Đã xử lý 49200/89712 dòng (54.84%)
# ➡️ Đã xử lý 49250/89712 dòng (54.90%)
# ➡️ Đã xử lý 49300/89712 dòng (54.95%)
# ➡️ Đã xử lý 49350/89712 dòng (55.01%)
# ➡️ Đã xử lý 49400/89712 dòng (55.07%)
# ➡️ Đã xử lý 49450/89712 dòng (55.12%)
# ➡️ Đã xử lý 49500/89712 dòng (55.18%)
# ➡️ Đã xử lý 49550/89712 dòng (55.23%)
# ➡️ Đã xử lý 49600/89712 dòng (55.29%)
# ➡️ Đã xử lý 49650/89712 dòng (55.34%)
# ➡️ Đã xử lý 49700/89712 dòng (55.40%)
# ➡️ Đã xử lý 49750/89712 dòng (55.46%)
# ➡️ Đã xử lý 49800/89712 dòng (55.51%)
# ➡️ Đã xử lý 49850/89712 dòng (55.57%)
# ➡️ Đã xử lý 49900/89712 dòng (55.62%)
# ➡️ Đã xử lý 49950/89712 dòng (55.68%)
# ➡️ Đã xử lý 50000/89712 dòng (55.73%)
# ➡️ Đã xử lý 50050/89712 dòng (55.79%)
# ➡️ Đã xử lý 50100/89712 dòng (55.85%)
# ➡️ Đã xử lý 50150/89712 dòng (55.90%)
# ➡️ Đã xử lý 50200/89712 dòng (55.96%)
# ➡️ Đã xử lý 50250/89712 dòng (56.01%)
# ➡️ Đã xử lý 50300/89712 dòng (56.07%)
# ➡️ Đã xử lý 50350/89712 dòng (56.12%)
# ➡️ Đã xử lý 50400/89712 dòng (56.18%)
# ➡️ Đã xử lý 50450/89712 dòng (56.24%)
# ➡️ Đã xử lý 50500/89712 dòng (56.29%)
# ➡️ Đã xử lý 50550/89712 dòng (56.35%)
# ➡️ Đã xử lý 50600/89712 dòng (56.40%)
# ➡️ Đã xử lý 50650/89712 dòng (56.46%)
# ➡️ Đã xử lý 50700/89712 dòng (56.51%)
# ➡️ Đã xử lý 50750/89712 dòng (56.57%)
# ➡️ Đã xử lý 50800/89712 dòng (56.63%)
# ➡️ Đã xử lý 50850/89712 dòng (56.68%)
# ➡️ Đã xử lý 50900/89712 dòng (56.74%)
# ➡️ Đã xử lý 50950/89712 dòng (56.79%)
# ➡️ Đã xử lý 51000/89712 dòng (56.85%)
# ➡️ Đã xử lý 51050/89712 dòng (56.90%)
# ➡️ Đã xử lý 51100/89712 dòng (56.96%)
# ➡️ Đã xử lý 51150/89712 dòng (57.02%)
# ➡️ Đã xử lý 51200/89712 dòng (57.07%)
# ➡️ Đã xử lý 51250/89712 dòng (57.13%)
# ➡️ Đã xử lý 51300/89712 dòng (57.18%)
# ➡️ Đã xử lý 51350/89712 dòng (57.24%)
# ➡️ Đã xử lý 51400/89712 dòng (57.29%)
# ➡️ Đã xử lý 51450/89712 dòng (57.35%)
# ➡️ Đã xử lý 51500/89712 dòng (57.41%)
# ➡️ Đã xử lý 51550/89712 dòng (57.46%)
# ➡️ Đã xử lý 51600/89712 dòng (57.52%)
# ➡️ Đã xử lý 51650/89712 dòng (57.57%)
# ➡️ Đã xử lý 51700/89712 dòng (57.63%)
# ➡️ Đã xử lý 51750/89712 dòng (57.68%)
# ➡️ Đã xử lý 51800/89712 dòng (57.74%)
# ➡️ Đã xử lý 51850/89712 dòng (57.80%)
# ➡️ Đã xử lý 51900/89712 dòng (57.85%)
# ➡️ Đã xử lý 51950/89712 dòng (57.91%)
# ➡️ Đã xử lý 52000/89712 dòng (57.96%)
# ➡️ Đã xử lý 52050/89712 dòng (58.02%)
# ➡️ Đã xử lý 52100/89712 dòng (58.07%)
# ➡️ Đã xử lý 52150/89712 dòng (58.13%)
# ➡️ Đã xử lý 52200/89712 dòng (58.19%)
# ➡️ Đã xử lý 52250/89712 dòng (58.24%)
# ➡️ Đã xử lý 52300/89712 dòng (58.30%)
# ➡️ Đã xử lý 52350/89712 dòng (58.35%)
# ➡️ Đã xử lý 52400/89712 dòng (58.41%)
# ➡️ Đã xử lý 52450/89712 dòng (58.46%)
# ➡️ Đã xử lý 52500/89712 dòng (58.52%)
# ➡️ Đã xử lý 52550/89712 dòng (58.58%)
# ➡️ Đã xử lý 52600/89712 dòng (58.63%)
# ➡️ Đã xử lý 52650/89712 dòng (58.69%)
# ➡️ Đã xử lý 52700/89712 dòng (58.74%)
# ➡️ Đã xử lý 52750/89712 dòng (58.80%)
# ➡️ Đã xử lý 52800/89712 dòng (58.86%)
# ➡️ Đã xử lý 52850/89712 dòng (58.91%)
# ➡️ Đã xử lý 52900/89712 dòng (58.97%)
# ➡️ Đã xử lý 52950/89712 dòng (59.02%)
# ➡️ Đã xử lý 53000/89712 dòng (59.08%)
# ➡️ Đã xử lý 53050/89712 dòng (59.13%)
# ➡️ Đã xử lý 53100/89712 dòng (59.19%)
# ➡️ Đã xử lý 53150/89712 dòng (59.25%)
# ➡️ Đã xử lý 53200/89712 dòng (59.30%)
# ➡️ Đã xử lý 53250/89712 dòng (59.36%)
# ➡️ Đã xử lý 53300/89712 dòng (59.41%)
# ➡️ Đã xử lý 53350/89712 dòng (59.47%)
# ➡️ Đã xử lý 53400/89712 dòng (59.52%)
# ➡️ Đã xử lý 53450/89712 dòng (59.58%)
# ➡️ Đã xử lý 53500/89712 dòng (59.64%)
# ➡️ Đã xử lý 53550/89712 dòng (59.69%)
# ➡️ Đã xử lý 53600/89712 dòng (59.75%)
# ➡️ Đã xử lý 53650/89712 dòng (59.80%)
# ➡️ Đã xử lý 53700/89712 dòng (59.86%)
# ➡️ Đã xử lý 53750/89712 dòng (59.91%)
# ➡️ Đã xử lý 53800/89712 dòng (59.97%)
# ➡️ Đã xử lý 53850/89712 dòng (60.03%)
# ➡️ Đã xử lý 53900/89712 dòng (60.08%)
# ➡️ Đã xử lý 53950/89712 dòng (60.14%)
# ➡️ Đã xử lý 54000/89712 dòng (60.19%)
# ➡️ Đã xử lý 54050/89712 dòng (60.25%)
# ➡️ Đã xử lý 54100/89712 dòng (60.30%)
# ➡️ Đã xử lý 54150/89712 dòng (60.36%)
# ➡️ Đã xử lý 54200/89712 dòng (60.42%)
# ➡️ Đã xử lý 54250/89712 dòng (60.47%)
# ➡️ Đã xử lý 54300/89712 dòng (60.53%)
# ➡️ Đã xử lý 54350/89712 dòng (60.58%)
# ➡️ Đã xử lý 54400/89712 dòng (60.64%)
# ➡️ Đã xử lý 54450/89712 dòng (60.69%)
# ➡️ Đã xử lý 54500/89712 dòng (60.75%)
# ➡️ Đã xử lý 54550/89712 dòng (60.81%)
# ➡️ Đã xử lý 54600/89712 dòng (60.86%)
# ➡️ Đã xử lý 54650/89712 dòng (60.92%)
# ➡️ Đã xử lý 54700/89712 dòng (60.97%)
# ➡️ Đã xử lý 54750/89712 dòng (61.03%)
# ➡️ Đã xử lý 54800/89712 dòng (61.08%)
# ➡️ Đã xử lý 54850/89712 dòng (61.14%)
# ➡️ Đã xử lý 54900/89712 dòng (61.20%)
# ➡️ Đã xử lý 54950/89712 dòng (61.25%)
# ➡️ Đã xử lý 55000/89712 dòng (61.31%)
# ➡️ Đã xử lý 55050/89712 dòng (61.36%)
# ➡️ Đã xử lý 55100/89712 dòng (61.42%)
# ➡️ Đã xử lý 55150/89712 dòng (61.47%)
# ➡️ Đã xử lý 55200/89712 dòng (61.53%)
# ➡️ Đã xử lý 55250/89712 dòng (61.59%)
# ➡️ Đã xử lý 55300/89712 dòng (61.64%)
# ➡️ Đã xử lý 55350/89712 dòng (61.70%)
# ➡️ Đã xử lý 55400/89712 dòng (61.75%)
# ➡️ Đã xử lý 55450/89712 dòng (61.81%)
# ➡️ Đã xử lý 55500/89712 dòng (61.86%)
# ➡️ Đã xử lý 55550/89712 dòng (61.92%)
# ➡️ Đã xử lý 55600/89712 dòng (61.98%)
# ➡️ Đã xử lý 55650/89712 dòng (62.03%)
# ➡️ Đã xử lý 55700/89712 dòng (62.09%)
# ➡️ Đã xử lý 55750/89712 dòng (62.14%)
# ➡️ Đã xử lý 55800/89712 dòng (62.20%)
# ➡️ Đã xử lý 55850/89712 dòng (62.25%)
# ➡️ Đã xử lý 55900/89712 dòng (62.31%)
# ➡️ Đã xử lý 55950/89712 dòng (62.37%)
# ➡️ Đã xử lý 56000/89712 dòng (62.42%)
# ➡️ Đã xử lý 56050/89712 dòng (62.48%)
# ➡️ Đã xử lý 56100/89712 dòng (62.53%)
# ➡️ Đã xử lý 56150/89712 dòng (62.59%)
# ➡️ Đã xử lý 56200/89712 dòng (62.64%)
# ➡️ Đã xử lý 56250/89712 dòng (62.70%)
# ➡️ Đã xử lý 56300/89712 dòng (62.76%)
# ➡️ Đã xử lý 56350/89712 dòng (62.81%)
# ➡️ Đã xử lý 56400/89712 dòng (62.87%)
# ➡️ Đã xử lý 56450/89712 dòng (62.92%)
# ➡️ Đã xử lý 56500/89712 dòng (62.98%)
# ➡️ Đã xử lý 56550/89712 dòng (63.04%)
# ➡️ Đã xử lý 56600/89712 dòng (63.09%)
# ➡️ Đã xử lý 56650/89712 dòng (63.15%)
# ➡️ Đã xử lý 56700/89712 dòng (63.20%)
# ➡️ Đã xử lý 56750/89712 dòng (63.26%)
# ➡️ Đã xử lý 56800/89712 dòng (63.31%)
# ➡️ Đã xử lý 56850/89712 dòng (63.37%)
# ➡️ Đã xử lý 56900/89712 dòng (63.43%)
# ➡️ Đã xử lý 56950/89712 dòng (63.48%)
# ➡️ Đã xử lý 57000/89712 dòng (63.54%)
# ➡️ Đã xử lý 57050/89712 dòng (63.59%)
# ➡️ Đã xử lý 57100/89712 dòng (63.65%)
# ➡️ Đã xử lý 57150/89712 dòng (63.70%)
# ➡️ Đã xử lý 57200/89712 dòng (63.76%)
# ➡️ Đã xử lý 57250/89712 dòng (63.82%)
# ➡️ Đã xử lý 57300/89712 dòng (63.87%)
# ➡️ Đã xử lý 57350/89712 dòng (63.93%)
# ➡️ Đã xử lý 57400/89712 dòng (63.98%)
# ➡️ Đã xử lý 57450/89712 dòng (64.04%)
# ➡️ Đã xử lý 57500/89712 dòng (64.09%)
# ➡️ Đã xử lý 57550/89712 dòng (64.15%)
# ➡️ Đã xử lý 57600/89712 dòng (64.21%)
# ➡️ Đã xử lý 57650/89712 dòng (64.26%)
# ➡️ Đã xử lý 57700/89712 dòng (64.32%)
# ➡️ Đã xử lý 57750/89712 dòng (64.37%)
# ➡️ Đã xử lý 57800/89712 dòng (64.43%)
# ➡️ Đã xử lý 57850/89712 dòng (64.48%)
# ➡️ Đã xử lý 57900/89712 dòng (64.54%)
# ➡️ Đã xử lý 57950/89712 dòng (64.60%)
# ➡️ Đã xử lý 58000/89712 dòng (64.65%)
# ➡️ Đã xử lý 58050/89712 dòng (64.71%)
# ➡️ Đã xử lý 58100/89712 dòng (64.76%)
# ➡️ Đã xử lý 58150/89712 dòng (64.82%)
# ➡️ Đã xử lý 58200/89712 dòng (64.87%)
# ➡️ Đã xử lý 58250/89712 dòng (64.93%)
# ➡️ Đã xử lý 58300/89712 dòng (64.99%)
# ➡️ Đã xử lý 58350/89712 dòng (65.04%)
# ➡️ Đã xử lý 58400/89712 dòng (65.10%)
# ➡️ Đã xử lý 58450/89712 dòng (65.15%)
# ➡️ Đã xử lý 58500/89712 dòng (65.21%)
# ➡️ Đã xử lý 58550/89712 dòng (65.26%)
# ➡️ Đã xử lý 58600/89712 dòng (65.32%)
# ➡️ Đã xử lý 58650/89712 dòng (65.38%)
# ➡️ Đã xử lý 58700/89712 dòng (65.43%)
# ➡️ Đã xử lý 58750/89712 dòng (65.49%)
# ➡️ Đã xử lý 58800/89712 dòng (65.54%)
# ➡️ Đã xử lý 58850/89712 dòng (65.60%)
# ➡️ Đã xử lý 58900/89712 dòng (65.65%)
# ➡️ Đã xử lý 58950/89712 dòng (65.71%)
# ➡️ Đã xử lý 59000/89712 dòng (65.77%)
# ➡️ Đã xử lý 59050/89712 dòng (65.82%)
# ➡️ Đã xử lý 59100/89712 dòng (65.88%)
# ➡️ Đã xử lý 59150/89712 dòng (65.93%)
# ➡️ Đã xử lý 59200/89712 dòng (65.99%)
# ➡️ Đã xử lý 59250/89712 dòng (66.04%)
# ➡️ Đã xử lý 59300/89712 dòng (66.10%)
# ➡️ Đã xử lý 59350/89712 dòng (66.16%)
# ➡️ Đã xử lý 59400/89712 dòng (66.21%)
# ➡️ Đã xử lý 59450/89712 dòng (66.27%)
# ➡️ Đã xử lý 59500/89712 dòng (66.32%)
# ➡️ Đã xử lý 59550/89712 dòng (66.38%)
# ➡️ Đã xử lý 59600/89712 dòng (66.43%)
# ➡️ Đã xử lý 59650/89712 dòng (66.49%)
# ➡️ Đã xử lý 59700/89712 dòng (66.55%)
# ➡️ Đã xử lý 59750/89712 dòng (66.60%)
# ➡️ Đã xử lý 59800/89712 dòng (66.66%)
# ➡️ Đã xử lý 59850/89712 dòng (66.71%)
# ➡️ Đã xử lý 59900/89712 dòng (66.77%)
# ➡️ Đã xử lý 59950/89712 dòng (66.82%)
# ➡️ Đã xử lý 60000/89712 dòng (66.88%)
# ➡️ Đã xử lý 60050/89712 dòng (66.94%)
# ➡️ Đã xử lý 60100/89712 dòng (66.99%)
# ➡️ Đã xử lý 60150/89712 dòng (67.05%)
# ➡️ Đã xử lý 60200/89712 dòng (67.10%)
# ➡️ Đã xử lý 60250/89712 dòng (67.16%)
# ➡️ Đã xử lý 60300/89712 dòng (67.22%)
# ➡️ Đã xử lý 60350/89712 dòng (67.27%)
# ➡️ Đã xử lý 60400/89712 dòng (67.33%)
# ➡️ Đã xử lý 60450/89712 dòng (67.38%)
# ➡️ Đã xử lý 60500/89712 dòng (67.44%)
# ➡️ Đã xử lý 60550/89712 dòng (67.49%)
# ➡️ Đã xử lý 60600/89712 dòng (67.55%)
# ➡️ Đã xử lý 60650/89712 dòng (67.61%)
# ➡️ Đã xử lý 60700/89712 dòng (67.66%)
# ➡️ Đã xử lý 60750/89712 dòng (67.72%)
# ➡️ Đã xử lý 60800/89712 dòng (67.77%)
# ➡️ Đã xử lý 60850/89712 dòng (67.83%)
# ➡️ Đã xử lý 60900/89712 dòng (67.88%)
# ➡️ Đã xử lý 60950/89712 dòng (67.94%)
# ➡️ Đã xử lý 61000/89712 dòng (68.00%)
# ➡️ Đã xử lý 61050/89712 dòng (68.05%)
# ➡️ Đã xử lý 61100/89712 dòng (68.11%)
# ➡️ Đã xử lý 61150/89712 dòng (68.16%)
# ➡️ Đã xử lý 61200/89712 dòng (68.22%)
# ➡️ Đã xử lý 61250/89712 dòng (68.27%)
# ➡️ Đã xử lý 61300/89712 dòng (68.33%)
# ➡️ Đã xử lý 61350/89712 dòng (68.39%)
# ➡️ Đã xử lý 61400/89712 dòng (68.44%)
# ➡️ Đã xử lý 61450/89712 dòng (68.50%)
# ➡️ Đã xử lý 61500/89712 dòng (68.55%)
# ➡️ Đã xử lý 61550/89712 dòng (68.61%)
# ➡️ Đã xử lý 61600/89712 dòng (68.66%)
# ➡️ Đã xử lý 61650/89712 dòng (68.72%)
# ➡️ Đã xử lý 61700/89712 dòng (68.78%)
# ➡️ Đã xử lý 61750/89712 dòng (68.83%)
# ➡️ Đã xử lý 61800/89712 dòng (68.89%)
# ➡️ Đã xử lý 61850/89712 dòng (68.94%)
# ➡️ Đã xử lý 61900/89712 dòng (69.00%)
# ➡️ Đã xử lý 61950/89712 dòng (69.05%)
# ➡️ Đã xử lý 62000/89712 dòng (69.11%)
# ➡️ Đã xử lý 62050/89712 dòng (69.17%)
# ➡️ Đã xử lý 62100/89712 dòng (69.22%)
# ➡️ Đã xử lý 62150/89712 dòng (69.28%)
# ➡️ Đã xử lý 62200/89712 dòng (69.33%)
# ➡️ Đã xử lý 62250/89712 dòng (69.39%)
# ➡️ Đã xử lý 62300/89712 dòng (69.44%)
# ➡️ Đã xử lý 62350/89712 dòng (69.50%)
# ➡️ Đã xử lý 62400/89712 dòng (69.56%)
# ➡️ Đã xử lý 62450/89712 dòng (69.61%)
# ➡️ Đã xử lý 62500/89712 dòng (69.67%)
# ➡️ Đã xử lý 62550/89712 dòng (69.72%)
# ➡️ Đã xử lý 62600/89712 dòng (69.78%)
# ➡️ Đã xử lý 62650/89712 dòng (69.83%)
# ➡️ Đã xử lý 62700/89712 dòng (69.89%)
# ➡️ Đã xử lý 62750/89712 dòng (69.95%)
# ➡️ Đã xử lý 62800/89712 dòng (70.00%)
# ➡️ Đã xử lý 62850/89712 dòng (70.06%)
# ➡️ Đã xử lý 62900/89712 dòng (70.11%)
# ➡️ Đã xử lý 62950/89712 dòng (70.17%)
# ➡️ Đã xử lý 63000/89712 dòng (70.22%)
# ➡️ Đã xử lý 63050/89712 dòng (70.28%)
# ➡️ Đã xử lý 63100/89712 dòng (70.34%)
# ➡️ Đã xử lý 63150/89712 dòng (70.39%)
# ➡️ Đã xử lý 63200/89712 dòng (70.45%)
# ➡️ Đã xử lý 63250/89712 dòng (70.50%)
# ➡️ Đã xử lý 63300/89712 dòng (70.56%)
# ➡️ Đã xử lý 63350/89712 dòng (70.61%)
# ➡️ Đã xử lý 63400/89712 dòng (70.67%)
# ➡️ Đã xử lý 63450/89712 dòng (70.73%)
# ➡️ Đã xử lý 63500/89712 dòng (70.78%)
# ...
# ➡️ Đã xử lý 68750/89712 dòng (76.63%)
# ➡️ Đã xử lý 68800/89712 dòng (76.69%)
# ➡️ Đã xử lý 68850/89712 dòng (76.75%)
# ➡️ Đã xử lý 68900/89712 dòng (76.80%)
# ➡️ Đã xử lý 68950/89712 dòng (76.86%)
# ➡️ Đã xử lý 69000/89712 dòng (76.91%)
# ➡️ Đã xử lý 69050/89712 dòng (76.97%)
# ➡️ Đã xử lý 69100/89712 dòng (77.02%)
# ➡️ Đã xử lý 69150/89712 dòng (77.08%)
# ➡️ Đã xử lý 69200/89712 dòng (77.14%)
# ➡️ Đã xử lý 69250/89712 dòng (77.19%)
# ➡️ Đã xử lý 69300/89712 dòng (77.25%)
# ➡️ Đã xử lý 69350/89712 dòng (77.30%)
# ➡️ Đã xử lý 69400/89712 dòng (77.36%)
# ➡️ Đã xử lý 69450/89712 dòng (77.41%)
# ➡️ Đã xử lý 69500/89712 dòng (77.47%)
# ➡️ Đã xử lý 69550/89712 dòng (77.53%)
# ➡️ Đã xử lý 69600/89712 dòng (77.58%)
# ➡️ Đã xử lý 69650/89712 dòng (77.64%)
# ➡️ Đã xử lý 69700/89712 dòng (77.69%)
# ➡️ Đã xử lý 69750/89712 dòng (77.75%)
# ➡️ Đã xử lý 69800/89712 dòng (77.80%)
# ➡️ Đã xử lý 69850/89712 dòng (77.86%)
# ➡️ Đã xử lý 69900/89712 dòng (77.92%)
# ➡️ Đã xử lý 69950/89712 dòng (77.97%)
# ➡️ Đã xử lý 70000/89712 dòng (78.03%)
# ➡️ Đã xử lý 70050/89712 dòng (78.08%)
# ➡️ Đã xử lý 70100/89712 dòng (78.14%)
# ➡️ Đã xử lý 70150/89712 dòng (78.19%)
# ➡️ Đã xử lý 70200/89712 dòng (78.25%)
# ➡️ Đã xử lý 70250/89712 dòng (78.31%)
# ➡️ Đã xử lý 70300/89712 dòng (78.36%)
# ➡️ Đã xử lý 70350/89712 dòng (78.42%)
# ➡️ Đã xử lý 70400/89712 dòng (78.47%)
# ➡️ Đã xử lý 70450/89712 dòng (78.53%)
# ➡️ Đã xử lý 70500/89712 dòng (78.58%)
# ➡️ Đã xử lý 70550/89712 dòng (78.64%)
# ➡️ Đã xử lý 70600/89712 dòng (78.70%)
# ➡️ Đã xử lý 70650/89712 dòng (78.75%)
# ➡️ Đã xử lý 70700/89712 dòng (78.81%)
# ➡️ Đã xử lý 70750/89712 dòng (78.86%)
# ➡️ Đã xử lý 70800/89712 dòng (78.92%)
# ➡️ Đã xử lý 70850/89712 dòng (78.97%)
# ➡️ Đã xử lý 70900/89712 dòng (79.03%)
# ➡️ Đã xử lý 70950/89712 dòng (79.09%)
# ➡️ Đã xử lý 71000/89712 dòng (79.14%)
# ➡️ Đã xử lý 71050/89712 dòng (79.20%)
# ➡️ Đã xử lý 71100/89712 dòng (79.25%)
# ➡️ Đã xử lý 71150/89712 dòng (79.31%)
# ➡️ Đã xử lý 71200/89712 dòng (79.37%)
# ➡️ Đã xử lý 71250/89712 dòng (79.42%)
# ➡️ Đã xử lý 71300/89712 dòng (79.48%)
# ➡️ Đã xử lý 71350/89712 dòng (79.53%)
# ➡️ Đã xử lý 71400/89712 dòng (79.59%)
# ➡️ Đã xử lý 71450/89712 dòng (79.64%)
# ➡️ Đã xử lý 71500/89712 dòng (79.70%)
# ➡️ Đã xử lý 71550/89712 dòng (79.76%)
# ➡️ Đã xử lý 71600/89712 dòng (79.81%)
# ➡️ Đã xử lý 71650/89712 dòng (79.87%)
# ➡️ Đã xử lý 71700/89712 dòng (79.92%)
# ➡️ Đã xử lý 71750/89712 dòng (79.98%)
# ➡️ Đã xử lý 71800/89712 dòng (80.03%)
# ➡️ Đã xử lý 71850/89712 dòng (80.09%)
# ➡️ Đã xử lý 71900/89712 dòng (80.15%)
# ➡️ Đã xử lý 71950/89712 dòng (80.20%)
# ➡️ Đã xử lý 72000/89712 dòng (80.26%)
# ➡️ Đã xử lý 72050/89712 dòng (80.31%)
# ➡️ Đã xử lý 72100/89712 dòng (80.37%)
# ➡️ Đã xử lý 72150/89712 dòng (80.42%)
# ➡️ Đã xử lý 72200/89712 dòng (80.48%)
# ➡️ Đã xử lý 72250/89712 dòng (80.54%)
# ➡️ Đã xử lý 72300/89712 dòng (80.59%)
# ➡️ Đã xử lý 72350/89712 dòng (80.65%)
# ➡️ Đã xử lý 72400/89712 dòng (80.70%)
# ➡️ Đã xử lý 72450/89712 dòng (80.76%)
# ➡️ Đã xử lý 72500/89712 dòng (80.81%)
# ➡️ Đã xử lý 72550/89712 dòng (80.87%)
# ➡️ Đã xử lý 72600/89712 dòng (80.93%)
# ➡️ Đã xử lý 72650/89712 dòng (80.98%)
# ➡️ Đã xử lý 72700/89712 dòng (81.04%)
# ➡️ Đã xử lý 72750/89712 dòng (81.09%)
# ➡️ Đã xử lý 72800/89712 dòng (81.15%)
# ➡️ Đã xử lý 72850/89712 dòng (81.20%)
# ➡️ Đã xử lý 72900/89712 dòng (81.26%)
# ➡️ Đã xử lý 72950/89712 dòng (81.32%)
# ➡️ Đã xử lý 73000/89712 dòng (81.37%)
# ➡️ Đã xử lý 73050/89712 dòng (81.43%)
# ➡️ Đã xử lý 73100/89712 dòng (81.48%)
# ➡️ Đã xử lý 73150/89712 dòng (81.54%)
# ➡️ Đã xử lý 73200/89712 dòng (81.59%)
# ➡️ Đã xử lý 73250/89712 dòng (81.65%)
# ➡️ Đã xử lý 73300/89712 dòng (81.71%)
# ➡️ Đã xử lý 73350/89712 dòng (81.76%)
# ➡️ Đã xử lý 73400/89712 dòng (81.82%)
# ➡️ Đã xử lý 73450/89712 dòng (81.87%)
# ➡️ Đã xử lý 73500/89712 dòng (81.93%)
# ➡️ Đã xử lý 73550/89712 dòng (81.98%)
# ➡️ Đã xử lý 73600/89712 dòng (82.04%)
# ➡️ Đã xử lý 73650/89712 dòng (82.10%)
# ➡️ Đã xử lý 73700/89712 dòng (82.15%)
# ➡️ Đã xử lý 73750/89712 dòng (82.21%)
# ➡️ Đã xử lý 73800/89712 dòng (82.26%)
# ➡️ Đã xử lý 73850/89712 dòng (82.32%)
# ➡️ Đã xử lý 73900/89712 dòng (82.37%)
# ➡️ Đã xử lý 73950/89712 dòng (82.43%)
# ➡️ Đã xử lý 74000/89712 dòng (82.49%)
# ➡️ Đã xử lý 74050/89712 dòng (82.54%)
# ➡️ Đã xử lý 74100/89712 dòng (82.60%)
# ➡️ Đã xử lý 74150/89712 dòng (82.65%)
# ➡️ Đã xử lý 74200/89712 dòng (82.71%)
# ➡️ Đã xử lý 74250/89712 dòng (82.76%)
# ➡️ Đã xử lý 74300/89712 dòng (82.82%)
# ➡️ Đã xử lý 74350/89712 dòng (82.88%)
# ➡️ Đã xử lý 74400/89712 dòng (82.93%)
# ➡️ Đã xử lý 74450/89712 dòng (82.99%)
# ➡️ Đã xử lý 74500/89712 dòng (83.04%)
# ➡️ Đã xử lý 74550/89712 dòng (83.10%)
# ➡️ Đã xử lý 74600/89712 dòng (83.15%)
# ➡️ Đã xử lý 74650/89712 dòng (83.21%)
# ➡️ Đã xử lý 74700/89712 dòng (83.27%)
# ➡️ Đã xử lý 74750/89712 dòng (83.32%)
# ➡️ Đã xử lý 74800/89712 dòng (83.38%)
# ➡️ Đã xử lý 74850/89712 dòng (83.43%)
# ➡️ Đã xử lý 74900/89712 dòng (83.49%)
# ➡️ Đã xử lý 74950/89712 dòng (83.55%)
# ➡️ Đã xử lý 75000/89712 dòng (83.60%)
# ➡️ Đã xử lý 75050/89712 dòng (83.66%)
# ➡️ Đã xử lý 75100/89712 dòng (83.71%)
# ➡️ Đã xử lý 75150/89712 dòng (83.77%)
# ➡️ Đã xử lý 75200/89712 dòng (83.82%)
# ➡️ Đã xử lý 75250/89712 dòng (83.88%)
# ➡️ Đã xử lý 75300/89712 dòng (83.94%)
# ➡️ Đã xử lý 75350/89712 dòng (83.99%)
# ➡️ Đã xử lý 75400/89712 dòng (84.05%)
# ➡️ Đã xử lý 75450/89712 dòng (84.10%)
# ➡️ Đã xử lý 75500/89712 dòng (84.16%)
# ➡️ Đã xử lý 75550/89712 dòng (84.21%)
# ➡️ Đã xử lý 75600/89712 dòng (84.27%)
# ➡️ Đã xử lý 75650/89712 dòng (84.33%)
# ➡️ Đã xử lý 75700/89712 dòng (84.38%)
# ➡️ Đã xử lý 75750/89712 dòng (84.44%)
# ➡️ Đã xử lý 75800/89712 dòng (84.49%)
# ➡️ Đã xử lý 75850/89712 dòng (84.55%)
# ➡️ Đã xử lý 75900/89712 dòng (84.60%)
# ➡️ Đã xử lý 75950/89712 dòng (84.66%)
# ➡️ Đã xử lý 76000/89712 dòng (84.72%)
# ➡️ Đã xử lý 76050/89712 dòng (84.77%)
# ➡️ Đã xử lý 76100/89712 dòng (84.83%)
# ➡️ Đã xử lý 76150/89712 dòng (84.88%)
# ➡️ Đã xử lý 76200/89712 dòng (84.94%)
# ➡️ Đã xử lý 76250/89712 dòng (84.99%)
# ➡️ Đã xử lý 76300/89712 dòng (85.05%)
# ➡️ Đã xử lý 76350/89712 dòng (85.11%)
# ➡️ Đã xử lý 76400/89712 dòng (85.16%)
# ➡️ Đã xử lý 76450/89712 dòng (85.22%)
# ➡️ Đã xử lý 76500/89712 dòng (85.27%)
# ➡️ Đã xử lý 76550/89712 dòng (85.33%)
# ➡️ Đã xử lý 76600/89712 dòng (85.38%)
# ➡️ Đã xử lý 76650/89712 dòng (85.44%)
# ➡️ Đã xử lý 76700/89712 dòng (85.50%)
# ➡️ Đã xử lý 76750/89712 dòng (85.55%)
# ➡️ Đã xử lý 76800/89712 dòng (85.61%)
# ➡️ Đã xử lý 76850/89712 dòng (85.66%)
# ➡️ Đã xử lý 76900/89712 dòng (85.72%)
# ➡️ Đã xử lý 76950/89712 dòng (85.77%)
# ➡️ Đã xử lý 77000/89712 dòng (85.83%)
# ➡️ Đã xử lý 77050/89712 dòng (85.89%)
# ➡️ Đã xử lý 77100/89712 dòng (85.94%)
# ➡️ Đã xử lý 77150/89712 dòng (86.00%)
# ➡️ Đã xử lý 77200/89712 dòng (86.05%)
# ➡️ Đã xử lý 77250/89712 dòng (86.11%)
# ➡️ Đã xử lý 77300/89712 dòng (86.16%)
# ➡️ Đã xử lý 77350/89712 dòng (86.22%)
# ➡️ Đã xử lý 77400/89712 dòng (86.28%)
# ➡️ Đã xử lý 77450/89712 dòng (86.33%)
# ➡️ Đã xử lý 77500/89712 dòng (86.39%)
# ➡️ Đã xử lý 77550/89712 dòng (86.44%)
# ➡️ Đã xử lý 77600/89712 dòng (86.50%)
# ➡️ Đã xử lý 77650/89712 dòng (86.55%)
# ➡️ Đã xử lý 77700/89712 dòng (86.61%)
# ➡️ Đã xử lý 77750/89712 dòng (86.67%)
# ➡️ Đã xử lý 77800/89712 dòng (86.72%)
# ➡️ Đã xử lý 77850/89712 dòng (86.78%)
# ➡️ Đã xử lý 77900/89712 dòng (86.83%)
# ➡️ Đã xử lý 77950/89712 dòng (86.89%)
# ➡️ Đã xử lý 78000/89712 dòng (86.94%)
# ➡️ Đã xử lý 78050/89712 dòng (87.00%)
# ➡️ Đã xử lý 78100/89712 dòng (87.06%)
# ➡️ Đã xử lý 78150/89712 dòng (87.11%)
# ➡️ Đã xử lý 78200/89712 dòng (87.17%)
# ➡️ Đã xử lý 78250/89712 dòng (87.22%)
# ➡️ Đã xử lý 78300/89712 dòng (87.28%)
# ➡️ Đã xử lý 78350/89712 dòng (87.34%)
# ➡️ Đã xử lý 78400/89712 dòng (87.39%)
# ➡️ Đã xử lý 78450/89712 dòng (87.45%)
# ➡️ Đã xử lý 78500/89712 dòng (87.50%)
# ➡️ Đã xử lý 78550/89712 dòng (87.56%)
# ➡️ Đã xử lý 78600/89712 dòng (87.61%)
# ➡️ Đã xử lý 78650/89712 dòng (87.67%)
# ➡️ Đã xử lý 78700/89712 dòng (87.73%)
# ➡️ Đã xử lý 78750/89712 dòng (87.78%)
# ➡️ Đã xử lý 78800/89712 dòng (87.84%)
# ➡️ Đã xử lý 78850/89712 dòng (87.89%)
# ➡️ Đã xử lý 78900/89712 dòng (87.95%)
# ➡️ Đã xử lý 78950/89712 dòng (88.00%)
# ➡️ Đã xử lý 79000/89712 dòng (88.06%)
# ➡️ Đã xử lý 79050/89712 dòng (88.12%)
# ➡️ Đã xử lý 79100/89712 dòng (88.17%)
# ➡️ Đã xử lý 79150/89712 dòng (88.23%)
# ➡️ Đã xử lý 79200/89712 dòng (88.28%)
# ➡️ Đã xử lý 79250/89712 dòng (88.34%)
# ➡️ Đã xử lý 79300/89712 dòng (88.39%)
# ➡️ Đã xử lý 79350/89712 dòng (88.45%)
# ➡️ Đã xử lý 79400/89712 dòng (88.51%)
# ➡️ Đã xử lý 79450/89712 dòng (88.56%)
# ➡️ Đã xử lý 79500/89712 dòng (88.62%)
# ➡️ Đã xử lý 79550/89712 dòng (88.67%)
# ➡️ Đã xử lý 79600/89712 dòng (88.73%)
# ➡️ Đã xử lý 79650/89712 dòng (88.78%)
# ➡️ Đã xử lý 79700/89712 dòng (88.84%)
# ➡️ Đã xử lý 79750/89712 dòng (88.90%)
# ➡️ Đã xử lý 79800/89712 dòng (88.95%)
# ➡️ Đã xử lý 79850/89712 dòng (89.01%)
# ➡️ Đã xử lý 79900/89712 dòng (89.06%)
# ➡️ Đã xử lý 79950/89712 dòng (89.12%)
# ➡️ Đã xử lý 80000/89712 dòng (89.17%)
# ➡️ Đã xử lý 80050/89712 dòng (89.23%)
# ➡️ Đã xử lý 80100/89712 dòng (89.29%)
# ➡️ Đã xử lý 80150/89712 dòng (89.34%)
# ➡️ Đã xử lý 80200/89712 dòng (89.40%)
# ➡️ Đã xử lý 80250/89712 dòng (89.45%)
# ➡️ Đã xử lý 80300/89712 dòng (89.51%)
# ➡️ Đã xử lý 80350/89712 dòng (89.56%)
# ➡️ Đã xử lý 80400/89712 dòng (89.62%)
# ➡️ Đã xử lý 80450/89712 dòng (89.68%)
# ➡️ Đã xử lý 80500/89712 dòng (89.73%)
# ➡️ Đã xử lý 80550/89712 dòng (89.79%)
# ➡️ Đã xử lý 80600/89712 dòng (89.84%)
# ➡️ Đã xử lý 80650/89712 dòng (89.90%)
# ➡️ Đã xử lý 80700/89712 dòng (89.95%)
# ➡️ Đã xử lý 80750/89712 dòng (90.01%)
# ➡️ Đã xử lý 80800/89712 dòng (90.07%)
# ➡️ Đã xử lý 80850/89712 dòng (90.12%)
# ➡️ Đã xử lý 80900/89712 dòng (90.18%)
# ➡️ Đã xử lý 80950/89712 dòng (90.23%)
# ➡️ Đã xử lý 81000/89712 dòng (90.29%)
# ➡️ Đã xử lý 81050/89712 dòng (90.34%)
# ➡️ Đã xử lý 81100/89712 dòng (90.40%)
# ➡️ Đã xử lý 81150/89712 dòng (90.46%)
# ➡️ Đã xử lý 81200/89712 dòng (90.51%)
# ➡️ Đã xử lý 81250/89712 dòng (90.57%)
# ➡️ Đã xử lý 81300/89712 dòng (90.62%)
# ➡️ Đã xử lý 81350/89712 dòng (90.68%)
# ➡️ Đã xử lý 81400/89712 dòng (90.73%)
# ➡️ Đã xử lý 81450/89712 dòng (90.79%)
# ➡️ Đã xử lý 81500/89712 dòng (90.85%)
# ➡️ Đã xử lý 81550/89712 dòng (90.90%)
# ➡️ Đã xử lý 81600/89712 dòng (90.96%)
# ➡️ Đã xử lý 81650/89712 dòng (91.01%)
# ➡️ Đã xử lý 81700/89712 dòng (91.07%)
# ➡️ Đã xử lý 81750/89712 dòng (91.12%)
# ➡️ Đã xử lý 81800/89712 dòng (91.18%)
# ➡️ Đã xử lý 81850/89712 dòng (91.24%)
# ➡️ Đã xử lý 81900/89712 dòng (91.29%)
# ➡️ Đã xử lý 81950/89712 dòng (91.35%)
# ➡️ Đã xử lý 82000/89712 dòng (91.40%)
# ➡️ Đã xử lý 82050/89712 dòng (91.46%)
# ➡️ Đã xử lý 82100/89712 dòng (91.52%)
# ➡️ Đã xử lý 82150/89712 dòng (91.57%)
# ➡️ Đã xử lý 82200/89712 dòng (91.63%)
# ➡️ Đã xử lý 82250/89712 dòng (91.68%)
# ➡️ Đã xử lý 82300/89712 dòng (91.74%)
# ➡️ Đã xử lý 82350/89712 dòng (91.79%)
# ➡️ Đã xử lý 82400/89712 dòng (91.85%)
# ➡️ Đã xử lý 82450/89712 dòng (91.91%)
# ➡️ Đã xử lý 82500/89712 dòng (91.96%)
# ➡️ Đã xử lý 82550/89712 dòng (92.02%)
# ➡️ Đã xử lý 82600/89712 dòng (92.07%)
# ➡️ Đã xử lý 82650/89712 dòng (92.13%)
# ➡️ Đã xử lý 82700/89712 dòng (92.18%)
# ➡️ Đã xử lý 82750/89712 dòng (92.24%)
# ➡️ Đã xử lý 82800/89712 dòng (92.30%)
# ➡️ Đã xử lý 82850/89712 dòng (92.35%)
# ➡️ Đã xử lý 82900/89712 dòng (92.41%)
# ➡️ Đã xử lý 82950/89712 dòng (92.46%)
# ➡️ Đã xử lý 83000/89712 dòng (92.52%)
# ➡️ Đã xử lý 83050/89712 dòng (92.57%)
# ➡️ Đã xử lý 83100/89712 dòng (92.63%)
# ➡️ Đã xử lý 83150/89712 dòng (92.69%)
# ➡️ Đã xử lý 83200/89712 dòng (92.74%)
# ➡️ Đã xử lý 83250/89712 dòng (92.80%)
# ➡️ Đã xử lý 83300/89712 dòng (92.85%)
# ➡️ Đã xử lý 83350/89712 dòng (92.91%)
# ➡️ Đã xử lý 83400/89712 dòng (92.96%)
# ➡️ Đã xử lý 83450/89712 dòng (93.02%)
# ➡️ Đã xử lý 83500/89712 dòng (93.08%)
# ➡️ Đã xử lý 83550/89712 dòng (93.13%)
# ➡️ Đã xử lý 83600/89712 dòng (93.19%)
# ➡️ Đã xử lý 83650/89712 dòng (93.24%)
# ➡️ Đã xử lý 83700/89712 dòng (93.30%)
# ➡️ Đã xử lý 83750/89712 dòng (93.35%)
# ➡️ Đã xử lý 83800/89712 dòng (93.41%)
# ➡️ Đã xử lý 83850/89712 dòng (93.47%)
# ➡️ Đã xử lý 83900/89712 dòng (93.52%)
# ➡️ Đã xử lý 83950/89712 dòng (93.58%)
# ➡️ Đã xử lý 84000/89712 dòng (93.63%)
# ➡️ Đã xử lý 84050/89712 dòng (93.69%)
# ➡️ Đã xử lý 84100/89712 dòng (93.74%)
# ➡️ Đã xử lý 84150/89712 dòng (93.80%)
# ➡️ Đã xử lý 84200/89712 dòng (93.86%)
# ➡️ Đã xử lý 84250/89712 dòng (93.91%)
# ➡️ Đã xử lý 84300/89712 dòng (93.97%)
# ➡️ Đã xử lý 84350/89712 dòng (94.02%)
# ➡️ Đã xử lý 84400/89712 dòng (94.08%)
# ➡️ Đã xử lý 84450/89712 dòng (94.13%)
# ➡️ Đã xử lý 84500/89712 dòng (94.19%)
# ➡️ Đã xử lý 84550/89712 dòng (94.25%)
# ➡️ Đã xử lý 84600/89712 dòng (94.30%)
# ➡️ Đã xử lý 84650/89712 dòng (94.36%)
# ➡️ Đã xử lý 84700/89712 dòng (94.41%)
# ➡️ Đã xử lý 84750/89712 dòng (94.47%)
# ➡️ Đã xử lý 84800/89712 dòng (94.52%)
# ➡️ Đã xử lý 84850/89712 dòng (94.58%)
# ➡️ Đã xử lý 84900/89712 dòng (94.64%)
# ➡️ Đã xử lý 84950/89712 dòng (94.69%)
# ➡️ Đã xử lý 85000/89712 dòng (94.75%)
# ➡️ Đã xử lý 85050/89712 dòng (94.80%)
# ➡️ Đã xử lý 85100/89712 dòng (94.86%)
# ➡️ Đã xử lý 85150/89712 dòng (94.91%)
# ➡️ Đã xử lý 85200/89712 dòng (94.97%)
# ➡️ Đã xử lý 85250/89712 dòng (95.03%)
# ➡️ Đã xử lý 85300/89712 dòng (95.08%)
# ➡️ Đã xử lý 85350/89712 dòng (95.14%)
# ➡️ Đã xử lý 85400/89712 dòng (95.19%)
# ➡️ Đã xử lý 85450/89712 dòng (95.25%)
# ➡️ Đã xử lý 85500/89712 dòng (95.30%)
# ➡️ Đã xử lý 85550/89712 dòng (95.36%)
# ➡️ Đã xử lý 85600/89712 dòng (95.42%)
# ➡️ Đã xử lý 85650/89712 dòng (95.47%)
# ➡️ Đã xử lý 85700/89712 dòng (95.53%)
# ➡️ Đã xử lý 85750/89712 dòng (95.58%)
# ➡️ Đã xử lý 85800/89712 dòng (95.64%)
# ➡️ Đã xử lý 85850/89712 dòng (95.70%)
# ➡️ Đã xử lý 85900/89712 dòng (95.75%)
# ➡️ Đã xử lý 85950/89712 dòng (95.81%)
# ➡️ Đã xử lý 86000/89712 dòng (95.86%)
# ➡️ Đã xử lý 86050/89712 dòng (95.92%)
# ➡️ Đã xử lý 86100/89712 dòng (95.97%)
# ➡️ Đã xử lý 86150/89712 dòng (96.03%)
# ➡️ Đã xử lý 86200/89712 dòng (96.09%)
# ➡️ Đã xử lý 86250/89712 dòng (96.14%)
# ➡️ Đã xử lý 86300/89712 dòng (96.20%)
# ➡️ Đã xử lý 86350/89712 dòng (96.25%)
# ➡️ Đã xử lý 86400/89712 dòng (96.31%)
# ➡️ Đã xử lý 86450/89712 dòng (96.36%)
# ➡️ Đã xử lý 86500/89712 dòng (96.42%)
# ➡️ Đã xử lý 86550/89712 dòng (96.48%)
# ➡️ Đã xử lý 86600/89712 dòng (96.53%)
# ➡️ Đã xử lý 86650/89712 dòng (96.59%)
# ➡️ Đã xử lý 86700/89712 dòng (96.64%)
# ➡️ Đã xử lý 86750/89712 dòng (96.70%)
# ➡️ Đã xử lý 86800/89712 dòng (96.75%)
# ➡️ Đã xử lý 86850/89712 dòng (96.81%)
# ➡️ Đã xử lý 86900/89712 dòng (96.87%)
# ➡️ Đã xử lý 86950/89712 dòng (96.92%)
# ➡️ Đã xử lý 87000/89712 dòng (96.98%)
# ➡️ Đã xử lý 87050/89712 dòng (97.03%)
# ➡️ Đã xử lý 87100/89712 dòng (97.09%)
# ➡️ Đã xử lý 87150/89712 dòng (97.14%)
# ➡️ Đã xử lý 87200/89712 dòng (97.20%)
# ➡️ Đã xử lý 87250/89712 dòng (97.26%)
# ➡️ Đã xử lý 87300/89712 dòng (97.31%)
# ➡️ Đã xử lý 87350/89712 dòng (97.37%)
# ➡️ Đã xử lý 87400/89712 dòng (97.42%)
# ➡️ Đã xử lý 87450/89712 dòng (97.48%)
# ➡️ Đã xử lý 87500/89712 dòng (97.53%)
# ➡️ Đã xử lý 87550/89712 dòng (97.59%)
# ➡️ Đã xử lý 87600/89712 dòng (97.65%)
# ➡️ Đã xử lý 87650/89712 dòng (97.70%)
# ➡️ Đã xử lý 87700/89712 dòng (97.76%)
# ➡️ Đã xử lý 87750/89712 dòng (97.81%)
# ➡️ Đã xử lý 87800/89712 dòng (97.87%)
# ➡️ Đã xử lý 87850/89712 dòng (97.92%)
# ➡️ Đã xử lý 87900/89712 dòng (97.98%)
# ➡️ Đã xử lý 87950/89712 dòng (98.04%)
# ➡️ Đã xử lý 88000/89712 dòng (98.09%)
# ➡️ Đã xử lý 88050/89712 dòng (98.15%)
# ➡️ Đã xử lý 88100/89712 dòng (98.20%)
# ➡️ Đã xử lý 88150/89712 dòng (98.26%)
# ➡️ Đã xử lý 88200/89712 dòng (98.31%)
# ➡️ Đã xử lý 88250/89712 dòng (98.37%)
# ➡️ Đã xử lý 88300/89712 dòng (98.43%)
# ➡️ Đã xử lý 88350/89712 dòng (98.48%)
# ➡️ Đã xử lý 88400/89712 dòng (98.54%)
# ➡️ Đã xử lý 88450/89712 dòng (98.59%)
# ➡️ Đã xử lý 88500/89712 dòng (98.65%)
# ➡️ Đã xử lý 88550/89712 dòng (98.70%)
# ➡️ Đã xử lý 88600/89712 dòng (98.76%)
# ➡️ Đã xử lý 88650/89712 dòng (98.82%)
# ➡️ Đã xử lý 88700/89712 dòng (98.87%)
# ➡️ Đã xử lý 88750/89712 dòng (98.93%)
# ➡️ Đã xử lý 88800/89712 dòng (98.98%)
# ➡️ Đã xử lý 88850/89712 dòng (99.04%)
# ➡️ Đã xử lý 88900/89712 dòng (99.09%)
# ➡️ Đã xử lý 88950/89712 dòng (99.15%)
# ➡️ Đã xử lý 89000/89712 dòng (99.21%)
# ➡️ Đã xử lý 89050/89712 dòng (99.26%)
# ➡️ Đã xử lý 89100/89712 dòng (99.32%)
# ➡️ Đã xử lý 89150/89712 dòng (99.37%)
# ➡️ Đã xử lý 89200/89712 dòng (99.43%)
# ➡️ Đã xử lý 89250/89712 dòng (99.49%)
# ➡️ Đã xử lý 89300/89712 dòng (99.54%)
# ➡️ Đã xử lý 89350/89712 dòng (99.60%)
# ➡️ Đã xử lý 89400/89712 dòng (99.65%)
# ➡️ Đã xử lý 89450/89712 dòng (99.71%)
# ➡️ Đã xử lý 89500/89712 dòng (99.76%)
# ➡️ Đã xử lý 89550/89712 dòng (99.82%)
# ➡️ Đã xử lý 89600/89712 dòng (99.88%)
# ➡️ Đã xử lý 89650/89712 dòng (99.93%)
# ➡️ Đã xử lý 89700/89712 dòng (99.99%)
# ➡️ Đã xử lý 89712/89712 dòng (100.00%)

# %%
# --- Chuẩn hóa các đặc trưng phụ ---
print("📏 Đang chuẩn hóa các đặc trưng phụ...")
feature_cols = ['sentiment', 'char_count', 'word_count', 'capital_ratio', 'punctuation_ratio']
scaler = MinMaxScaler()
X_features = scaler.fit_transform(df[feature_cols])
# Out:
# 📏 Đang chuẩn hóa các đặc trưng phụ...

# %%
# --- Lưu đặc trưng phụ để sử dụng cùng embedding sau ---
np.save("X_features_scaled.npy", X_features)
df.to_csv("cleaned_data_with_features.csv", index=False)
print("✅ Đã lưu đặc trưng nâng cao vào: X_features_scaled.npy và cleaned_data_with_features.csv")
# Out:
# ✅ Đã lưu đặc trưng nâng cao vào: X_features_scaled.npy và cleaned_data_with_features.csv
